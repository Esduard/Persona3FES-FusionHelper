# %%
import re
from bs4 import BeautifulSoup
import pandas as pd

# Load the HTML content
with open('skill_list.html', 'r') as f:
    html_content = f.read()

# Parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Find all "tr" elements with class="app-smt-skill-list-row"
rows = soup.find_all('tr', class_='app-smt-skill-list-row')

# Prepare a list to hold the data
data = []

# Loop through each row
for row in rows:
    # Get the skill name
    skill = row.find_all('td')[1].text

    # Get the skill type by finding the "element-icon" div and extracting its text
    type_div = row.find('div', class_='element-icon')
    skill_type = type_div.text if type_div else 'Unknown'

    # Extract the rank value from the appropriate <td> element
    rank_td = row.find_all('td')[5]  # Assuming the rank value is always in the 6th <td> element
    rank = rank_td.text.strip()

    # Initialize an empty list for learners
    learners = [a.text for a in row.find_all('a')]
    
    # Remove all "\n" and text between parentheses
    learners = [re.sub(r'\(.*?\)|\n', '', learner) for learner in learners]

    # Add the data to the list, including the skill type and rank
    data.append({'skill': skill, 'type': skill_type, 'rank': rank, 'learns': ', '.join(learners)})

# Create a pandas DataFrame
df = pd.DataFrame(data)

# Print the entire dataframe
pd.set_option('display.max_rows', None)
print(df)
# Out:
#                 skill type rank  \
# 0              Cleave  sla  1.5
# 1         Power Slash  sla    2
# 2            Getsu-ei  sla    3
# 3              Zan-ei  sla    3
# 4          Gale Slash  sla    3
# 5        Mighty Swing  sla    4
# 6           Fatal End  sla  4.5
# 7       Blade of Fury  sla  5.5
# 8          Deathbound  sla  6.5
# 9      Heaven's Blade  sla    7
# 10      Tempest Slash  sla    7
# 11        Brave Blade  sla    8
# 12      Scarlet Havoc  sla   99
# 13       Vorpal Blade  sla   99
# 14               Bash  str  1.5
# 15       Assault Dive  str  2.5
# 16        Sonic Punch  str  2.5
# 17       Swift Strike  str    3
# 18          Kill Rush  str  3.5
# 19   Herculean Strike  str    4
# 20      Gigantic Fist  str  5.5
# 21          Heat Wave  str  5.5
# 22     Vicious Strike  str    6
# 23        Akasha Arts  str    7
# 24         God's Hand  str    8
# 25       Shadow Hound  str   99
# 26       Weary Thrust  str   99
# 27        Single Shot  pie  1.5
# 28       Double Fangs  pie    2
# 29         Holy Arrow  pie  2.5
# 30          Twin Shot  pie  3.5
# 31       Cruel Attack  pie    4
# 32       Torrent Shot  pie  4.5
# 33       Vile Assault  pie    5
# 34       Poison Arrow  pie    5
# 35         Arrow Rain  pie  6.5
# 36      Myriad Arrows  pie    7
# 37            Pralaya  pie    8
# 38       Primal Force  pie    8
# 39                Agi  fir  1.5
# 40             Maragi  fir    2
# 41             Agilao  fir  3.5
# 42           Maragion  fir    4
# 43            Agidyne  fir  5.5
# 44         Maragidyne  fir    6
# 45           Ragnarok  fir    9
# 46          Ardhanari  fir   99
# 47       Maralagidyne  fir   99
# 48               Bufu  ice  1.5
# 49             Mabufu  ice    2
# 50             Bufula  ice  3.5
# 51           Mabufula  ice    4
# 52           Bufudyne  ice  5.5
# 53         Mabufudyne  ice    6
# 54           Niflheim  ice    9
# 55         King and I  ice   99
# 56                Zio  ele  1.5
# 57              Mazio  ele    2
# 58             Zionga  ele  3.5
# 59           Mazionga  ele    4
# 60            Ziodyne  ele  5.5
# 61          Maziodyne  ele    6
# 62      Thunder Reign  ele    9
# 63       Thunder Call  ele   99
# 64               Garu  win  1.5
# 65             Magaru  win    2
# 66             Garula  win  3.5
# 67           Magarula  win    4
# 68           Garudyne  win  5.5
# 69         Magarudyne  win    6
# 70         Panta Rhei  win    9
# 71               Hama  lig  2.5
# 72             Mahama  lig    3
# 73             Hamaon  lig  4.5
# 74           Mahamaon  lig    5
# 75            Samsara  lig    9
# 76            Justice  lig   99
# 77               Mudo  dar  2.5
# 78             Mamudo  dar    3
# 79             Mudoon  dar  4.5
# 80           Mamudoon  dar    5
# 81        Die for Me!  dar    9
# 82        Foul Breath  alm    2
# 83         Life Drain  alm    3
# 84       Stagnant Air  alm    3
# 85       Spirit Drain  alm    4
# 86             Megido  alm  6.5
# 87           Megidola  alm  7.5
# 88         Megidolaon  alm    8
# 89        Black Viper  alm    9
# 90       Morning Star  alm    9
# 91         Armageddon  alm   99
# 92      Jack Brothers  alm   99
# 93         Last Judge  alm   99
# 94        Raktapaksha  alm   99
# 95           Bewilder  ail  1.5
# 96             Poisma  ail  1.5
# 97        Eerie Sound  ail    2
# 98        Marin Karin  ail  2.5
# 99            Provoke  ail  2.5
# 100           Pulinpa  ail  2.5
# 101         Infuriate  ail    3
# 102       Poison Mist  ail    3
# 103        Sexy Dance  ail    3
# 104        Evil Touch  ail  3.5
# 105        Evil Smile  ail    4
# 106        Tentarafoo  ail    4
# 107      Virus Breath  ail    5
# 108      Ghastly Wail  ail    8
# 109         Dreamfest  ail   99
# 110      Summer Dream  ail   99
# 111         Trickster  ail   99
# 112             Patra  rec  1.5
# 113           Charmdi  rec    2
# 114            Enradi  rec    2
# 115          Posumudi  rec    2
# 116          Re Patra  rec    2
# 117               Dia  rec  2.5
# 118          Me Patra  rec    3
# 119             Media  rec    3
# 120           Diarama  rec  3.5
# 121            Recarm  rec    4
# 122         Mediarama  rec    5
# 123        Samarecarm  rec    5
# 124          Diarahan  rec  5.5
# 125            Amrita  rec    6
# 126        Mediarahan  rec    7
# 127         Salvation  rec    9
# 128           Cadenza  rec   99
# 129            Frolic  rec   99
# 130          Rakukaja  sup    2
# 131           Rakunda  sup    2
# 132         Rebellion  sup    2
# 133          Sukukaja  sup  2.5
# 134           Sukunda  sup  2.5
# 135          Tarukaja  sup  2.5
# 136           Tarunda  sup  2.5
# 137           Dekunda  sup    3
# 138        Revolution  sup    3
# 139        Elec Break  sup    4
# 140        Fire Break  sup    4
# 141         Ice Break  sup    4
# 142         Marakunda  sup    4
# 143         Masukunda  sup    4
# 144         Matarunda  sup    4
# 145      Power Charge  sup    4
# 146        Wind Break  sup    4
# 147            Dekaja  sup    5
# 148        Marakukaja  sup    5
# 149        Masukukaja  sup    5
# 150        Matarukaja  sup    5
# 151       Mind Charge  sup    5
# 152        Makarakarn  sup    7
# 153         Tetrakarn  sup    7
# 154      Best Friends  sup   99
# 155          Infinity  sup   99
# 156          Valhalla  sup   99
# 157         Recarmdra  spe    7
# 158           Trafuri  spe    8
# 159      Raging Tiger  pas    1
# 160        Elec Boost  pas  2.5
# 161        Fire Boost  pas  2.5
# 162          Growth 1  pas  2.5
# 163         Ice Boost  pas  2.5
# 164        Wind Boost  pas  2.5
# 165       Charm Boost  pas    3
# 166    Distress Boost  pas    3
# 167        Fear Boost  pas    3
# 168       Panic Boost  pas    3
# 169      Poison Boost  pas    3
# 170        Rage Boost  pas    3
# 171     Sharp Student  pas    3
# 172           Counter  pas  3.5
# 173        Dodge Elec  pas  3.5
# 174        Dodge Fire  pas  3.5
# 175         Dodge Ice  pas  3.5
# 176      Dodge Pierce  pas  3.5
# 177       Dodge Slash  pas  3.5
# 178      Dodge Strike  pas  3.5
# 179        Dodge Wind  pas  3.5
# 180          Growth 2  pas  3.5
# 181       Cool Breeze  pas    4
# 182          Elec Amp  pas    4
# 183        Evade Elec  pas    4
# 184        Evade Fire  pas    4
# 185         Evade Ice  pas    4
# 186        Evade Wind  pas    4
# 187      Fast Retreat  pas    4
# 188          Fire Amp  pas    4
# 189          Growth 3  pas    4
# 190        Hama Boost  pas    4
# 191           Ice Amp  pas    4
# 192        Mudo Boost  pas    4
# 193      Survive Dark  pas    4
# 194     Survive Light  pas    4
# 195          Wind Amp  pas    4
# 196     Counterstrike  pas  4.5
# 197      Invigorate 1  pas  4.5
# 198      Regenerate 1  pas  4.5
# 199       Resist Dark  pas  4.5
# 200       Resist Elec  pas  4.5
# 201       Resist Fire  pas  4.5
# 202        Resist Ice  pas  4.5
# 203      Resist Light  pas  4.5
# 204       Resist Wind  pas  4.5
# 205         Alertness  pas    5
# 206         Apt Pupil  pas    5
# 207       Endure Dark  pas    5
# 208      Endure Light  pas    5
# 209      Evade Pierce  pas    5
# 210       Evade Slash  pas    5
# 211      Evade Strike  pas    5
# 212      High Counter  pas    5
# 213        Null Charm  pas    5
# 214     Null Distress  pas    5
# 215         Null Fear  pas    5
# 216       Null Freeze  pas    5
# 217        Null Panic  pas    5
# 218       Null Poison  pas    5
# 219         Null Rage  pas    5
# 220        Null Shock  pas    5
# 221    Spring of Life  pas    5
# 222      Invigorate 2  pas  5.5
# 223         Null Dark  pas  5.5
# 224         Null Elec  pas  5.5
# 225         Null Fire  pas  5.5
# 226          Null Ice  pas  5.5
# 227        Null Light  pas  5.5
# 228         Null Wind  pas  5.5
# 229      Regenerate 2  pas  5.5
# 230     Resist Pierce  pas  5.5
# 231      Resist Slash  pas  5.5
# 232     Resist Strike  pas  5.5
# 233      1hSwd Master  pas    6
# 234      2hSwd Master  pas    6
# 235       Auto-Maraku  pas    6
# 236       Auto-Masuku  pas    6
# 237       Auto-Mataru  pas    6
# 238     Auto-Rakukaja  pas    6
# 239     Auto-Sukukaja  pas    6
# 240     Auto-Tarukaja  pas    6
# 241        Bow Master  pas    6
# 242            Endure  pas    6
# 243       Fist Master  pas    6
# 244      Heavy Master  pas    6
# 245      Invigorate 3  pas    6
# 246      Regenerate 3  pas    6
# 247        Repel Dark  pas    6
# 248       Repel Light  pas    6
# 249      Spear Master  pas    6
# 250       Null Pierce  pas  6.5
# 251        Null Slash  pas  6.5
# 252       Null Strike  pas  6.5
# 253        Repel Elec  pas  6.5
# 254        Repel Fire  pas  6.5
# 255         Repel Ice  pas  6.5
# 256        Repel Wind  pas  6.5
# 257       Absorb Elec  pas    7
# 258       Absorb Fire  pas    7
# 259        Absorb Ice  pas    7
# 260       Absorb Wind  pas    7
# 261     Ailment Boost  pas    7
# 262      Divine Grace  pas    7
# 263      Repel Pierce  pas  7.5
# 264       Repel Slash  pas  7.5
# 265      Repel Strike  pas  7.5
# 266     Absorb Pierce  pas    8
# 267      Absorb Slash  pas    8
# 268     Absorb Strike  pas    8
# 269       Arms Master  pas    9
# 270     Enduring Soul  pas    9
# 271      Spell Master  pas    9
# 272     Unshaken Will  pas    9
# 273       Victory Cry  pas    9
# 274      Escape Route  pas   99
# 275     Full Analysis  pas   99
# 276      Healing Wave  pas   99
# 277            Oracle  pas   99
# 278      Support Scan  pas   99
# 279         Third Eye  pas   99
#
#                                                 learns
# 0       Hermes, Nekomata, Chimera, Archangel, Valkyrie
# 1                             Valkyrie, Gurr, Rakshasa
# 2    Rakshasa, Ares, Take-Mikazuchi, Orthrus, Hanum...
# 3    Oberon, Ares, Titan, Pale Rider, Power, Jikoku...
# 4               Rakshasa, Ghoul, Shiisaa, Flauros, Ose
# 5    Orthrus, Flauros, Taraka, Girimehkala, Okuninushi
# 6    Shiisaa, Palladion, Castor, Hanuman, Taraka, N...
# 7    Hermes, Castor, Hanuman, Narasimha, Yaksini, K...
# 8    Castor, Yaksini, Surt, Kali, Byakko, Chernobog...
# 9                                              Michael
# 10       Siegfried, Raphael, Uriel, Thanatos, Masakado
# 11         Hermes, Thanatos, Susanoo, Atavaka, Lucifer
# 12                                     Ares, Siegfried
# 13                 Hermes, Siegfried, Susanoo, Chi You
# 14            Orpheus, Ara Mitama, Forneus, Zouchouten
# 15                   Hermes, Zouchouten, Ghoul, Legion
# 16                     Jack Frost, Chimera, Polydeuces
# 17   Titan, Yamatano-Orochi, Palladion, Genbu, Nata...
# 18   Hermes, Titan, Vetala, Yamatano-Orochi, Pallad...
# 19              Nata Taishi, Ose, Narasimha, Ubelluris
# 20       Hermes, Koumokuten, Ubelluris, Hecatoncheires
# 21   Palladion, Castor, Quetzalcoatl, Kingu, Dionys...
# 22   Thor, Hecatoncheires, Melchizedek, Arahabaki, ...
# 23   Palladion, Castor, Melchizedek, Sandalphon, Vi...
# 24   Palladion, Castor, Melchizedek, Vishnu, Metatr...
# 25                               Cu Chulainn, Scathach
# 26              Kohryu, Seiten Taisei, Abaddon, Ananta
# 27                                      Inugami, Slime
# 28                        Hermes, Berith, Naga, Mithra
# 29                 Archangel, Principality, High Pixie
# 30                           Eligor, Raja Naga, Vasuki
# 31           Eligor, Nemesis, Koumokuten, Kurama Tengu
# 32              Hermes, Orobas, Raja Naga, Cu Chulainn
# 33                  Nemesis, Cu Chulainn, Kaiwan, Odin
# 34                       Hokuto Seikun, Pazuzu, Hariti
# 35          Pazuzu, Bishamonten, Garuda, Seiten Taisei
# 36   Bishamonten, Scathach, Cybele, Gabriel, Kartik...
# 37                                               Shiva
# 38   Kartikeya, Mara, Saturnus, Beelzebub, Chi You,...
# 39   Hermes, Orpheus, Nekomata, Ara Mitama, Lilim, ...
# 40    Nekomata, Slime, Berith, Pyro Jack, Hua Po, Sati
# 41   Hermes, Pyro Jack, Hua Po, Lamia, Orthrus, Sat...
# 42   Eligor, Cerberus, Incubus, Okuninushi, Ose, Ya...
# 43   Hermes, Cerberus, Rangda, Succubus, Okuninushi...
# 44   Cerberus, Surt, Bishamonten, Hell Biker, Uriel...
# 45                                                Surt
# 46                                      Parvati, Shiva
# 47                                                Mara
# 48   Apsaras, Forneus, Jack Frost, Yomotsu Shikome,...
# 49   Jack Frost, Valkyrie, Penthesilea, High Pixie,...
# 50   Penthesilea, High Pixie, Sarasvati, Genbu, Kin...
# 51   Penthesilea, King Frost, Parvati, Titania, Laksmi
# 52   Penthesilea, Parvati, Laksmi, Loki, Hariti, Ho...
# 53   Penthesilea, Scathach, Yurlungur, Trumpeter, G...
# 54                                               Skadi
# 55                              Jack Frost, King Frost
# 56   Omoikane, Lilim, Inugami, Polydeuces, Zouchout...
# 57   Lilim, Archangel, Polydeuces, Oberon, Naga, Ta...
# 58   Polydeuces, Oberon, Rakshasa, Take-Mikazuchi, ...
# 59   Polydeuces, Raja Naga, Cu Chulainn, Thoth, Dom...
# 60   Polydeuces, Mothman, Nemesis, Dionysus, Thor, ...
# 61   Polydeuces, Byakko, Odin, Lilith, Kartikeya, M...
# 62                                                Odin
# 63                                Take-Mikazuchi, Thor
# 64                Io, Angel, Alp, Nigi Mitama, Fortuna
# 65   Io, Yomotsu Shikome, Nigi Mitama, Fortuna, Nar...
# 66   Io, Empusa, Pale Rider, Kusi Mitama, Orobas, S...
# 67   Io, Seiryu, Clotho, Nandi, Quetzalcoatl, Lache...
# 68   Io, Nandi, Quetzalcoatl, Pazuzu, Atropos, Jata...
# 69   Io, Jatayu, Ganesha, Norn, Scathach, Garuda, S...
# 70                                                Norn
# 71   Angel, Archangel, Unicorn, Principality, Mithr...
# 72          Principality, Power, Virtue, Vasuki, Thoth
# 73   Virtue, Nemesis, Dominion, Throne, Daisoujou, ...
# 74   Quetzalcoatl, Throne, Anubis, Horus, Uriel, Th...
# 75                                           Daisoujou
# 76                                    Angel, Archangel
# 77   Alp, Lilim, Yomotsu Shikome, Ghoul, Titan, Pal...
# 78     Ghoul, Pale Rider, Lamia, Loa, Cerberus, Samael
# 79   Cerberus, Samael, Succubus, Mot, Nebiros, Trum...
# 80   Cerberus, Girimehkala, Mot, Hecatoncheires, Ch...
# 81                                               Alice
# 82                            Inugami, Vetala, Mothman
# 83                                        Loa, Incubus
# 84            Lamia, Incubus, Decarabia, Nebiros, Loki
# 85         Penthesilea, Incubus, Kaiwan, Pazuzu, Alice
# 86          Mothman, Samael, Thoth, Decarabia, Nebiros
# 87   Chernobog, Loki, Lilith, Thanatos, Attis, Cybe...
# 88                   Asura, Metatron, Lucifer, Messiah
# 89                                               Satan
# 90                                               Helel
# 91                                        Satan, Helel
# 92                               Jack Frost, Pyro Jack
# 93                                    Mithra, Metatron
# 94                                        Gurr, Garuda
# 95                        Chimera, Naga, Legion, Lamia
# 96                           Forneus, Inugami, Unicorn
# 97                Slime, Naga, Mithra, Mothman, Taraka
# 98           Alp, Lilim, Penthesilea, Narcissus, Nandi
# 99                  Nekomata, Pyro Jack, Ghoul, Empusa
# 100          Pixie, Jack Frost, Legion, Take-Mikazuchi
# 101                       Yatagarasu, Virtue, Dominion
# 102       Gurr, Lamia, Seiryu, Ose, Pazuzu, Baal Zebul
# 103  Narcissus, Legion, Leanan Sidhe, Succubus, Yak...
# 104                      Yomotsu Shikome, Slime, Alice
# 105     Vetala, Incubus, Castor, Mot, Nebiros, Abaddon
# 106  Penthesilea, Vetala, Ganga, Raja Naga, Kurama ...
# 107  Seiryu, Girimehkala, Kingu, Kaiwan, Barong, Pa...
# 108              Samael, Mot, Nebiros, Thanatos, Attis
# 109                                  Incubus, Succubus
# 110                                    Oberon, Titania
# 111                                      Loki, Susanoo
# 112                  Io, Angel, Archangel, Nigi Mitama
# 113           Io, Angel, Alp, Narcissus, Ganga, Clotho
# 114                            Omoikane, Unicorn, Sati
# 115  Apsaras, Forneus, Nigi Mitama, Queen Mab, Sara...
# 116  Hermes, Nekomata, Jack Frost, Hua Po, Kusi Mitama
# 117  Io, Pixie, Alp, Omoikane, Unicorn, Polydeuces,...
# 118  Io, Omoikane, Power, Sarasvati, Genbu, Leanan ...
# 119  Io, Inugami, Nigi Mitama, Oberon, Principality...
# 120  Io, Polydeuces, Penthesilea, Sati, Yatagarasu,...
# 121  Io, Nigi Mitama, Principality, Queen Mab, Kusi...
# 122  Io, Leanan Sidhe, Nemesis, Saki Mitama, Thoth,...
# 123  Io, Palladion, Nemesis, Hariti, Yurlungur, Koh...
# 124  Io, Polydeuces, Penthesilea, Palladion, Nemesi...
# 125                   Jatayu, Laksmi, Scathach, Garuda
# 126  Io, Nemesis, Throne, Melchizedek, Raphael, Har...
# 127                 Sandalphon, Vishnu, Helel, Messiah
# 128                                   Orpheus, Apsaras
# 129                                   Pixie, Narcissus
# 130  Hermes, Ara Mitama, Lilim, Fortuna, Naga, High...
# 131  Pixie, Ara Mitama, Chimera, Polydeuces, Ares, ...
# 132     Berith, Ares, Legion, Titan, Vetala, Oumitsunu
# 133  Angel, Ara Mitama, Archangel, Palladion, Yatag...
# 134     Apsaras, Alp, Polydeuces, Pyro Jack, Jikokuten
# 135  Forneus, Berith, Zouchouten, Palladion, Virtue...
# 136  Orpheus, Yomotsu Shikome, Polydeuces, Empusa, Loa
# 137  Narcissus, Palladion, Genbu, Samael, Saki Mita...
# 138           Power, Jikokuten, Eligor, Kali, Nidhoggr
# 139              Take-Mikazuchi, Hokuto Seikun, Lilith
# 140  Hermes, Mothman, Cerberus, Incubus, Succubus, ...
# 141         Penthesilea, King Frost, Laksmi, Trumpeter
# 142  Polydeuces, Black Frost, Girimehkala, Kali, Al...
# 143       Polydeuces, Yatagarasu, Samael, Kurama Tengu
# 144    Polydeuces, Seiryu, Rangda, Decarabia, Nidhoggr
# 145  Castor, Cu Chulainn, Narasimha, Ganesha, Siegf...
# 146                                Io, Mothman, Orobas
# 147  Ghoul, Take-Minakata, Vetala, Yamatano-Orochi,...
# 148  Hermes, Palladion, Nandi, Quetzalcoatl, Parvat...
# 149  Palladion, Cerberus, Nata Taishi, Lachesis, Su...
# 150  Palladion, Black Frost, Raja Naga, Cu Chulainn...
# 151  Penthesilea, Dionysus, Titania, Atropos, Vishn...
# 152  Anubis, Lilith, Kohryu, Sandalphon, Beelzebub,...
# 153  Arahabaki, Trumpeter, Suparna, Susanoo, Mara, ...
# 154                                 Forneus, Decarabia
# 155                                     Ananta, Vishnu
# 156                                     Valkyrie, Odin
# 157   Vasuki, Ubelluris, Throne, Hecatoncheires, Attis
# 158       Pixie, High Pixie, Sati, Black Frost, Orobas
# 159                      Slime, Gurr, Lamia, Ubelluris
# 160  Polydeuces, Take-Mikazuchi, Hokuto Seikun, Byakko
# 161        Hua Po, Orthrus, Cerberus, Okuninushi, Surt
# 162             Gurr, Empusa, King Frost, Kurama Tengu
# 163  Jack Frost, Penthesilea, Yamatano-Orochi, Shii...
# 164  Fortuna, Kusi Mitama, Orobas, Clotho, Quetzalc...
# 165                   Narcissus, Leanan Sidhe, Yaksini
# 166                                             Taraka
# 167                                       Loa, Nebiros
# 168                           Legion, Ganga, Raja Naga
# 169                                      Inugami, Gurr
# 170                                  Pyro Jack, Virtue
# 171  Ara Mitama, Archangel, Zouchouten, Flauros, Or...
# 172  Hermes, Rakshasa, Ares, Mithra, Pale Rider, Or...
# 173                     Principality, Mithra, Lachesis
# 174                Shiisaa, King Frost, Nandi, Parvati
# 175                            Orthrus, Eligor, Rangda
# 176                Unicorn, Naga, Queen Mab, Oumitsunu
# 177           Valkyrie, Rakshasa, Titan, Hokuto Seikun
# 178                     Gurr, Take-Minakata, Queen Mab
# 179                         Fortuna, Queen Mab, Vasuki
# 180      Yatagarasu, Thoth, Quetzalcoatl, Kurama Tengu
# 181                    Eligor, Nandi, Ose, Kikuri-Hime
# 182                             Polydeuces, Thor, Odin
# 183                                           Lachesis
# 184                                              Kingu
# 185                                Decarabia, Saturnus
# 186                                 Flauros, Narasimha
# 187                     Lilith, Seiten Taisei, Susanoo
# 188  Cerberus, Surt, Kikuri-Hime, Kumbhanda, Bisham...
# 189  Suzaku, Daisoujou, Jatayu, Horus, Yurlungur, S...
# 190  Nemesis, Dominion, Throne, Daisoujou, Gabriel,...
# 191             Penthesilea, Titania, Yurlungur, Skadi
# 192         Loa, Mot, Alice, Baal Zebul, Mother Harlot
# 193             Oberon, Jikokuten, Virtue, Cu Chulainn
# 194  Slime, Take-Minakata, Pale Rider, Loa, Girimeh...
# 195                    Atropos, Ganesha, Norn, Suparna
# 196  Hermes, Cerberus, Castor, Nata Taishi, Vasuki,...
# 197                            Yatagarasu, Kikuri-Hime
# 198                    Castor, Nata Taishi, Koumokuten
# 199                                   Dominion, Throne
# 200                              Kurama Tengu, Atropos
# 201                                             Laksmi
# 202                     Decarabia, Suzaku, Kikuri-Hime
# 203                                        Vasuki, Mot
# 204                                           Dionysus
# 205                      Kumbhanda, Ganesha, Arahabaki
# 206  Okuninushi, Hokuto Seikun, Kali, Loki, Seiten ...
# 207   Jikokuten, Virtue, Nata Taishi, Dominion, Barong
# 208                        Girimehkala, Hecatoncheires
# 209                                             Kaiwan
# 210                                 Jikokuten, Hanuman
# 211                          Ubelluris, Hecatoncheires
# 212  Hermes, Cerberus, Castor, Thor, Kali, Ganesha,...
# 213                    Saki Mitama, Kumbhanda, Raphael
# 214                                  Clotho, Ubelluris
# 215                                                Mot
# 216                                             Hua Po
# 217                                  Raja Naga, Jatayu
# 218                                      Kingu, Barong
# 219                                          Oumitsunu
# 220                                      Hokuto Seikun
# 221                                             Hermes
# 222                          Kaiwan, Barong, Chernobog
# 223                                  Daisoujou, Laksmi
# 224                                     Jatayu, Anubis
# 225                                Loki, Mother Harlot
# 226                                       Anubis, Seth
# 227                                   Succubus, Kaiwan
# 228                                          Chernobog
# 229                        Castor, Dionysus, Kumbhanda
# 230                                          Oumitsunu
# 231                                            Hanuman
# 232                                              Genbu
# 233                                           Thanatos
# 234                                          Siegfried
# 235                 Barong, Arahabaki, Raphael, Cybele
# 236                Kumbhanda, Siegfried, Hariti, Horus
# 237                        Thor, Melchizedek, Metatron
# 238  Omoikane, Unicorn, Take-Minakata, Yamatano-Oro...
# 239  Forneus, Valkyrie, Zouchouten, Jikokuten, Flauros
# 240  Chimera, Yomotsu Shikome, Berith, Gurr, Take-M...
# 241                                             Cybele
# 242                 Kingu, Byakko, Ganesha, Hell Biker
# 243                            Polydeuces, Melchizedek
# 244                                               Thor
# 245  Norn, Scathach, Kohryu, Satan, Shiva, Chi You,...
# 246  Anubis, Norn, Seiten Taisei, Sandalphon, Susan...
# 247        Alice, Melchizedek, Horus, Gabriel, Michael
# 248                      Yurlungur, Seth, Attis, Satan
# 249                             Nemesis, Seiten Taisei
# 250                                    Kohryu, Abaddon
# 251                                 Chernobog, Abaddon
# 252                         Arahabaki, Kohryu, Abaddon
# 253                                           Metatron
# 254                                     Loki, Metatron
# 255                      Arahabaki, Saturnus, Metatron
# 256                                             Garuda
# 257                                    Norn, Kartikeya
# 258                                  Hell Biker, Skadi
# 259                                     Mara, Saturnus
# 260                                     Lilith, Ananta
# 261                    Succubus, Kaiwan, Mother Harlot
# 262                               Saki Mitama, Titania
# 263                                             Alilat
# 264                                             Alilat
# 265                                    Susanoo, Alilat
# 266                                  Nidhoggr, Messiah
# 267                                              Helel
# 268                                   Abaddon, Chi You
# 269          Siegfried, Bishamonten, Masakado, Chi You
# 270                              Attis, Shiva, Messiah
# 271                       Odin, Cybele, Asura, Lucifer
# 272                                              Asura
# 273           Beelzebub, Shiva, Lucifer, Orpheus Telos
# 274                                              Lucia
# 275                                              Lucia
# 276                                              Lucia
# 277                                              Lucia
# 278                                              Lucia
# 279                                              Lucia

# %%
# Find the skill "Panta Rhei"
panta_rhei = df.loc[df['skill'] == 'Panta Rhei']

# Print the result
print(panta_rhei)
# Out:
#          skill type rank learns
# 70  Panta Rhei  win    9   Norn

# %%
conversion_of_types = {'sla': 'Slash',
 'str': 'Strike',
 'pie': 'Pierce',
 'fir': 'Fire',
 'ice': 'Ice',
 'ele': 'Elec',
 'win': 'Wind',
 'lig': 'Light',
 'dar': 'Dark',
 'rec': 'Recovery',
 'sup': 'Enhance',
 'ail': 'Bad Status',
 'spe': 'Special',
 'alm': 'Almighty',
 'pas': 'Passive'}

# update each row of the dataframe. the update is to change the value in the 'type' column to the value in the 'conversion_of_types' dictionary
for index, row in df.iterrows():
    df.loc[index, 'type'] = conversion_of_types[row['type']]

# Print the DataFrame
print(df)
# Out:
#                 skill        type rank  \
# 0              Cleave       Slash  1.5
# 1         Power Slash       Slash    2
# 2            Getsu-ei       Slash    3
# 3              Zan-ei       Slash    3
# 4          Gale Slash       Slash    3
# 5        Mighty Swing       Slash    4
# 6           Fatal End       Slash  4.5
# 7       Blade of Fury       Slash  5.5
# 8          Deathbound       Slash  6.5
# 9      Heaven's Blade       Slash    7
# 10      Tempest Slash       Slash    7
# 11        Brave Blade       Slash    8
# 12      Scarlet Havoc       Slash   99
# 13       Vorpal Blade       Slash   99
# 14               Bash      Strike  1.5
# 15       Assault Dive      Strike  2.5
# 16        Sonic Punch      Strike  2.5
# 17       Swift Strike      Strike    3
# 18          Kill Rush      Strike  3.5
# 19   Herculean Strike      Strike    4
# 20      Gigantic Fist      Strike  5.5
# 21          Heat Wave      Strike  5.5
# 22     Vicious Strike      Strike    6
# 23        Akasha Arts      Strike    7
# 24         God's Hand      Strike    8
# 25       Shadow Hound      Strike   99
# 26       Weary Thrust      Strike   99
# 27        Single Shot      Pierce  1.5
# 28       Double Fangs      Pierce    2
# 29         Holy Arrow      Pierce  2.5
# 30          Twin Shot      Pierce  3.5
# 31       Cruel Attack      Pierce    4
# 32       Torrent Shot      Pierce  4.5
# 33       Vile Assault      Pierce    5
# 34       Poison Arrow      Pierce    5
# 35         Arrow Rain      Pierce  6.5
# 36      Myriad Arrows      Pierce    7
# 37            Pralaya      Pierce    8
# 38       Primal Force      Pierce    8
# 39                Agi        Fire  1.5
# 40             Maragi        Fire    2
# 41             Agilao        Fire  3.5
# 42           Maragion        Fire    4
# 43            Agidyne        Fire  5.5
# 44         Maragidyne        Fire    6
# 45           Ragnarok        Fire    9
# 46          Ardhanari        Fire   99
# 47       Maralagidyne        Fire   99
# 48               Bufu         Ice  1.5
# 49             Mabufu         Ice    2
# 50             Bufula         Ice  3.5
# 51           Mabufula         Ice    4
# 52           Bufudyne         Ice  5.5
# 53         Mabufudyne         Ice    6
# 54           Niflheim         Ice    9
# 55         King and I         Ice   99
# 56                Zio        Elec  1.5
# 57              Mazio        Elec    2
# 58             Zionga        Elec  3.5
# 59           Mazionga        Elec    4
# 60            Ziodyne        Elec  5.5
# 61          Maziodyne        Elec    6
# 62      Thunder Reign        Elec    9
# 63       Thunder Call        Elec   99
# 64               Garu        Wind  1.5
# 65             Magaru        Wind    2
# 66             Garula        Wind  3.5
# 67           Magarula        Wind    4
# 68           Garudyne        Wind  5.5
# 69         Magarudyne        Wind    6
# 70         Panta Rhei        Wind    9
# 71               Hama       Light  2.5
# 72             Mahama       Light    3
# 73             Hamaon       Light  4.5
# 74           Mahamaon       Light    5
# 75            Samsara       Light    9
# 76            Justice       Light   99
# 77               Mudo        Dark  2.5
# 78             Mamudo        Dark    3
# 79             Mudoon        Dark  4.5
# 80           Mamudoon        Dark    5
# 81        Die for Me!        Dark    9
# 82        Foul Breath    Almighty    2
# 83         Life Drain    Almighty    3
# 84       Stagnant Air    Almighty    3
# 85       Spirit Drain    Almighty    4
# 86             Megido    Almighty  6.5
# 87           Megidola    Almighty  7.5
# 88         Megidolaon    Almighty    8
# 89        Black Viper    Almighty    9
# 90       Morning Star    Almighty    9
# 91         Armageddon    Almighty   99
# 92      Jack Brothers    Almighty   99
# 93         Last Judge    Almighty   99
# 94        Raktapaksha    Almighty   99
# 95           Bewilder  Bad Status  1.5
# 96             Poisma  Bad Status  1.5
# 97        Eerie Sound  Bad Status    2
# 98        Marin Karin  Bad Status  2.5
# 99            Provoke  Bad Status  2.5
# 100           Pulinpa  Bad Status  2.5
# 101         Infuriate  Bad Status    3
# 102       Poison Mist  Bad Status    3
# 103        Sexy Dance  Bad Status    3
# 104        Evil Touch  Bad Status  3.5
# 105        Evil Smile  Bad Status    4
# 106        Tentarafoo  Bad Status    4
# 107      Virus Breath  Bad Status    5
# 108      Ghastly Wail  Bad Status    8
# 109         Dreamfest  Bad Status   99
# 110      Summer Dream  Bad Status   99
# 111         Trickster  Bad Status   99
# 112             Patra    Recovery  1.5
# 113           Charmdi    Recovery    2
# 114            Enradi    Recovery    2
# 115          Posumudi    Recovery    2
# 116          Re Patra    Recovery    2
# 117               Dia    Recovery  2.5
# 118          Me Patra    Recovery    3
# 119             Media    Recovery    3
# 120           Diarama    Recovery  3.5
# 121            Recarm    Recovery    4
# 122         Mediarama    Recovery    5
# 123        Samarecarm    Recovery    5
# 124          Diarahan    Recovery  5.5
# 125            Amrita    Recovery    6
# 126        Mediarahan    Recovery    7
# 127         Salvation    Recovery    9
# 128           Cadenza    Recovery   99
# 129            Frolic    Recovery   99
# 130          Rakukaja     Enhance    2
# 131           Rakunda     Enhance    2
# 132         Rebellion     Enhance    2
# 133          Sukukaja     Enhance  2.5
# 134           Sukunda     Enhance  2.5
# 135          Tarukaja     Enhance  2.5
# 136           Tarunda     Enhance  2.5
# 137           Dekunda     Enhance    3
# 138        Revolution     Enhance    3
# 139        Elec Break     Enhance    4
# 140        Fire Break     Enhance    4
# 141         Ice Break     Enhance    4
# 142         Marakunda     Enhance    4
# 143         Masukunda     Enhance    4
# 144         Matarunda     Enhance    4
# 145      Power Charge     Enhance    4
# 146        Wind Break     Enhance    4
# 147            Dekaja     Enhance    5
# 148        Marakukaja     Enhance    5
# 149        Masukukaja     Enhance    5
# 150        Matarukaja     Enhance    5
# 151       Mind Charge     Enhance    5
# 152        Makarakarn     Enhance    7
# 153         Tetrakarn     Enhance    7
# 154      Best Friends     Enhance   99
# 155          Infinity     Enhance   99
# 156          Valhalla     Enhance   99
# 157         Recarmdra     Special    7
# 158           Trafuri     Special    8
# 159      Raging Tiger     Passive    1
# 160        Elec Boost     Passive  2.5
# 161        Fire Boost     Passive  2.5
# 162          Growth 1     Passive  2.5
# 163         Ice Boost     Passive  2.5
# 164        Wind Boost     Passive  2.5
# 165       Charm Boost     Passive    3
# 166    Distress Boost     Passive    3
# 167        Fear Boost     Passive    3
# 168       Panic Boost     Passive    3
# 169      Poison Boost     Passive    3
# 170        Rage Boost     Passive    3
# 171     Sharp Student     Passive    3
# 172           Counter     Passive  3.5
# 173        Dodge Elec     Passive  3.5
# 174        Dodge Fire     Passive  3.5
# 175         Dodge Ice     Passive  3.5
# 176      Dodge Pierce     Passive  3.5
# 177       Dodge Slash     Passive  3.5
# 178      Dodge Strike     Passive  3.5
# 179        Dodge Wind     Passive  3.5
# 180          Growth 2     Passive  3.5
# 181       Cool Breeze     Passive    4
# 182          Elec Amp     Passive    4
# 183        Evade Elec     Passive    4
# 184        Evade Fire     Passive    4
# 185         Evade Ice     Passive    4
# 186        Evade Wind     Passive    4
# 187      Fast Retreat     Passive    4
# 188          Fire Amp     Passive    4
# 189          Growth 3     Passive    4
# 190        Hama Boost     Passive    4
# 191           Ice Amp     Passive    4
# 192        Mudo Boost     Passive    4
# 193      Survive Dark     Passive    4
# 194     Survive Light     Passive    4
# 195          Wind Amp     Passive    4
# 196     Counterstrike     Passive  4.5
# 197      Invigorate 1     Passive  4.5
# 198      Regenerate 1     Passive  4.5
# 199       Resist Dark     Passive  4.5
# 200       Resist Elec     Passive  4.5
# 201       Resist Fire     Passive  4.5
# 202        Resist Ice     Passive  4.5
# 203      Resist Light     Passive  4.5
# 204       Resist Wind     Passive  4.5
# 205         Alertness     Passive    5
# 206         Apt Pupil     Passive    5
# 207       Endure Dark     Passive    5
# 208      Endure Light     Passive    5
# 209      Evade Pierce     Passive    5
# 210       Evade Slash     Passive    5
# 211      Evade Strike     Passive    5
# 212      High Counter     Passive    5
# 213        Null Charm     Passive    5
# 214     Null Distress     Passive    5
# 215         Null Fear     Passive    5
# 216       Null Freeze     Passive    5
# 217        Null Panic     Passive    5
# 218       Null Poison     Passive    5
# 219         Null Rage     Passive    5
# 220        Null Shock     Passive    5
# 221    Spring of Life     Passive    5
# 222      Invigorate 2     Passive  5.5
# 223         Null Dark     Passive  5.5
# 224         Null Elec     Passive  5.5
# 225         Null Fire     Passive  5.5
# 226          Null Ice     Passive  5.5
# 227        Null Light     Passive  5.5
# 228         Null Wind     Passive  5.5
# 229      Regenerate 2     Passive  5.5
# 230     Resist Pierce     Passive  5.5
# 231      Resist Slash     Passive  5.5
# 232     Resist Strike     Passive  5.5
# 233      1hSwd Master     Passive    6
# 234      2hSwd Master     Passive    6
# 235       Auto-Maraku     Passive    6
# 236       Auto-Masuku     Passive    6
# 237       Auto-Mataru     Passive    6
# 238     Auto-Rakukaja     Passive    6
# 239     Auto-Sukukaja     Passive    6
# 240     Auto-Tarukaja     Passive    6
# 241        Bow Master     Passive    6
# 242            Endure     Passive    6
# 243       Fist Master     Passive    6
# 244      Heavy Master     Passive    6
# 245      Invigorate 3     Passive    6
# 246      Regenerate 3     Passive    6
# 247        Repel Dark     Passive    6
# 248       Repel Light     Passive    6
# 249      Spear Master     Passive    6
# 250       Null Pierce     Passive  6.5
# 251        Null Slash     Passive  6.5
# 252       Null Strike     Passive  6.5
# 253        Repel Elec     Passive  6.5
# 254        Repel Fire     Passive  6.5
# 255         Repel Ice     Passive  6.5
# 256        Repel Wind     Passive  6.5
# 257       Absorb Elec     Passive    7
# 258       Absorb Fire     Passive    7
# 259        Absorb Ice     Passive    7
# 260       Absorb Wind     Passive    7
# 261     Ailment Boost     Passive    7
# 262      Divine Grace     Passive    7
# 263      Repel Pierce     Passive  7.5
# 264       Repel Slash     Passive  7.5
# 265      Repel Strike     Passive  7.5
# 266     Absorb Pierce     Passive    8
# 267      Absorb Slash     Passive    8
# 268     Absorb Strike     Passive    8
# 269       Arms Master     Passive    9
# 270     Enduring Soul     Passive    9
# 271      Spell Master     Passive    9
# 272     Unshaken Will     Passive    9
# 273       Victory Cry     Passive    9
# 274      Escape Route     Passive   99
# 275     Full Analysis     Passive   99
# 276      Healing Wave     Passive   99
# 277            Oracle     Passive   99
# 278      Support Scan     Passive   99
# 279         Third Eye     Passive   99
#
#                                                 learns
# 0       Hermes, Nekomata, Chimera, Archangel, Valkyrie
# 1                             Valkyrie, Gurr, Rakshasa
# 2    Rakshasa, Ares, Take-Mikazuchi, Orthrus, Hanum...
# 3    Oberon, Ares, Titan, Pale Rider, Power, Jikoku...
# 4               Rakshasa, Ghoul, Shiisaa, Flauros, Ose
# 5    Orthrus, Flauros, Taraka, Girimehkala, Okuninushi
# 6    Shiisaa, Palladion, Castor, Hanuman, Taraka, N...
# 7    Hermes, Castor, Hanuman, Narasimha, Yaksini, K...
# 8    Castor, Yaksini, Surt, Kali, Byakko, Chernobog...
# 9                                              Michael
# 10       Siegfried, Raphael, Uriel, Thanatos, Masakado
# 11         Hermes, Thanatos, Susanoo, Atavaka, Lucifer
# 12                                     Ares, Siegfried
# 13                 Hermes, Siegfried, Susanoo, Chi You
# 14            Orpheus, Ara Mitama, Forneus, Zouchouten
# 15                   Hermes, Zouchouten, Ghoul, Legion
# 16                     Jack Frost, Chimera, Polydeuces
# 17   Titan, Yamatano-Orochi, Palladion, Genbu, Nata...
# 18   Hermes, Titan, Vetala, Yamatano-Orochi, Pallad...
# 19              Nata Taishi, Ose, Narasimha, Ubelluris
# 20       Hermes, Koumokuten, Ubelluris, Hecatoncheires
# 21   Palladion, Castor, Quetzalcoatl, Kingu, Dionys...
# 22   Thor, Hecatoncheires, Melchizedek, Arahabaki, ...
# 23   Palladion, Castor, Melchizedek, Sandalphon, Vi...
# 24   Palladion, Castor, Melchizedek, Vishnu, Metatr...
# 25                               Cu Chulainn, Scathach
# 26              Kohryu, Seiten Taisei, Abaddon, Ananta
# 27                                      Inugami, Slime
# 28                        Hermes, Berith, Naga, Mithra
# 29                 Archangel, Principality, High Pixie
# 30                           Eligor, Raja Naga, Vasuki
# 31           Eligor, Nemesis, Koumokuten, Kurama Tengu
# 32              Hermes, Orobas, Raja Naga, Cu Chulainn
# 33                  Nemesis, Cu Chulainn, Kaiwan, Odin
# 34                       Hokuto Seikun, Pazuzu, Hariti
# 35          Pazuzu, Bishamonten, Garuda, Seiten Taisei
# 36   Bishamonten, Scathach, Cybele, Gabriel, Kartik...
# 37                                               Shiva
# 38   Kartikeya, Mara, Saturnus, Beelzebub, Chi You,...
# 39   Hermes, Orpheus, Nekomata, Ara Mitama, Lilim, ...
# 40    Nekomata, Slime, Berith, Pyro Jack, Hua Po, Sati
# 41   Hermes, Pyro Jack, Hua Po, Lamia, Orthrus, Sat...
# 42   Eligor, Cerberus, Incubus, Okuninushi, Ose, Ya...
# 43   Hermes, Cerberus, Rangda, Succubus, Okuninushi...
# 44   Cerberus, Surt, Bishamonten, Hell Biker, Uriel...
# 45                                                Surt
# 46                                      Parvati, Shiva
# 47                                                Mara
# 48   Apsaras, Forneus, Jack Frost, Yomotsu Shikome,...
# 49   Jack Frost, Valkyrie, Penthesilea, High Pixie,...
# 50   Penthesilea, High Pixie, Sarasvati, Genbu, Kin...
# 51   Penthesilea, King Frost, Parvati, Titania, Laksmi
# 52   Penthesilea, Parvati, Laksmi, Loki, Hariti, Ho...
# 53   Penthesilea, Scathach, Yurlungur, Trumpeter, G...
# 54                                               Skadi
# 55                              Jack Frost, King Frost
# 56   Omoikane, Lilim, Inugami, Polydeuces, Zouchout...
# 57   Lilim, Archangel, Polydeuces, Oberon, Naga, Ta...
# 58   Polydeuces, Oberon, Rakshasa, Take-Mikazuchi, ...
# 59   Polydeuces, Raja Naga, Cu Chulainn, Thoth, Dom...
# 60   Polydeuces, Mothman, Nemesis, Dionysus, Thor, ...
# 61   Polydeuces, Byakko, Odin, Lilith, Kartikeya, M...
# 62                                                Odin
# 63                                Take-Mikazuchi, Thor
# 64                Io, Angel, Alp, Nigi Mitama, Fortuna
# 65   Io, Yomotsu Shikome, Nigi Mitama, Fortuna, Nar...
# 66   Io, Empusa, Pale Rider, Kusi Mitama, Orobas, S...
# 67   Io, Seiryu, Clotho, Nandi, Quetzalcoatl, Lache...
# 68   Io, Nandi, Quetzalcoatl, Pazuzu, Atropos, Jata...
# 69   Io, Jatayu, Ganesha, Norn, Scathach, Garuda, S...
# 70                                                Norn
# 71   Angel, Archangel, Unicorn, Principality, Mithr...
# 72          Principality, Power, Virtue, Vasuki, Thoth
# 73   Virtue, Nemesis, Dominion, Throne, Daisoujou, ...
# 74   Quetzalcoatl, Throne, Anubis, Horus, Uriel, Th...
# 75                                           Daisoujou
# 76                                    Angel, Archangel
# 77   Alp, Lilim, Yomotsu Shikome, Ghoul, Titan, Pal...
# 78     Ghoul, Pale Rider, Lamia, Loa, Cerberus, Samael
# 79   Cerberus, Samael, Succubus, Mot, Nebiros, Trum...
# 80   Cerberus, Girimehkala, Mot, Hecatoncheires, Ch...
# 81                                               Alice
# 82                            Inugami, Vetala, Mothman
# 83                                        Loa, Incubus
# 84            Lamia, Incubus, Decarabia, Nebiros, Loki
# 85         Penthesilea, Incubus, Kaiwan, Pazuzu, Alice
# 86          Mothman, Samael, Thoth, Decarabia, Nebiros
# 87   Chernobog, Loki, Lilith, Thanatos, Attis, Cybe...
# 88                   Asura, Metatron, Lucifer, Messiah
# 89                                               Satan
# 90                                               Helel
# 91                                        Satan, Helel
# 92                               Jack Frost, Pyro Jack
# 93                                    Mithra, Metatron
# 94                                        Gurr, Garuda
# 95                        Chimera, Naga, Legion, Lamia
# 96                           Forneus, Inugami, Unicorn
# 97                Slime, Naga, Mithra, Mothman, Taraka
# 98           Alp, Lilim, Penthesilea, Narcissus, Nandi
# 99                  Nekomata, Pyro Jack, Ghoul, Empusa
# 100          Pixie, Jack Frost, Legion, Take-Mikazuchi
# 101                       Yatagarasu, Virtue, Dominion
# 102       Gurr, Lamia, Seiryu, Ose, Pazuzu, Baal Zebul
# 103  Narcissus, Legion, Leanan Sidhe, Succubus, Yak...
# 104                      Yomotsu Shikome, Slime, Alice
# 105     Vetala, Incubus, Castor, Mot, Nebiros, Abaddon
# 106  Penthesilea, Vetala, Ganga, Raja Naga, Kurama ...
# 107  Seiryu, Girimehkala, Kingu, Kaiwan, Barong, Pa...
# 108              Samael, Mot, Nebiros, Thanatos, Attis
# 109                                  Incubus, Succubus
# 110                                    Oberon, Titania
# 111                                      Loki, Susanoo
# 112                  Io, Angel, Archangel, Nigi Mitama
# 113           Io, Angel, Alp, Narcissus, Ganga, Clotho
# 114                            Omoikane, Unicorn, Sati
# 115  Apsaras, Forneus, Nigi Mitama, Queen Mab, Sara...
# 116  Hermes, Nekomata, Jack Frost, Hua Po, Kusi Mitama
# 117  Io, Pixie, Alp, Omoikane, Unicorn, Polydeuces,...
# 118  Io, Omoikane, Power, Sarasvati, Genbu, Leanan ...
# 119  Io, Inugami, Nigi Mitama, Oberon, Principality...
# 120  Io, Polydeuces, Penthesilea, Sati, Yatagarasu,...
# 121  Io, Nigi Mitama, Principality, Queen Mab, Kusi...
# 122  Io, Leanan Sidhe, Nemesis, Saki Mitama, Thoth,...
# 123  Io, Palladion, Nemesis, Hariti, Yurlungur, Koh...
# 124  Io, Polydeuces, Penthesilea, Palladion, Nemesi...
# 125                   Jatayu, Laksmi, Scathach, Garuda
# 126  Io, Nemesis, Throne, Melchizedek, Raphael, Har...
# 127                 Sandalphon, Vishnu, Helel, Messiah
# 128                                   Orpheus, Apsaras
# 129                                   Pixie, Narcissus
# 130  Hermes, Ara Mitama, Lilim, Fortuna, Naga, High...
# 131  Pixie, Ara Mitama, Chimera, Polydeuces, Ares, ...
# 132     Berith, Ares, Legion, Titan, Vetala, Oumitsunu
# 133  Angel, Ara Mitama, Archangel, Palladion, Yatag...
# 134     Apsaras, Alp, Polydeuces, Pyro Jack, Jikokuten
# 135  Forneus, Berith, Zouchouten, Palladion, Virtue...
# 136  Orpheus, Yomotsu Shikome, Polydeuces, Empusa, Loa
# 137  Narcissus, Palladion, Genbu, Samael, Saki Mita...
# 138           Power, Jikokuten, Eligor, Kali, Nidhoggr
# 139              Take-Mikazuchi, Hokuto Seikun, Lilith
# 140  Hermes, Mothman, Cerberus, Incubus, Succubus, ...
# 141         Penthesilea, King Frost, Laksmi, Trumpeter
# 142  Polydeuces, Black Frost, Girimehkala, Kali, Al...
# 143       Polydeuces, Yatagarasu, Samael, Kurama Tengu
# 144    Polydeuces, Seiryu, Rangda, Decarabia, Nidhoggr
# 145  Castor, Cu Chulainn, Narasimha, Ganesha, Siegf...
# 146                                Io, Mothman, Orobas
# 147  Ghoul, Take-Minakata, Vetala, Yamatano-Orochi,...
# 148  Hermes, Palladion, Nandi, Quetzalcoatl, Parvat...
# 149  Palladion, Cerberus, Nata Taishi, Lachesis, Su...
# 150  Palladion, Black Frost, Raja Naga, Cu Chulainn...
# 151  Penthesilea, Dionysus, Titania, Atropos, Vishn...
# 152  Anubis, Lilith, Kohryu, Sandalphon, Beelzebub,...
# 153  Arahabaki, Trumpeter, Suparna, Susanoo, Mara, ...
# 154                                 Forneus, Decarabia
# 155                                     Ananta, Vishnu
# 156                                     Valkyrie, Odin
# 157   Vasuki, Ubelluris, Throne, Hecatoncheires, Attis
# 158       Pixie, High Pixie, Sati, Black Frost, Orobas
# 159                      Slime, Gurr, Lamia, Ubelluris
# 160  Polydeuces, Take-Mikazuchi, Hokuto Seikun, Byakko
# 161        Hua Po, Orthrus, Cerberus, Okuninushi, Surt
# 162             Gurr, Empusa, King Frost, Kurama Tengu
# 163  Jack Frost, Penthesilea, Yamatano-Orochi, Shii...
# 164  Fortuna, Kusi Mitama, Orobas, Clotho, Quetzalc...
# 165                   Narcissus, Leanan Sidhe, Yaksini
# 166                                             Taraka
# 167                                       Loa, Nebiros
# 168                           Legion, Ganga, Raja Naga
# 169                                      Inugami, Gurr
# 170                                  Pyro Jack, Virtue
# 171  Ara Mitama, Archangel, Zouchouten, Flauros, Or...
# 172  Hermes, Rakshasa, Ares, Mithra, Pale Rider, Or...
# 173                     Principality, Mithra, Lachesis
# 174                Shiisaa, King Frost, Nandi, Parvati
# 175                            Orthrus, Eligor, Rangda
# 176                Unicorn, Naga, Queen Mab, Oumitsunu
# 177           Valkyrie, Rakshasa, Titan, Hokuto Seikun
# 178                     Gurr, Take-Minakata, Queen Mab
# 179                         Fortuna, Queen Mab, Vasuki
# 180      Yatagarasu, Thoth, Quetzalcoatl, Kurama Tengu
# 181                    Eligor, Nandi, Ose, Kikuri-Hime
# 182                             Polydeuces, Thor, Odin
# 183                                           Lachesis
# 184                                              Kingu
# 185                                Decarabia, Saturnus
# 186                                 Flauros, Narasimha
# 187                     Lilith, Seiten Taisei, Susanoo
# 188  Cerberus, Surt, Kikuri-Hime, Kumbhanda, Bisham...
# 189  Suzaku, Daisoujou, Jatayu, Horus, Yurlungur, S...
# 190  Nemesis, Dominion, Throne, Daisoujou, Gabriel,...
# 191             Penthesilea, Titania, Yurlungur, Skadi
# 192         Loa, Mot, Alice, Baal Zebul, Mother Harlot
# 193             Oberon, Jikokuten, Virtue, Cu Chulainn
# 194  Slime, Take-Minakata, Pale Rider, Loa, Girimeh...
# 195                    Atropos, Ganesha, Norn, Suparna
# 196  Hermes, Cerberus, Castor, Nata Taishi, Vasuki,...
# 197                            Yatagarasu, Kikuri-Hime
# 198                    Castor, Nata Taishi, Koumokuten
# 199                                   Dominion, Throne
# 200                              Kurama Tengu, Atropos
# 201                                             Laksmi
# 202                     Decarabia, Suzaku, Kikuri-Hime
# 203                                        Vasuki, Mot
# 204                                           Dionysus
# 205                      Kumbhanda, Ganesha, Arahabaki
# 206  Okuninushi, Hokuto Seikun, Kali, Loki, Seiten ...
# 207   Jikokuten, Virtue, Nata Taishi, Dominion, Barong
# 208                        Girimehkala, Hecatoncheires
# 209                                             Kaiwan
# 210                                 Jikokuten, Hanuman
# 211                          Ubelluris, Hecatoncheires
# 212  Hermes, Cerberus, Castor, Thor, Kali, Ganesha,...
# 213                    Saki Mitama, Kumbhanda, Raphael
# 214                                  Clotho, Ubelluris
# 215                                                Mot
# 216                                             Hua Po
# 217                                  Raja Naga, Jatayu
# 218                                      Kingu, Barong
# 219                                          Oumitsunu
# 220                                      Hokuto Seikun
# 221                                             Hermes
# 222                          Kaiwan, Barong, Chernobog
# 223                                  Daisoujou, Laksmi
# 224                                     Jatayu, Anubis
# 225                                Loki, Mother Harlot
# 226                                       Anubis, Seth
# 227                                   Succubus, Kaiwan
# 228                                          Chernobog
# 229                        Castor, Dionysus, Kumbhanda
# 230                                          Oumitsunu
# 231                                            Hanuman
# 232                                              Genbu
# 233                                           Thanatos
# 234                                          Siegfried
# 235                 Barong, Arahabaki, Raphael, Cybele
# 236                Kumbhanda, Siegfried, Hariti, Horus
# 237                        Thor, Melchizedek, Metatron
# 238  Omoikane, Unicorn, Take-Minakata, Yamatano-Oro...
# 239  Forneus, Valkyrie, Zouchouten, Jikokuten, Flauros
# 240  Chimera, Yomotsu Shikome, Berith, Gurr, Take-M...
# 241                                             Cybele
# 242                 Kingu, Byakko, Ganesha, Hell Biker
# 243                            Polydeuces, Melchizedek
# 244                                               Thor
# 245  Norn, Scathach, Kohryu, Satan, Shiva, Chi You,...
# 246  Anubis, Norn, Seiten Taisei, Sandalphon, Susan...
# 247        Alice, Melchizedek, Horus, Gabriel, Michael
# 248                      Yurlungur, Seth, Attis, Satan
# 249                             Nemesis, Seiten Taisei
# 250                                    Kohryu, Abaddon
# 251                                 Chernobog, Abaddon
# 252                         Arahabaki, Kohryu, Abaddon
# 253                                           Metatron
# 254                                     Loki, Metatron
# 255                      Arahabaki, Saturnus, Metatron
# 256                                             Garuda
# 257                                    Norn, Kartikeya
# 258                                  Hell Biker, Skadi
# 259                                     Mara, Saturnus
# 260                                     Lilith, Ananta
# 261                    Succubus, Kaiwan, Mother Harlot
# 262                               Saki Mitama, Titania
# 263                                             Alilat
# 264                                             Alilat
# 265                                    Susanoo, Alilat
# 266                                  Nidhoggr, Messiah
# 267                                              Helel
# 268                                   Abaddon, Chi You
# 269          Siegfried, Bishamonten, Masakado, Chi You
# 270                              Attis, Shiva, Messiah
# 271                       Odin, Cybele, Asura, Lucifer
# 272                                              Asura
# 273           Beelzebub, Shiva, Lucifer, Orpheus Telos
# 274                                              Lucia
# 275                                              Lucia
# 276                                              Lucia
# 277                                              Lucia
# 278                                              Lucia
# 279                                              Lucia

# %%
df.to_csv('skills.csv', index=False)

# %%
import re
from bs4 import BeautifulSoup
import pandas as pd

# Load the HTML content
with open('skill_list.html', 'r') as f:
    html_content = f.read()

# Parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Find all "tr" elements with class="app-smt-skill-list-row"
rows = soup.find_all('tr', class_='app-smt-skill-list-row')

# Prepare a list to hold the data
data = []

# Loop through each row
for row in rows:
    # Get the skill name
    skill = row.find_all('td')[1].text

    # Initialize an empty list for learners with levels
    learners_with_levels = []
    skip_row = False  # Flag to indicate whether to skip adding the current row to the dataset

    # Iterate through each 'li' element in the row
    for li in row.find_all('li'):
        # Extract the learner's name
        learner_name = li.find('a').text if li.find('a') else None
        
        # Extract the text after the learner's name to check for levels or 'Fs'
        text_after_a = li.get_text(strip=True)[len(learner_name):] if learner_name else ''
        level_match = re.search(r'\((\d+|Fs)\)', text_after_a)

        # Check if 'Fs' or any non-numeric value is found
        if level_match and level_match.group(1) == 'Fs':
            skip_row = True  # Set the flag to skip this row
            break  # No need to continue processing this row
        else:
            level = level_match.group(1) if level_match else None

        # Append the learner name with level if available
        learner_with_level = f"{learner_name} ({level})" if level else learner_name
        learners_with_levels.append(learner_with_level)

    # If the skip_row flag is set, continue to the next row without adding this one to the dataset
    if skip_row:
        continue

    # Add the data to the list
    data.append({'skill': skill, 'learners': ', '.join(learners_with_levels)})

# Create a pandas DataFrame
df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
#                 skill  \
# 0              Cleave
# 1         Power Slash
# 2            Getsu-ei
# 3              Zan-ei
# 4          Gale Slash
# 5        Mighty Swing
# 6           Fatal End
# 7       Blade of Fury
# 8          Deathbound
# 9      Heaven's Blade
# 10      Tempest Slash
# 11        Brave Blade
# 12       Vorpal Blade
# 13               Bash
# 14       Assault Dive
# 15        Sonic Punch
# 16       Swift Strike
# 17          Kill Rush
# 18   Herculean Strike
# 19      Gigantic Fist
# 20          Heat Wave
# 21     Vicious Strike
# 22        Akasha Arts
# 23         God's Hand
# 24       Weary Thrust
# 25        Single Shot
# 26       Double Fangs
# 27         Holy Arrow
# 28          Twin Shot
# 29       Cruel Attack
# 30       Torrent Shot
# 31       Vile Assault
# 32       Poison Arrow
# 33         Arrow Rain
# 34      Myriad Arrows
# 35            Pralaya
# 36       Primal Force
# 37                Agi
# 38             Maragi
# 39             Agilao
# 40           Maragion
# 41            Agidyne
# 42         Maragidyne
# 43           Ragnarok
# 44       Maralagidyne
# 45               Bufu
# 46             Mabufu
# 47             Bufula
# 48           Mabufula
# 49           Bufudyne
# 50         Mabufudyne
# 51           Niflheim
# 52                Zio
# 53              Mazio
# 54             Zionga
# 55           Mazionga
# 56            Ziodyne
# 57          Maziodyne
# 58      Thunder Reign
# 59               Garu
# 60             Magaru
# 61             Garula
# 62           Magarula
# 63           Garudyne
# 64         Magarudyne
# 65         Panta Rhei
# 66               Hama
# 67             Mahama
# 68             Hamaon
# 69           Mahamaon
# 70            Samsara
# 71               Mudo
# 72             Mamudo
# 73             Mudoon
# 74           Mamudoon
# 75        Die for Me!
# 76        Foul Breath
# 77         Life Drain
# 78       Stagnant Air
# 79       Spirit Drain
# 80             Megido
# 81           Megidola
# 82         Megidolaon
# 83        Black Viper
# 84       Morning Star
# 85           Bewilder
# 86             Poisma
# 87        Eerie Sound
# 88        Marin Karin
# 89            Provoke
# 90            Pulinpa
# 91          Infuriate
# 92        Poison Mist
# 93         Sexy Dance
# 94         Evil Touch
# 95         Evil Smile
# 96         Tentarafoo
# 97       Virus Breath
# 98       Ghastly Wail
# 99              Patra
# 100           Charmdi
# 101            Enradi
# 102          Posumudi
# 103          Re Patra
# 104               Dia
# 105          Me Patra
# 106             Media
# 107           Diarama
# 108            Recarm
# 109         Mediarama
# 110        Samarecarm
# 111          Diarahan
# 112            Amrita
# 113        Mediarahan
# 114         Salvation
# 115          Rakukaja
# 116           Rakunda
# 117         Rebellion
# 118          Sukukaja
# 119           Sukunda
# 120          Tarukaja
# 121           Tarunda
# 122           Dekunda
# 123        Revolution
# 124        Elec Break
# 125        Fire Break
# 126         Ice Break
# 127         Marakunda
# 128         Masukunda
# 129         Matarunda
# 130      Power Charge
# 131        Wind Break
# 132            Dekaja
# 133        Marakukaja
# 134        Masukukaja
# 135        Matarukaja
# 136       Mind Charge
# 137        Makarakarn
# 138         Tetrakarn
# 139         Recarmdra
# 140           Trafuri
# 141      Raging Tiger
# 142        Elec Boost
# 143        Fire Boost
# 144          Growth 1
# 145         Ice Boost
# 146        Wind Boost
# 147       Charm Boost
# 148    Distress Boost
# 149        Fear Boost
# 150       Panic Boost
# 151      Poison Boost
# 152        Rage Boost
# 153     Sharp Student
# 154           Counter
# 155        Dodge Elec
# 156        Dodge Fire
# 157         Dodge Ice
# 158      Dodge Pierce
# 159       Dodge Slash
# 160      Dodge Strike
# 161        Dodge Wind
# 162          Growth 2
# 163       Cool Breeze
# 164          Elec Amp
# 165        Evade Elec
# 166        Evade Fire
# 167         Evade Ice
# 168        Evade Wind
# 169      Fast Retreat
# 170          Fire Amp
# 171          Growth 3
# 172        Hama Boost
# 173           Ice Amp
# 174        Mudo Boost
# 175      Survive Dark
# 176     Survive Light
# 177          Wind Amp
# 178     Counterstrike
# 179      Invigorate 1
# 180      Regenerate 1
# 181       Resist Dark
# 182       Resist Elec
# 183       Resist Fire
# 184        Resist Ice
# 185      Resist Light
# 186       Resist Wind
# 187         Alertness
# 188         Apt Pupil
# 189       Endure Dark
# 190      Endure Light
# 191      Evade Pierce
# 192       Evade Slash
# 193      Evade Strike
# 194      High Counter
# 195        Null Charm
# 196     Null Distress
# 197         Null Fear
# 198       Null Freeze
# 199        Null Panic
# 200       Null Poison
# 201         Null Rage
# 202        Null Shock
# 203    Spring of Life
# 204      Invigorate 2
# 205         Null Dark
# 206         Null Elec
# 207         Null Fire
# 208          Null Ice
# 209        Null Light
# 210         Null Wind
# 211      Regenerate 2
# 212     Resist Pierce
# 213      Resist Slash
# 214     Resist Strike
# 215      1hSwd Master
# 216      2hSwd Master
# 217       Auto-Maraku
# 218       Auto-Masuku
# 219       Auto-Mataru
# 220     Auto-Rakukaja
# 221     Auto-Sukukaja
# 222     Auto-Tarukaja
# 223        Bow Master
# 224            Endure
# 225       Fist Master
# 226      Heavy Master
# 227      Invigorate 3
# 228      Regenerate 3
# 229        Repel Dark
# 230       Repel Light
# 231      Spear Master
# 232       Null Pierce
# 233        Null Slash
# 234       Null Strike
# 235        Repel Elec
# 236        Repel Fire
# 237         Repel Ice
# 238        Repel Wind
# 239       Absorb Elec
# 240       Absorb Fire
# 241        Absorb Ice
# 242       Absorb Wind
# 243     Ailment Boost
# 244      Divine Grace
# 245      Repel Pierce
# 246       Repel Slash
# 247      Repel Strike
# 248     Absorb Pierce
# 249      Absorb Slash
# 250     Absorb Strike
# 251       Arms Master
# 252     Enduring Soul
# 253      Spell Master
# 254     Unshaken Will
# 255       Victory Cry
# 256      Escape Route
# 257     Full Analysis
# 258      Healing Wave
# 259            Oracle
# 260      Support Scan
# 261         Third Eye
#
#                                                                                                                                                                   learners
# 0                                                                                                                           Hermes, Nekomata, Chimera, Archangel, Valkyrie
# 1                                                                                                                                            Valkyrie (15), Gurr, Rakshasa
# 2                                                                                                  Rakshasa (18), Ares (24), Take-Mikazuchi (27), Orthrus, Hanuman, Taraka
# 3                                                                                          Oberon (18), Ares, Titan, Pale Rider, Power (27), Jikokuten, Yatagarasu, Rangda
# 4                                                                                                                         Rakshasa (22), Ghoul (23), Shiisaa, Flauros, Ose
# 5                                                                                                         Orthrus (33), Flauros (37), Taraka (41), Girimehkala, Okuninushi
# 6                                                                                      Shiisaa (32), Palladion (35), Castor, Hanuman (38), Taraka (43), Narasimha, Yaksini
# 7                                                                                    Hermes (50), Castor (52), Hanuman (43), Narasimha (51), Yaksini (52), Kali, Chernobog
# 8                                                                              Castor (60), Yaksini (56), Surt, Kali (57), Byakko, Chernobog (60), Ganesha, Raphael, Uriel
# 9                                                                                                                                                             Michael (77)
# 10                                                                                                                 Siegfried, Raphael (67), Uriel (66), Thanatos, Masakado
# 11                                                                                                              Hermes (65), Thanatos (71), Susanoo, Atavaka (85), Lucifer
# 12                                                                                                                      Hermes (75), Siegfried (63), Susanoo (79), Chi You
# 13                                                                                                                                Orpheus, Ara Mitama, Forneus, Zouchouten
# 14                                                                                                                             Hermes (18), Zouchouten (16), Ghoul, Legion
# 15                                                                                                                               Jack Frost (10), Chimera (11), Polydeuces
# 16                                                                                        Titan (29), Yamatano-Orochi (30), Palladion, Genbu (30), Nata Taishi, Koumokuten
# 17                                                                                                  Hermes (25), Titan (25), Vetala, Yamatano-Orochi, Palladion, Oumitsunu
# 18                                                                                                                   Nata Taishi (41), Ose (47), Narasimha (47), Ubelluris
# 19                                                                                                            Hermes (55), Koumokuten (47), Ubelluris (50), Hecatoncheires
# 20                                                                                       Palladion (51), Castor (53), Quetzalcoatl (46), Kingu (50), Dionysus (51), Barong
# 21                                                                                                      Thor, Hecatoncheires (56), Melchizedek, Arahabaki, Hell Biker (63)
# 22                                                                 Palladion (73), Castor (72), Melchizedek (64), Sandalphon (76), Vishnu, Skadi (83), Atavaka (82), Asura
# 23                                                                                           Palladion (77), Castor (77), Melchizedek (69), Vishnu (82), Metatron, Messiah
# 24                                                                                                                        Kohryu, Seiten Taisei (70), Abaddon, Ananta (76)
# 25                                                                                                                                                          Inugami, Slime
# 26                                                                                                                                       Hermes (20), Berith, Naga, Mithra
# 27                                                                                                                                Archangel (12), Principality, High Pixie
# 28                                                                                                                                               Eligor, Raja Naga, Vasuki
# 29                                                                                                                     Eligor (34), Nemesis, Koumokuten, Kurama Tengu (48)
# 30                                                                                                                   Hermes (40), Orobas (37), Raja Naga (39), Cu Chulainn
# 31                                                                                                                       Nemesis (59), Cu Chulainn (45), Kaiwan (53), Odin
# 32                                                                                                                            Hokuto Seikun (49), Pazuzu (55), Hariti (65)
# 33                                                                                                                    Pazuzu (58), Bishamonten (63), Garuda, Seiten Taisei
# 34                                                                                        Bishamonten (65), Scathach, Cybele, Gabriel (75), Kartikeya, Masakado (76), Mara
# 35                                                                                                                                                              Shiva (85)
# 36                                                                                           Kartikeya (77), Mara (79), Saturnus (82), Beelzebub (83), Chi You (89), Helel
# 37                                                                                        Hermes (5), Orpheus (2), Nekomata, Ara Mitama, Lilim, Chimera, Berith, Pyro Jack
# 38                                                                                                         Nekomata (10), Slime (13), Berith (16), Pyro Jack, Hua Po, Sati
# 39                                                         Hermes (32), Pyro Jack (19), Hua Po (22), Lamia, Orthrus, Sati, Flauros, Cerberus, Black Frost, Incubus, Rangda
# 40                                                                       Eligor (32), Cerberus (38), Incubus (35), Okuninushi, Ose (45), Yaksini (53), Suzaku, Kikuri-Hime
# 41                                               Hermes (64), Cerberus (45), Rangda (46), Succubus, Okuninushi (46), Suzaku (53), Surt, Kumbhanda, Hell Biker, Seth, Asura
# 42                                                                 Cerberus (67), Surt (54), Bishamonten, Hell Biker, Uriel, Seth, Baal Zebul (75), Saturnus, Satan, Helel
# 43                                                                                                                                                               Surt (58)
# 44                                                                                                                                                                    Mara
# 45                                                                                                     Apsaras, Forneus, Jack Frost, Yomotsu Shikome, Fortuna, Penthesilea
# 46                                                        Jack Frost (13), Valkyrie (13), Penthesilea, High Pixie, Mithra, Yamatano-Orochi, Shiisaa, Sarasvati, King Frost
# 47                                                                            Penthesilea (21), High Pixie (23), Sarasvati, Genbu, King Frost, Black Frost, Ganga, Parvati
# 48                                                                                                   Penthesilea (42), King Frost (36), Parvati (49), Titania (51), Laksmi
# 49                                                                      Penthesilea (55), Parvati (52), Laksmi, Loki, Hariti, Horus (67), Gabriel, Baal Zebul (72), Vishnu
# 50                                                          Penthesilea (71), Scathach, Yurlungur, Trumpeter (67), Gabriel (71), Suparna (74), Michael (74), Skadi, Alilat
# 51                                                                                                                                                              Skadi (86)
# 52                                                                                                 Omoikane, Lilim, Inugami, Polydeuces, Zouchouten, Oberon, Take-Minakata
# 53                                           Lilim (12), Archangel (13), Polydeuces (21), Oberon (17), Naga (19), Take-Minakata, Empusa (27), Take-Mikazuchi, Shiisaa (28)
# 54                                                  Polydeuces (29), Oberon (20), Rakshasa (20), Take-Mikazuchi (26), Loa (34), Nemesis, Saki Mitama, Thoth, Hokuto Seikun
# 55                                                                          Polydeuces (41), Raja Naga (41), Cu Chulainn (41), Thoth (44), Dominion (47), Dionysus, Byakko
# 56                                                              Polydeuces (53), Mothman (38), Nemesis (55), Dionysus (50), Thor, Byakko (59), Odin, Mother Harlot, Vishnu
# 57                                                                     Polydeuces (74), Byakko (63), Odin, Lilith, Kartikeya (72), Michael, Beelzebub (84), Shiva, Lucifer
# 58                                                                                                                                                               Odin (63)
# 59                                                                                                                                Io (5), Angel, Alp, Nigi Mitama, Fortuna
# 60                                                                    Io (21), Yomotsu Shikome (14), Nigi Mitama (16), Fortuna (18), Narcissus, Empusa, Power, Kusi Mitama
# 61                                                                                    Io (32), Empusa (26), Pale Rider (25), Kusi Mitama, Orobas, Seiryu, Clotho, Lachesis
# 62                                                                            Io (46), Seiryu (37), Clotho (44), Nandi, Quetzalcoatl, Lachesis (50), Titania (49), Atropos
# 63                                                                        Io (57), Nandi (43), Quetzalcoatl (44), Pazuzu, Atropos (58), Jatayu, Loki, Yurlungur, Trumpeter
# 64                                                                      Io (65), Jatayu (60), Ganesha (61), Norn, Scathach (67), Garuda, Suparna, Masakado (75), Beelzebub
# 65                                                                                                                                                                    Norn
# 66                                                                                                     Angel (7), Archangel, Unicorn, Principality, Mithra, Power, Nemesis
# 67                                                                                                                         Principality (21), Power, Virtue, Vasuki, Thoth
# 68                                                                                                       Virtue (36), Nemesis (41), Dominion, Throne, Daisoujou, Trumpeter
# 69                                                                  Quetzalcoatl (47), Throne, Anubis, Horus, Uriel, Thanatos (66), Gabriel, Sandalphon, Atavaka, Metatron
# 70                                                                                                                                                          Daisoujou (56)
# 71                                                                             Alp (11), Lilim (11), Yomotsu Shikome (13), Ghoul, Titan, Pale Rider, Cerberus, Black Frost
# 72                                                                                                          Ghoul (20), Pale Rider, Lamia (26), Loa, Cerberus (42), Samael
# 73                                                                                                      Cerberus (56), Samael (42), Succubus, Mot, Nebiros (53), Trumpeter
# 74                                                  Cerberus (71), Girimehkala (45), Mot (46), Hecatoncheires (58), Chernobog, Anubis, Nidhoggr, Baal Zebul, Mother Harlot
# 75                                                                                                                                                              Alice (59)
# 76                                                                                                                                      Inugami (14), Vetala (27), Mothman
# 77                                                                                                                                                            Loa, Incubus
# 78                                                                                                            Lamia (29), Incubus (36), Decarabia, Nebiros (55), Loki (61)
# 79                                                                                                              Penthesilea (27), Incubus (37), Kaiwan, Pazuzu (54), Alice
# 80                                                                                                               Mothman (37), Samael (40), Thoth (45), Decarabia, Nebiros
# 81                                                                        Chernobog (63), Loki (60), Lilith (63), Thanatos, Attis, Cybele (70), Baal Zebul, Satan, Atavaka
# 82                                                                                                                        Asura (88), Metatron (90), Lucifer (91), Messiah
# 83                                                                                                                                                              Satan (86)
# 84                                                                                                                                                              Helel (91)
# 85                                                                                                                                       Chimera, Naga, Legion (27), Lamia
# 86                                                                                                                                          Forneus (10), Inugami, Unicorn
# 87                                                                                                                     Slime (16), Naga (22), Mithra (24), Mothman, Taraka
# 88                                                                                                                           Alp (7), Lilim, Penthesilea, Narcissus, Nandi
# 89                                                                                                                   Nekomata (6), Pyro Jack (15), Ghoul (22), Empusa (28)
# 90                                                                                                                           Pixie (4), Jack Frost, Legion, Take-Mikazuchi
# 91                                                                                                                                       Yatagarasu (32), Virtue, Dominion
# 92                                                                                                                  Gurr (20), Lamia (28), Seiryu, Ose, Pazuzu, Baal Zebul
# 93                                                                    Narcissus (21), Legion (24), Leanan Sidhe (34), Succubus, Yaksini, Lilith, Mother Harlot (77), Shiva
# 94                                                                                                                                           Yomotsu Shikome, Slime, Alice
# 95                                                                                                                Vetala (28), Incubus, Castor (39), Mot, Nebiros, Abaddon
# 96                                                                                                           Penthesilea (32), Vetala, Ganga (37), Raja Naga, Kurama Tengu
# 97                                                                        Seiryu (40), Girimehkala (43), Kingu (48), Kaiwan, Barong (54), Pazuzu (57), Arahabaki, Nidhoggr
# 98                                                                                                                    Samael (43), Mot (48), Nebiros (52), Thanatos, Attis
# 99                                                                                                                              Io (4), Angel, Archangel (11), Nigi Mitama
# 100                                                                                                             Io (16), Angel (8), Alp (8), Narcissus (22), Ganga, Clotho
# 101                                                                                                                                  Omoikane (8), Unicorn (13), Sati (29)
# 102                                                                                                           Apsaras (4), Forneus (11), Nigi Mitama, Queen Mab, Sarasvati
# 103                                                                                                              Hermes (7), Nekomata (7), Jack Frost, Hua Po, Kusi Mitama
# 104                                                                                                             Io, Pixie, Alp, Omoikane, Unicorn, Polydeuces, Penthesilea
# 105                                                                              Io (36), Omoikane (13), Power (28), Sarasvati (28), Genbu (31), Leanan Sidhe, Clotho (42)
# 106                                                         Io (22), Inugami (13), Nigi Mitama (14), Oberon, Principality (18), High Pixie (24), Sati, Leanan Sidhe, Ganga
# 107                           Io (25), Polydeuces (38), Penthesilea (24), Sati (33), Yatagarasu, Leanan Sidhe, Ganga (39), Nemesis (37), Seiryu (39), Saki Mitama, Parvati
# 108                                                        Io (28), Nigi Mitama (18), Principality (20), Queen Mab (28), Kusi Mitama (31), Nemesis (42), Hanuman, Lachesis
# 109                                               Io (43), Leanan Sidhe (38), Nemesis (51), Saki Mitama (42), Thoth (46), Kingu, Titania, Suzaku (54), Kikuri-Hime, Garuda
# 110                                                            Io (68), Palladion (65), Nemesis (73), Hariti (64), Yurlungur (70), Kohryu, Attis (70), Cybele, Ananta (79)
# 111                    Io (52), Polydeuces (65), Penthesilea (58), Palladion (59), Nemesis (62), Ubelluris (54), Daisoujou, Kikuri-Hime (56), Bishamonten, Hariti, Suparna
# 112                                                                                                                   Jatayu (57), Laksmi (63), Scathach (66), Garuda (68)
# 113                                    Io (74), Nemesis (78), Throne (55), Melchizedek, Raphael (63), Hariti, Horus, Yurlungur (68), Kohryu, Michael, Ananta, Atavaka (83)
# 114                                                                                                                 Sandalphon (83), Vishnu (84), Helel (94), Messiah (93)
# 115                                                              Hermes (9), Ara Mitama, Lilim (9), Fortuna (19), Naga, High Pixie (25), Queen Mab, Palladion (32), Orobas
# 116                                                                                 Pixie (3), Ara Mitama (7), Chimera (12), Polydeuces (25), Ares, Hua Po (23), Queen Mab
# 117                                                                                                               Berith (17), Ares (22), Legion, Titan, Vetala, Oumitsunu
# 118                                                                                                  Angel (5), Ara Mitama (8), Archangel, Palladion, Yatagarasu, Cerberus
# 119                                                                                                                Apsaras (5), Alp, Polydeuces (33), Pyro Jack, Jikokuten
# 120                                                                                                            Forneus, Berith, Zouchouten, Palladion (36), Virtue, Taraka
# 121                                                                                                             Orpheus (6), Yomotsu Shikome, Polydeuces (16), Empusa, Loa
# 122                                                                                      Narcissus (24), Palladion (42), Genbu (32), Samael (41), Saki Mitama (43), Ananta
# 123                                                                                                           Power (30), Jikokuten (31), Eligor, Kali (59), Nidhoggr (71)
# 124                                                                                                                   Take-Mikazuchi (29), Hokuto Seikun (52), Lilith (65)
# 125                                                                      Hermes (60), Mothman (36), Cerberus (60), Incubus (38), Succubus (45), Okuninushi (48), Seth (69)
# 126                                                                                                         Penthesilea (61), King Frost (32), Laksmi (59), Trumpeter (68)
# 127                                                                                             Polydeuces (57), Black Frost (35), Girimehkala, Kali, Alice (60), Masakado
# 128                                                                                                                 Polydeuces (66), Yatagarasu (31), Samael, Kurama Tengu
# 129                                                                                                         Polydeuces (47), Seiryu, Rangda (42), Decarabia, Nidhoggr (72)
# 130                                                                  Castor (50), Cu Chulainn (43), Narasimha (48), Ganesha, Siegfried, Scathach (69), Masakado, Mara (80)
# 131                                                                                                                                     Io (60), Mothman (35), Orobas (36)
# 132                                                                          Ghoul (21), Take-Minakata (26), Vetala (26), Yamatano-Orochi (28), Sarasvati (31), Koumokuten
# 133                                                                                              Hermes (44), Palladion (56), Nandi, Quetzalcoatl, Parvati, Decarabia (54)
# 134                                                                                                Palladion (47), Cerberus (50), Nata Taishi, Lachesis, Suzaku, Kartikeya
# 135                                                                                            Palladion (60), Black Frost (40), Raja Naga (37), Cu Chulainn, Raphael (64)
# 136                                                                                                  Penthesilea (50), Dionysus, Titania, Atropos (57), Vishnu (80), Helel
# 137                                                                                               Anubis (61), Lilith, Kohryu (70), Sandalphon, Beelzebub, Alilat, Lucifer
# 138                                                                                    Arahabaki (64), Trumpeter (70), Suparna (76), Susanoo, Mara (82), Skadi, Asura (87)
# 139                                                                                                        Vasuki (40), Ubelluris, Throne (53), Hecatoncheires (59), Attis
# 140                                                                                                   Pixie (8), High Pixie (26), Sati (31), Black Frost (37), Orobas (38)
# 141                                                                                                                           Slime (14), Gurr (18), Lamia, Ubelluris (53)
# 142                                                                                                       Polydeuces (37), Take-Mikazuchi (30), Hokuto Seikun (50), Byakko
# 143                                                                                                        Hua Po (24), Orthrus (31), Cerberus (48), Okuninushi (47), Surt
# 144                                                                                                                  Gurr (17), Empusa (25), King Frost (33), Kurama Tengu
# 145                                                                                  Jack Frost (11), Penthesilea (45), Yamatano-Orochi (31), Shiisaa (30), Sarasvati (29)
# 146                                                                                   Fortuna (22), Kusi Mitama (34), Orobas (39), Clotho (40), Quetzalcoatl (48), Atropos
# 147                                                                                                                             Narcissus, Leanan Sidhe (35), Yaksini (54)
# 148                                                                                                                                                            Taraka (42)
# 149                                                                                                                                                 Loa (35), Nebiros (54)
# 150                                                                                                                                Legion (25), Ganga (40), Raja Naga (42)
# 151                                                                                                                                                Inugami (11), Gurr (21)
# 152                                                                                                                                            Pyro Jack (17), Virtue (37)
# 153                                                                                                 Ara Mitama (12), Archangel (14), Zouchouten (18), Flauros (35), Orobas
# 154                                                          Hermes (35), Rakshasa (21), Ares (21), Mithra (28), Pale Rider (27), Orthrus, Oumitsunu (34), Castor, Hanuman
# 155                                                                                                                               Principality, Mithra (25), Lachesis (47)
# 156                                                                                                                     Shiisaa (29), King Frost, Nandi (44), Parvati (51)
# 157                                                                                                                                 Orthrus (30), Eligor (33), Rangda (44)
# 158                                                                                                                     Unicorn (12), Naga (21), Queen Mab (32), Oumitsunu
# 159                                                                                                                          Valkyrie, Rakshasa, Titan (26), Hokuto Seikun
# 160                                                                                                                          Gurr (19), Take-Minakata (24), Queen Mab (30)
# 161                                                                                                                                   Fortuna, Queen Mab (29), Vasuki (41)
# 162                                                                                                           Yatagarasu (37), Thoth (43), Quetzalcoatl, Kurama Tengu (46)
# 163                                                                                                                    Eligor (37), Nandi (41), Ose (49), Kikuri-Hime (55)
# 164                                                                                                                                  Polydeuces (76), Thor (59), Odin (60)
# 165                                                                                                                                                          Lachesis (51)
# 166                                                                                                                                                                  Kingu
# 167                                                                                                                                               Decarabia (52), Saturnus
# 168                                                                                                                                                Flauros (38), Narasimha
# 169                                                                                                                                    Lilith (64), Seiten Taisei, Susanoo
# 170                                         Cerberus (77), Surt (59), Kikuri-Hime (59), Kumbhanda (59), Bishamonten (62), Hell Biker (62), Uriel (65), Seth (68), Saturnus
# 171                                                                                                   Suzaku (55), Daisoujou, Jatayu, Horus, Yurlungur (67), Saturnus (80)
# 172                                                                                               Nemesis (54), Dominion (46), Throne, Daisoujou (59), Gabriel, Sandalphon
# 173                                                                                                                  Penthesilea (76), Titania (54), Yurlungur (66), Skadi
# 174                                                                                                    Loa (36), Mot (49), Alice (62), Baal Zebul (73), Mother Harlot (76)
# 175                                                                                                             Oberon (16), Jikokuten (32), Virtue (34), Cu Chulainn (44)
# 176                                                                                            Slime (18), Take-Minakata (22), Pale Rider (29), Loa (33), Girimehkala (46)
# 177                                                                                                                         Atropos (60), Ganesha (63), Norn, Suparna (72)
# 178                                                        Hermes (45), Cerberus (40), Castor (42), Nata Taishi (40), Vasuki (42), Koumokuten (46), Narasimha (49), Barong
# 179                                                                                                                                           Yatagarasu (34), Kikuri-Hime
# 180                                                                                                                              Castor, Nata Taishi (38), Koumokuten (48)
# 181                                                                                                                                             Dominion (49), Throne (57)
# 182                                                                                                                                        Kurama Tengu (50), Atropos (59)
# 183                                                                                                                                                            Laksmi (62)
# 184                                                                                                                          Decarabia (56), Suzaku (57), Kikuri-Hime (58)
# 185                                                                                                                                                  Vasuki (43), Mot (51)
# 186                                                                                                                                                          Dionysus (52)
# 187                                                                                                                                Kumbhanda (62), Ganesha, Arahabaki (62)
# 188                                                                                                         Okuninushi (49), Hokuto Seikun (53), Kali, Loki, Seiten Taisei
# 189                                                                                              Jikokuten (36), Virtue (39), Nata Taishi (43), Dominion (45), Barong (57)
# 190                                                                                                                                  Girimehkala (48), Hecatoncheires (57)
# 191                                                                                                                                                                 Kaiwan
# 192                                                                                                                                           Jikokuten (34), Hanuman (41)
# 193                                                                                                                                         Ubelluris (52), Hecatoncheires
# 194  Hermes (58), Cerberus (52), Castor (55), Thor, Kali (60), Ganesha (62), Siegfried (62), Uriel (67), Garuda (69), Abaddon, Kartikeya (73), Ananta (78), Beelzebub (85)
# 195                                                                                                                              Saki Mitama (44), Kumbhanda (58), Raphael
# 196                                                                                                                                                 Clotho (41), Ubelluris
# 197                                                                                                                                                                    Mot
# 198                                                                                                                                                            Hua Po (26)
# 199                                                                                                                                                 Raja Naga (40), Jatayu
# 200                                                                                                                                                     Kingu (49), Barong
# 201                                                                                                                                                         Oumitsunu (35)
# 202                                                                                                                                                     Hokuto Seikun (51)
# 203                                                                                                                                                                 Hermes
# 204                                                                                                                               Kaiwan (51), Barong (55), Chernobog (64)
# 205                                                                                                                                            Daisoujou (58), Laksmi (61)
# 206                                                                                                                                               Jatayu (59), Anubis (64)
# 207                                                                                                                                          Loki (63), Mother Harlot (80)
# 208                                                                                                                                                 Anubis (62), Seth (71)
# 209                                                                                                                                             Succubus (48), Kaiwan (54)
# 210                                                                                                                                                         Chernobog (62)
# 211                                                                                                                             Castor (65), Dionysus (53), Kumbhanda (60)
# 212                                                                                                                                                         Oumitsunu (36)
# 213                                                                                                                                                           Hanuman (44)
# 214                                                                                                                                                             Genbu (34)
# 215                                                                                                                                                          Thanatos (68)
# 216                                                                                                                                                         Siegfried (66)
# 217                                                                                                                                Barong (56), Arahabaki, Raphael, Cybele
# 218                                                                                                                          Kumbhanda, Siegfried, Hariti (67), Horus (65)
# 219                                                                                                                                       Thor (55), Melchizedek, Metatron
# 220                                                                              Omoikane (12), Unicorn (15), Take-Minakata (23), Yamatano-Orochi, Genbu, Kusi Mitama (30)
# 221                                                                                                   Forneus (9), Valkyrie (14), Zouchouten (19), Jikokuten, Flauros (34)
# 222                                                                                  Chimera (14), Yomotsu Shikome (11), Berith (15), Gurr, Take-Mikazuchi, Oumitsunu (31)
# 223                                                                                                                                                            Cybele (73)
# 224                                                                                                                 Kingu (52), Byakko (61), Ganesha (64), Hell Biker (64)
# 225                                                                                                                                      Polydeuces (50), Melchizedek (60)
# 226                                                                                                                                                              Thor (60)
# 227                                                                                   Norn (67), Scathach (72), Kohryu (68), Satan (82), Shiva (86), Chi You, Messiah (94)
# 228                                                                 Anubis (66), Norn (66), Seiten Taisei (73), Sandalphon (78), Susanoo (81), Satan (81), Alilat, Messiah
# 229                                                                                                   Alice (61), Melchizedek (65), Horus (68), Gabriel (73), Michael (75)
# 230                                                                                                                      Yurlungur (71), Seth (72), Attis (71), Satan (83)
# 231                                                                                                                                       Nemesis (65), Seiten Taisei (71)
# 232                                                                                                                                              Kohryu (73), Abaddon (73)
# 233                                                                                                                                                Chernobog, Abaddon (72)
# 234                                                                                                                              Arahabaki (67), Kohryu (71), Abaddon (71)
# 235                                                                                                                                                          Metatron (92)
# 236                                                                                                                                               Loki (65), Metatron (93)
# 237                                                                                                                           Arahabaki (66), Saturnus (83), Metatron (91)
# 238                                                                                                                                                            Garuda (70)
# 239                                                                                                                                              Norn (69), Kartikeya (75)
# 240                                                                                                                                            Hell Biker (66), Skadi (84)
# 241                                                                                                                                               Mara (84), Saturnus (84)
# 242                                                                                                                                               Lilith (67), Ananta (81)
# 243                                                                                                                         Succubus (46), Kaiwan (55), Mother Harlot (78)
# 244                                                                                                                                         Saki Mitama (45), Titania (52)
# 245                                                                                                                                                            Alilat (90)
# 246                                                                                                                                                            Alilat (88)
# 247                                                                                                                                              Susanoo (83), Alilat (89)
# 248                                                                                                                                            Nidhoggr (74), Messiah (95)
# 249                                                                                                                                                             Helel (92)
# 250                                                                                                                                             Abaddon (74), Chi You (91)
# 251                                                                                                          Siegfried (65), Bishamonten (67), Masakado (79), Chi You (92)
# 252                                                                                                                                        Attis (75), Shiva, Messiah (97)
# 253                                                                                                                       Odin (65), Cybele (75), Asura (91), Lucifer (93)
# 254                                                                                                                                                                  Asura
# 255                                                                                                           Beelzebub (87), Shiva (88), Lucifer (95), Orpheus Telos (97)
# 256                                                                                                                                                             Lucia (62)
# 257                                                                                                                                                                  Lucia
# 258                                                                                                                                                             Lucia (41)
# 259                                                                                                                                                             Lucia (50)
# 260                                                                                                                                                             Lucia (23)
# 261                                                                                                                                                             Lucia (32)

# %%
# Find the skill "Panta Rhei"
panta_rhei = df.loc[df['skill'] == 'Panta Rhei']

# Print the result
print(panta_rhei)
# Out:
#          skill learners
# 65  Panta Rhei     Norn

# %%
df.to_csv('skills_with_levels.csv', index=False)
