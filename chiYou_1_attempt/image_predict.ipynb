# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # replace with your actual path

# %%
from PIL import Image
import os
import re

# Open an image file
mainDirectory = r"C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou"

directory = 0

fullDirectory = os.path.join(mainDirectory, str(directory))

i = 0

curr_image = os.path.join(fullDirectory, f"cropped_{i}.png")

custom_config = r'--tessdata-dir "C:\Program Files\Tesseract-OCR\tessdata" --psm 13'

img = Image.open(curr_image)
text = pytesseract.image_to_string(img, config=custom_config)

# 'remove all characters that are not letters, numbers, ' ' or '-'
text = re.sub(r'[^a-zA-Z0-9 -]', '', text)

# remove ' ' and '-' from the beginning and end of the string
text = text.strip(' -')

print(text)
# Out:
# Auto-Sukuka ja

# %%
from PIL import Image
import os
import pytesseract

# Main directory
mainDirectory = r"C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou"

# Define the path to the custom dictionary
custom_dict_path = r"skills_dict.txt"

# Custom configuration for pytesseract
custom_config = r'--tessdata-dir "C:\Program Files\Tesseract-OCR\tessdata" --psm 13'

# Iterate over directories
for directory in range(999,1016):
    fullDirectory = os.path.join(mainDirectory, str(directory))

    # Iterate over images in each directory
    for i in range(5):
        curr_image = os.path.join(fullDirectory, f"cropped_{i}.png")

        # Check if the image file exists
        if os.path.exists(curr_image):
            img = Image.open(curr_image)
            text = pytesseract.image_to_string(img, config=custom_config)

            # 'remove all characters that are not letters, numbers, ' ' or '-'
            text = re.sub(r'[^a-zA-Z0-9 -]', '', text)

            # remove ' ' and '-' from the beginning and end of the string
            text = text.strip(' -')

            print(f"Text from image {i} in directory {fullDirectory}:")
            print(text)

            # Save the extracted text to a file
            with open(os.path.join(fullDirectory, f"cropped_{i}.txt"), 'w') as f:
                f.write(text)
        else:
            print(f"Image {i} in directory {directory} does not exist.")
# Out:
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou\999:
# Primal Force
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou\999:
# Absorb Slash
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou\999:
# Fire Amp
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou\999:
# Poison Arrow
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou\999:
# Wind Amp
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou\1000:
# Poison Arrow
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou\1000:
# Unshaken Will
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou\1000:
# Primallborce
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou\1000:
# Wind Boost
# ...
