# %%
#!/usr/bin/env python
# coding: utf-8

# In[2]:
import json

personae_path = '/home/eduardo/Documents/Persona3/AutoTelos/fusion_navigator/personae.json'
#personae_path = 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\fusion_navigator\\personae.json'
with open(personae_path, 'r') as fp:
    personae = json.load(fp)


# open json file and read contenta as a list of dictionaries
#combos2path = 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\fusion_navigator\\combos2.json'
combos2path = '/home/eduardo/Documents/Persona3/AutoTelos/fusion_navigator/combos2.json'
with open(combos2path, 'r') as fp:
    arcana2Combos = json.load(fp)


combos3path = '/home/eduardo/Documents/Persona3/AutoTelos/fusion_navigator/combos3.json'
#combos3path = 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\fusion_navigator\\combos3.json'
with open(combos3path, 'r') as fp:
    arcana3Combos = json.load(fp)


# specialCombos_path = 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\fusion_navigator\\specialCombos.json'
specialCombos_path = '/home/eduardo/Documents/Persona3/AutoTelos/fusion_navigator/specialCombos.json'
with open(specialCombos_path, 'r') as fp:
    specialCombos = json.load(fp)


# In[3]:


class PersonaCompendiumExtracted:
    def __init__(self, name, level, skills):
        self.name = name
        self.level = level
        self.skills = skills

import json


# persona_compendium_save_file_path = 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\fusion_navigator\\persona_compendium_save_file.json'
persona_compendium_save_file_path = '/home/eduardo/Documents/Persona3/AutoTelos/fusion_navigator/persona_compendium_save_file.json'
# Load the JSON file
with open(persona_compendium_save_file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)
# Create Persona objects
personas_compendium_extracted = [PersonaCompendiumExtracted(item['name'], item['level'], item['skills']) for item in data]

for persona in personae:
    persona['base_level+5'] = persona['level'] + 5 # max social links lead to a +5 bonus
    persona['base_level'] = persona['level']

# overwrite 'personae' with the new list
for persona_compendium_extracted in personas_compendium_extracted:
    for persona in personae:
        if persona_compendium_extracted.name.lower() == persona['name'].lower():
            persona['level'] = persona_compendium_extracted.level
            persona['skills'] = persona_compendium_extracted.skills
            break

# In[5]:


import math

def generate_arcana_rank(personae):
    arcana_rank = {}
    rank = 0
    last_arcana = None
    for persona in personae:
        if persona['arcana'] == last_arcana:
            continue
        last_arcana = persona['arcana']
        arcana_rank[persona['arcana']] = rank
        rank += 1
    return arcana_rank

# Assuming 'personae' is a list of dictionaries with an 'arcana' key.
# You need to define or import this list from your data.
arcana_rank = generate_arcana_rank(personae)

def generate_personae_by_name(personae):
    personae_by_name = {}
    for persona in personae:
        personae_by_name[persona['name']] = persona
    return personae_by_name

personae_by_name = generate_personae_by_name(personae)

def generate_personae_by_arcana(personae):
    personae_by_arcana = {}
    for persona in personae:
        arcana = persona['arcana']
        if arcana not in personae_by_arcana:
            personae_by_arcana[arcana] = []
        personae_by_arcana[arcana].append(persona)
    return personae_by_arcana

# Assuming 'personae' is a list of dictionaries with at least an 'arcana' key.
# You need to define or import this list from your data.
personae_by_arcana = generate_personae_by_arcana(personae)




class CalcCtrl:
    def __init__(self, persona_name, is_intermediate_fusion=False):
        self.ceil = math.ceil
        
        self.level_key = 'base_level'

        if is_intermediate_fusion:
            self.current_level_key = 'base_level+5'
        else:
            self.current_level_key = 'level'

        self.persona = personae_by_name.get(persona_name)

        self.all_recipes = []  # Consider renaming this to just 'recipes' for consistency with other methods
        if self.persona:
            self.get_recipes()
            self.all_recipes.sort(key=lambda x: x['cost'])
            self.max_cost = max(recipe['cost'] for recipe in self.all_recipes) if self.all_recipes else 0

    @staticmethod
    def get_rank(persona):
        return arcana_rank[persona['arcana']]

    def add_recipe(self, recipe):
        recipe['cost'] = sum((27 * source[self.level_key]**2 + 126 * source[self.level_key] + 2147) for source in recipe['sources'])
        recipe['sources'].sort(key=lambda x: (-x[self.level_key], self.get_rank(x)))
        self.all_recipes.append(recipe)

    def fuse2(self, arcana, persona1, persona2):
        level = 1 + (persona1[self.level_key] + persona2[self.level_key]) // 2
        personae = personae_by_arcana[arcana]

        for i, persona in enumerate(personae):
            if persona[self.level_key] >= level:
                if persona.get('special'):
                    continue
                break

        if persona1['arcana'] == persona2['arcana']:
            i -= 1
        if i < len(personae) and (personae[i] == persona1 or personae[i] == persona2):
            i -= 1

        return personae[max(i, 0)]  # Ensure i doesn't go below 0

    def fuse3(self, arcana, persona1, persona2, persona3):
        level = 5 + (persona1[self.level_key] + persona2[self.level_key] + persona3[self.level_key]) // 3
        personae = personae_by_arcana[arcana]

        found = False
        for i, persona in enumerate(personae):
            if persona[self.level_key] >= level:
                if persona.get('special'):
                    continue
                found = True
                break

        if not found:
            return None

        # In same arcana fusion, skip over the ingredients.
        if persona1['arcana'] == arcana and persona2['arcana'] == arcana and persona3['arcana'] == arcana:
            while (i < len(personae) and (persona1['name'] == personae[i]['name'] or
                                          persona2['name'] == personae[i]['name'] or
                                          persona3['name'] == personae[i]['name'])):
                i += 1
                if i >= len(personae):
                    return None

        return personae[i] if i < len(personae) else None
    
    def persona3_is_valid(self, persona1, persona2, persona3):
        if persona3 == persona1 or persona3 == persona2:
            return False

        if persona3[self.current_level_key] < persona1[self.current_level_key] or persona3[self.current_level_key] < persona2[self.current_level_key]:
            return False

        if persona3[self.current_level_key] == persona1[self.current_level_key]:
            return arcana_rank[persona3['arcana']] < arcana_rank[persona1['arcana']]

        if persona3[self.current_level_key] == persona2[self.current_level_key]:
            return arcana_rank[persona3['arcana']] < arcana_rank[persona2['arcana']]

        return True

    def find_3way_recipes(self, arcana1, arcana2):
        step1_recipes = self.get_arcana_recipes(arcana1)
        for step1_recipe in step1_recipes:
            persona1 = step1_recipe['sources'][0]
            persona2 = step1_recipe['sources'][1]
            personae = personae_by_arcana[arcana2]

            for persona3 in personae:
                if self.persona3_is_valid(persona1, persona2, persona3):
                    result = self.fuse3(self.persona['arcana'], persona1, persona2, persona3)
                    if not result or result['name'] != self.persona['name']:
                        continue

                    # filter if persona1,persona2 or persona3 name are equal to result
                    if persona1['name'] == result['name'] or persona2['name'] == result['name'] or persona3['name'] == result['name']:
                        continue

                    self.add_recipe({'sources': [persona1, persona2, persona3]})

    def get_recipes(self):
        if self.persona.get('special'):
            for combo in specialCombos:
                if self.persona['name'] == combo['result']:
                    recipe = {'sources': [personae_by_name[source] for source in combo['sources']]}
                    self.add_recipe(recipe)
                    return
        
         # Define filter_2way inside get_recipes
        def filter_2way(persona1, persona2, result):
            # Note: 'self' is accessible here because this is an inner function
            if persona1['name'] ==  self.persona['name']:
                return True
            if persona2['name'] ==  self.persona['name']:
                return True
            if result['name'] ==  self.persona['name']:
                return False
            return True
        


        recipes = self.get_arcana_recipes(self.persona['arcana'], filter_2way)
        for recipe in recipes:
            self.add_recipe(recipe)

        # Consider triangle fusion
        combos = [combo for combo in arcana3Combos if combo['result'] == self.persona['arcana']]
        for combo in combos:
            self.find_3way_recipes(combo['source'][0], combo['source'][1])
            if combo['source'][1] != combo['source'][0]:
                self.find_3way_recipes(combo['source'][1], combo['source'][0])
    
    def get_arcana_recipes(self, arcana_name, filter_callback=None):
        recipes = []
        combos = [x for x in arcana2Combos if x['result'] == arcana_name]

        for combo in combos:
            personae1 = personae_by_arcana[combo['source'][0]]
            personae2 = personae_by_arcana[combo['source'][1]]

            for i, persona1 in enumerate(personae1):
                for j, persona2 in enumerate(personae2):
                    if persona1['arcana'] == persona2['arcana'] and j <= i:
                        continue
                    result = self.fuse2(combo['result'], persona1, persona2)
                    if not result:
                        continue
                    if filter_callback and filter_callback(persona1, persona2, result):
                        continue

                    recipes.append({'sources': [persona1, persona2]})

        return recipes

#calc_ctrl = CalcCtrl('chi you', is_intermediate_fusion=False)
#calc_ctrl = CalcCtrl('orpheus telos', is_intermediate_fusion=True)
#print(calc_ctrl.all_recipes)


def print_sources(recipes, file):
    for recipe in recipes:
        print("Recipe:", file=file)
        for source in recipe['sources']:
            name = source.get('name', 'Unknown')
            level = source.get('level', 'Unknown')
            arcana = source.get('arcana', 'Unknown')
            special = ' (special)' if source.get('special') else ''
            print(f"  - {name}, Level: {level}, Arcana: {arcana}{special}", file=file)
        cost = recipe.get('cost', 'Unknown')
        print(f"Total Cost: {cost}\\n", file=file)


# In[17]:


# open dataframe located in "/home/eduardo/Documents/Persona3/AutoTelos/skills_list/skills.csv"
import pandas as pd


# 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\skills_list\\skills.csv'
skills_csv_path = "/home/eduardo/Documents/Persona3/AutoTelos/skills_list/skills.csv"
df = pd.read_csv(skills_csv_path)

#print(df)

skill_type_dict = df.set_index('skill')['type'].to_dict()

skill_rank_dict = df.set_index('skill')['rank'].to_dict()


# given a skill name return the skill type
def get_skill_type(skill_name):
    return skill_type_dict[skill_name]

def get_skill_rank(skill_name):
    return skill_rank_dict[skill_name]

#print(get_skill_type('Agidyne'))

persona_name = 'chi you'

# 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\inheritance_calculator\\inheritance.csv'
inheritance_csv_path = '/home/eduardo/Documents/Persona3/AutoTelos/inheritance_calculator/inheritance.csv'
inheritance_df = pd.read_csv(inheritance_csv_path)

# 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\inheritance_calculator\\personas_inheritance.csv'
personas_inheritance_csv_path = '/home/eduardo/Documents/Persona3/AutoTelos/inheritance_calculator/personas_inheritance.csv'
persona_inheritance_df = pd.read_csv(personas_inheritance_csv_path)

# get the type of the persona 'chi you' in the persona_inheritance_df
persona_inherit_type = persona_inheritance_df.loc[persona_inheritance_df['Persona'] == persona_name, 'Type'].iloc[0]


# Convert the DataFrame to a dictionary where each key is an inheritance type
# and its value is another dictionary of skill types and their probabilities.
inheritance_dict = inheritance_df.set_index('Inheritance Type').T.to_dict('dict')



# given a skill type return the skill inheritance probability for a given persona type
def get_inheritance_probability(skill_type, persona_inheritance_type):
    # Access the nested dictionary directly for the value
    # Check if the persona_inheritance_type exists to avoid KeyErrors
    if persona_inheritance_type in inheritance_dict:
        # Return the probability value for the given skill_type and persona_inheritance_type
        return inheritance_dict[persona_inheritance_type].get(skill_type, 0)  # Returns 0 if skill_type is not found


#print(get_inheritance_probability('Almighty', persona_inherit_type))


def get_ammount_of_inherited_skills(skills):
    if len(skills) < 6:
        return 1
    elif len(skills) < 9:
        return 2
    elif len(skills) < 12:
        return 3
    elif len(skills) < 24:
        return 4
    elif len(skills) < 32:
        return 5
    elif len(skills) < 40:
        return 6
    elif len(skills) < 48:
        return 7
    else:
        return 8
    
def create_desired_skills_probability_dict(desired_skills):
    desired_skills_probability_dict = {}
    for s in desired_skills:
        skill_type = get_skill_type(s)
        desired_skills_probability_dict[s] = get_inheritance_probability(skill_type, persona_inherit_type)
    return desired_skills_probability_dict
    
def get_best_recipe(desired_skills, recipes_list):

    best_ratio = 0
    best_ratio_max = 0
    best_recipe = recipes_list[0]
    best_set = None

    best_ratio_max = 0
    best_recipe_max = best_recipe
    best_set_max = best_set
    best_skills_max = best_set

    biggest_ammount_of_inherited_skills = 0

    for i in range(len(recipes_list)):
        current_skills = []
        dont_have = False

        skadi = False
        norn = False
        baal_zebul = False

        for j in range(len(recipes_list[i]['sources'])):
            # if 'skills' key does not exist continue
            if 'skills' not in recipes_list[i]['sources'][j]:
                dont_have = True
                continue
            for s in recipes_list[i]['sources'][j]['skills']:
                current_skills.append(s)
            if recipes_list[i]['sources'][j]['name'] == 'skadi':
                skadi = True
            if recipes_list[i]['sources'][j]['name'] == 'norn':
                norn = True
            if recipes_list[i]['sources'][j]['name'] == 'baal zebul':
                baal_zebul = True
            if skadi:
                print('hello')
                None
            
        
        if dont_have:
            continue

        ammount_of_inherited_skills = get_ammount_of_inherited_skills(current_skills)

        

        if ammount_of_inherited_skills > biggest_ammount_of_inherited_skills:
            best_ratio_max = 0
            best_recipe_max = None
            best_set_max = None
            biggest_ammount_of_inherited_skills = ammount_of_inherited_skills
            

        set_current_skills = list(set(current_skills))
        
        #count how many skills of the desired skills are in the current skills
        desired_count = 0
        
        # while 'ammount_of_inherited_skills' is not reached count as many 'desired_skills' as possible. If space still remais count 'noise_skills'
        for s in set_current_skills:
            skill_type = get_skill_type(s)
            if s in desired_skills:
                ratio_skill = get_inheritance_probability(skill_type, persona_inherit_type)
                if ratio_skill > 0:
                    desired_count += 1
        
        
        current_desired_skills = []

        #count how many skills of the desired skills are in the current skills
        desired_count_ratio = 0
        noise_count_ratio = 0
        for s in set_current_skills:
            # get the skill type from the dataframe
            skill_type = get_skill_type(s)

            ratio_skill = get_inheritance_probability(skill_type, persona_inherit_type)
            if s in desired_skills:
                current_desired_skills.append(s)
                desired_count_ratio += ratio_skill
            else:
                noise_count_ratio += ratio_skill

        # should it be 1 or something between? should i switch nominator and denominator?   
        ratio = desired_count_ratio / max(noise_count_ratio,1)

        # the bigger the ratio the better
        if ratio > best_ratio:
            best_ratio = ratio
            best_recipe = recipes_list[i]
            best_set = set_current_skills
            best_desired_skills_prob_dict = create_desired_skills_probability_dict(current_desired_skills)
        
        if desired_count >= biggest_ammount_of_inherited_skills and ammount_of_inherited_skills == biggest_ammount_of_inherited_skills and ratio > best_ratio_max:
            best_ratio_max = ratio
            best_recipe_max = recipes_list[i]
            best_set_max = set_current_skills
            best_skills_max = current_skills
            best_desired_skills_prob_dict_max = create_desired_skills_probability_dict(current_desired_skills)

        if 2185 == i:
            running_ratio = ratio
            running_recipe = recipes_list[i]
            running_set = set_current_skills

    return best_ratio, best_recipe, best_set, best_desired_skills_prob_dict, biggest_ammount_of_inherited_skills, best_ratio_max, best_recipe_max, best_set_max, best_skills_max, best_desired_skills_prob_dict_max, running_ratio, running_recipe, running_set


#chi_you_base = CalcCtrl(persona_name, is_intermediate_fusion=False).all_recipes



mandatory_skills = [
'High Counter',
'Unshaken Will',
'Panta Rhei',
]

optional_skills = [
'Wind Boost',
'Wind Amp',
'Spell Master',
'Mind Charge',
'Salvation',
]

desired_skills = mandatory_skills + optional_skills

#best_ratio, best_recipe, best_set, best_desired_skills_prob_dict, biggest_ammount_of_inherited_skills, best_ratio_max, best_recipe_max, best_set_max, best_skills_max, best_desired_skills_prob_dict_max, running_ratio, running_recipe, running_set = get_best_recipe(desired_skills=desired_skills, recipes_list=chi_you_base)

# %%
import pandas as pd

# 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\inheritance_calculator\\personas_inheritance.csv'
personas_inheritance_csv_path = '/home/eduardo/Documents/Persona3/AutoTelos/inheritance_calculator/personas_inheritance.csv'
persona_inheritance_df = pd.read_csv(personas_inheritance_csv_path)

# Convert the dataframe to a dictionary
persona_inheritance_dict = persona_inheritance_df.set_index('Persona')['Type'].to_dict()

def get_persona_inheritance_type(persona_name):
    # Use the dictionary for fast lookups
    return persona_inheritance_dict.get(persona_name)

# Example usage
#persona_inheritance_type = get_persona_inheritance_type("chi you")

# %%
# open json file into a dictionary

# 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\skills_list\\skills.csv'
skills_csv_path = "/home/eduardo/Documents/Persona3/AutoTelos/skills_list/skills.csv"
df = pd.read_csv(skills_csv_path)

#print(df)

skill_type_dict = df.set_index('skill')['type'].to_dict()

skill_rank_dict = df.set_index('skill')['rank'].to_dict()

# get all unique skill types and all unique ranks
unique_skill_types = set(skill_type_dict.values())
unique_skill_ranks = set(skill_rank_dict.values())

missing = 0
pair_exist = []
pair_dont_exist = []
for st in unique_skill_types:
    for sr in unique_skill_ranks:
        if sr == 99:
            continue
        # veriy if there is not an entry in the df with that skill type and rank
        if len(df.loc[(df['type'] == st) & (df['rank'] == sr)]) == 0:
            #print(f"Missing skill: {st} - {sr}")
            missing+=1
            pair_dont_exist.append((st,sr))
        else:
            pair_exist.append((st,sr))

def load_empty_total_dict():
    # 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\inheritance_calculator\\combinations.json'
    combinations_json_path = '/home/eduardo/Documents/Persona3/AutoTelos/inheritance_calculator/combinations.json'
    with open(combinations_json_path, 'r') as fp:
        total_combinations_dict = json.load(fp)

    total_combinations_dict_new = {}

    # for each key in the dictionary convert the tuple string in a tuple
    for key in total_combinations_dict:
        eval_key = eval(key)
        inherit_type , skill_rank, skill_type = eval_key

        pair = skill_rank, skill_type

        if pair in pair_dont_exist:
            total_combinations_dict_new[eval_key] = 1
        else:
            total_combinations_dict_new[eval_key] = 0


    total_dict = total_combinations_dict_new

    return total_dict

# %%
import ast

import pandas as pd
# Load the CSV file into a DataFrame
# 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\skills_list\\inheritable_skills_with_levels.csv'
inheritable_skills_csv_path = '/home/eduardo/Documents/Persona3/AutoTelos/skills_list/inheritable_skills_with_levels.csv'
df = pd.read_csv(inheritable_skills_csv_path)

#print all lines of the dataframe
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    None
    #print(df)

class UnlockableSkill:
    def __init__(self, name, level=None):
        self.name = name
        self.level = level

    def __repr__(self):
        if self.level:
            return f"('{self.name}', lv{self.level})"
        else:
            return f"('{self.name}')"


def extract_skills(data):
    skill_dict = {}
    for persona, skills_str in zip(data['persona'], data['skill']):
        # Safely evaluate the string as a list
        skills = ast.literal_eval(skills_str)
        skill_list = []
        for skill in skills:
            # Check if there's a level specified in the skill string
            if '(' in skill and ')' in skill:
                name, level_str = skill.rsplit('(', 1)
                level = int(level_str[:-1])  # Remove the closing parenthesis and convert to int
            else:
                name, level = skill, None

            skill_list.append(UnlockableSkill(name.strip(), level))
        
        skill_dict[persona] = skill_list

    return skill_dict

skill_dict = extract_skills(df)
for persona, skills in skill_dict.items():
    None
    #print(f"{persona}: {skills}")


# verify if for any persona in the dictionary, if it's skills have level numbers that repeat
for persona, skills in skill_dict.items():
    levels = [skill.level for skill in skills]
    # remove 'None' values from the list
    levels = [level for level in levels if level is not None]
    if len(levels) != len(set(levels)):
        print(f"Persona {persona} has repeated levels: {levels}")

def ammount_of_base_skills(persona_name):
    persona_skills = skill_dict[persona_name]
    base_skills = [skill for skill in persona_skills if skill.level is None]
    return len(base_skills)

print(ammount_of_base_skills('chi you'))
# Out:
# 2

# %%
from itertools import product
from tqdm import tqdm
from bitarray import bitarray


class Persona:
    def __init__(self, data):
        self.name = data.get('name', 'Unknown')
        self.level = data.get('level', 0)
        self.arcana = data.get('arcana', 'Unknown')
        self.special = data.get('special', False)
        self.base_level = data.get('base_level', 0)
        self.base_level_plus_5 = data.get('base_level+5', self.base_level + 5)
        self.skills = data.get('skills', [])
        self.all_recipes = CalcCtrl(self.name, is_intermediate_fusion=False).all_recipes
        self.ammount_of_base_skills = ammount_of_base_skills(self.name)

    def __str__(self):
        return (f"Name: {self.name}\\n"
                f"Level: {self.level}\\n"
                f"Arcana: {self.arcana}\\n"
                f"Special: {self.special}\\n"
                f"Base Level: {self.base_level}\\n"
                f"Base Level + 5: {self.base_level_plus_5}\\n"
                f"Skills: {', '.join(self.skills)}\\n"
                f"Ammount of Base Skills: {self.ammount_of_base_skills}\\n")

all_personas = {}

# beging search

def are_all_values_true(dictionary):
    return all(dictionary.values())

minimal_ammout_of_recipes = 0
''' 
class Recipe():
    def __init__(self, personas, skills_set, resulting_persona_name=None, coverage_dict=None):
        self.personas = personas
        self.skills_set = skills_set
        self.resulting_persona_name = resulting_persona_name
        self.ammount_of_base_skills = ammount_of_base_skills(resulting_persona_name)
        self.ammount_of_inherited_skills = get_ammount_of_inherited_skills(self.skills_set)


        # Sort and enumerate keys
        sorted_keys = sorted(coverage_dict.keys())
        key_index_map = {key: index for index, key in enumerate(sorted_keys)}

        # Create a bitarray for the values
        bit_values = bitarray(len(sorted_keys))
        for key, value in sorted_keys:
            bit_values[key_index_map[key]] = value
        
        self.coverage_bits = bit_values
    
    @property
    def coverage_dict(self):

         # Sort and enumerate keys
        sorted_keys = sorted(total_dict.keys())
        key_index_map = {key: index for index, key in enumerate(sorted_keys)}

        dictionary = {}

        for key, _ in enumerate(sorted_keys):
            index = key_index_map[key]
            dictionary[key] = self.coverage_bits[index]


        return self._coverage_dict   
'''
total_dict = load_empty_total_dict()
# Sort and enumerate keys of the initial coverage_dict
sorted_keys = sorted(total_dict.keys())
key_index_map = {key: index for index, key in enumerate(sorted_keys)}


class Recipe():
    def __init__(self, personas, skills_set, resulting_persona_name, coverage_dict=None):
        self.personas = personas
        self.skills_set = skills_set
        self.resulting_persona_name = resulting_persona_name
        self.amount_of_base_skills = ammount_of_base_skills(resulting_persona_name)  # Assuming this is defined elsewhere
        self.amount_of_inherited_skills = get_ammount_of_inherited_skills(self.skills_set)  # Assuming this is defined elsewhere

        # Create a bitarray for the values
        self.coverage_bits = bitarray(len(sorted_keys))
        for key, value in coverage_dict.items():
            self.coverage_bits[key_index_map[key]] = value

        # empty the variable to free memory
        coverage_dict = None

    @property
    def coverage_dict(self):
        # Reconstruct the dictionary from the bitarray
        return {key: self.coverage_bits[index] for key, index in key_index_map.items()}

    def __str__(self):
        # count ammount of true values in the dictionary
        count = sum(self.coverage_dict.values())

        persona_names = [persona.name for persona in self.personas]

        return (f"Personas: {persona_names}\\n"
                f"Skills: {self.skills_set}\\n"
                f"Resulting Persona: {self.resulting_persona_name}\\n"
                f"Coverage: {self.coverage_dict}\\n"
                f"Coverage Ammount: {count}\\n"
                f"Base Skills Ammount: {self.ammount_of_base_skills}\\n"
                f"Inherited Skills Ammount: {self.ammount_of_inherited_skills}\\n"
                "------------------------\\n")
    
    def __repr__(self):

        count = sum(self.coverage_dict.values())

        persona_names = [persona.name for persona in self.personas]

        return (f"Personas: {persona_names}\\n"
                f"Skills: {self.skills_set}\\n"
                f"Resulting Persona: {self.resulting_persona_name}\\n"
                f"Coverage: {self.coverage_dict}\\n"
                f"Coverage Ammount: {count}\\n"
                f"Base Skills Ammount: {self.ammount_of_base_skills}\\n"
                f"Inherited Skills Ammount: {self.ammount_of_inherited_skills}\\n"
                "------------------------\\n")


all_fucking_recipes = []

print("Creating giant list")

# giant list of recipes
for persona in tqdm(personae):
    persona_name = persona['name']

    persona_inherit_type = get_persona_inheritance_type(persona_name)

    if persona_name not in all_personas:
        # Convert JSON string to dictionary
        # Create Persona object
        current_p = Persona(persona)
        all_personas[persona_name] = current_p
    else:
        current_p = all_personas[persona_name]
    
    all_recipes = current_p.all_recipes

    for recipe in all_recipes:
        # make all values in the dictionary be the last iteration
        personas = []
        recipe_skills = []

        coverage_dict = total_dict.copy()
        for parent in recipe['sources']:
            name = parent.get('name', 'Unknown')
            if name not in all_personas:
                # Convert JSON string to dictionary
                # Create Persona object
                current_p = Persona(parent)
                all_personas[name] = current_p
            else:
                current_p = all_personas[name]
            personas.append(current_p)
            
            for s in current_p.skills:
                recipe_skills.append(s)

            for s in current_p.skills:
                skill_type = get_skill_type(s)
                skill_rank = get_skill_rank(s)
                triple_rank_skilltype_inherittype = (persona_inherit_type, skill_rank, skill_type)
                coverage_dict[triple_rank_skilltype_inherittype] = True
                
        recipe_skills_set_list = list(set(recipe_skills))

        currect_recipe = Recipe(personas, recipe_skills_set_list,resulting_persona_name=persona_name,coverage_dict=coverage_dict)
        all_fucking_recipes.append(currect_recipe)
        


print(len(all_fucking_recipes))
# Out:
# Creating giant list
#   0%|          | 0/169 [00:00<?, ?it/s]
# 100%|██████████| 169/169 [01:22<00:00,  2.05it/s]
# 573133

# %%
import itertools


def coverage_of_list_of_recipes(list_of_recipes):
    total_dict = load_empty_total_dict()
    #print(total_dict)

    for recipe in list_of_recipes:
        
        recipe_skills_set_list = recipe.skills_set

        persona_inherit_type = get_persona_inheritance_type(recipe.resulting_persona_name)
        
        #find all probability ratios for each skill in the recipe
        for s in recipe_skills_set_list:
            skill_type = get_skill_type(s)
            skill_rank = get_skill_rank(s)
            triple_rank_skilltype_inherittype = (persona_inherit_type, skill_rank, skill_type)
            total_dict[triple_rank_skilltype_inherittype] = True
    
            
    # count the ammount of True values in the dictionary
    count = sum(total_dict.values())
    return count

recipe = all_fucking_recipes[:1]
print(recipe[0].coverage_dict)
print(len(recipe[0].coverage_dict))


# print all skills of the recipe
print(recipe[0].resulting_persona_name)

print(recipe[0].skills_set)


for key, value in recipe[0].coverage_dict.items():
    if value > 0:
        print(key)
coverage_of_list_of_recipes(recipe)
# Out:
# {('ALL', 1, 'Almighty'): 0, ('ALL', 1, 'Bad Status'): 0, ('ALL', 1, 'Dark'): 0, ('ALL', 1, 'Elec'): 0, ('ALL', 1, 'Enhance'): 0, ('ALL', 1, 'Fire'): 0, ('ALL', 1, 'Ice'): 0, ('ALL', 1, 'Light'): 0, ('ALL', 1, 'Passive'): 0, ('ALL', 1, 'Pierce'): 0, ('ALL', 1, 'Recovery'): 0, ('ALL', 1, 'Slash'): 0, ('ALL', 1, 'Special'): 0, ('ALL', 1, 'Strike'): 0, ('ALL', 1, 'Wind'): 0, ('ALL', 2, 'Almighty'): 0, ('ALL', 2, 'Bad Status'): 0, ('ALL', 2, 'Dark'): 0, ('ALL', 2, 'Elec'): 0, ('ALL', 2, 'Enhance'): 0, ('ALL', 2, 'Fire'): 0, ('ALL', 2, 'Ice'): 0, ('ALL', 2, 'Light'): 0, ('ALL', 2, 'Passive'): 0, ('ALL', 2, 'Pierce'): 0, ('ALL', 2, 'Recovery'): 0, ('ALL', 2, 'Slash'): 0, ('ALL', 2, 'Special'): 0, ('ALL', 2, 'Strike'): 0, ('ALL', 2, 'Wind'): 0, ('ALL', 3, 'Almighty'): 0, ('ALL', 3, 'Bad Status'): 0, ('ALL', 3, 'Dark'): 0, ('ALL', 3, 'Elec'): 0, ('ALL', 3, 'Enhance'): 0, ('ALL', 3, 'Fire'): 0, ('ALL', 3, 'Ice'): 0, ('ALL', 3, 'Light'): 0, ('ALL', 3, 'Passive'): 0, ('ALL', 3, 'Pierce'): 0, ('ALL', 3, 'Recovery'): 0, ('ALL', 3, 'Slash'): 0, ('ALL', 3, 'Special'): 0, ('ALL', 3, 'Strike'): 0, ('ALL', 3, 'Wind'): 0, ('ALL', 4, 'Almighty'): 0, ('ALL', 4, 'Bad Status'): 0, ('ALL', 4, 'Dark'): 0, ('ALL', 4, 'Elec'): 0, ('ALL', 4, 'Enhance'): 0, ('ALL', 4, 'Fire'): 0, ('ALL', 4, 'Ice'): 0, ('ALL', 4, 'Light'): 0, ('ALL', 4, 'Passive'): 0, ('ALL', 4, 'Pierce'): 0, ('ALL', 4, 'Recovery'): 0, ('ALL', 4, 'Slash'): 0, ('ALL', 4, 'Special'): 0, ('ALL', 4, 'Strike'): 0, ('ALL', 4, 'Wind'): 0, ('ALL', 5, 'Almighty'): 0, ('ALL', 5, 'Bad Status'): 0, ('ALL', 5, 'Dark'): 0, ('ALL', 5, 'Elec'): 0, ('ALL', 5, 'Enhance'): 0, ('ALL', 5, 'Fire'): 0, ('ALL', 5, 'Ice'): 0, ('ALL', 5, 'Light'): 0, ('ALL', 5, 'Passive'): 0, ('ALL', 5, 'Pierce'): 0, ('ALL', 5, 'Recovery'): 0, ('ALL', 5, 'Slash'): 0, ('ALL', 5, 'Special'): 0, ('ALL', 5, 'Strike'): 0, ('ALL', 5, 'Wind'): 0, ('ALL', 6, 'Almighty'): 0, ('ALL', 6, 'Bad Status'): 0, ('ALL', 6, 'Dark'): 0, ('ALL', 6, 'Elec'): 0, ('ALL', 6, 'Enhance'): 0, ('ALL', 6, 'Fire'): 0, ('ALL', 6, 'Ice'): 0, ('ALL', 6, 'Light'): 0, ('ALL', 6, 'Passive'): 0, ('ALL', 6, 'Pierce'): 0, ('ALL', 6, 'Recovery'): 0, ('ALL', 6, 'Slash'): 0, ('ALL', 6, 'Special'): 0, ('ALL', 6, 'Strike'): 0, ('ALL', 6, 'Wind'): 0, ('ALL', 7, 'Almighty'): 0, ('ALL', 7, 'Bad Status'): 0, ('ALL', 7, 'Dark'): 0, ('ALL', 7, 'Elec'): 0, ('ALL', 7, 'Enhance'): 0, ('ALL', 7, 'Fire'): 0, ('ALL', 7, 'Ice'): 0, ('ALL', 7, 'Light'): 0, ('ALL', 7, 'Passive'): 0, ('ALL', 7, 'Pierce'): 0, ('ALL', 7, 'Recovery'): 0, ('ALL', 7, 'Slash'): 0, ('ALL', 7, 'Special'): 0, ('ALL', 7, 'Strike'): 0, ('ALL', 7, 'Wind'): 0, ('ALL', 8, 'Almighty'): 0, ('ALL', 8, 'Bad Status'): 0, ('ALL', 8, 'Dark'): 0, ('ALL', 8, 'Elec'): 0, ('ALL', 8, 'Enhance'): 0, ('ALL', 8, 'Fire'): 0, ('ALL', 8, 'Ice'): 0, ('ALL', 8, 'Light'): 0, ('ALL', 8, 'Passive'): 0, ('ALL', 8, 'Pierce'): 0, ('ALL', 8, 'Recovery'): 0, ('ALL', 8, 'Slash'): 0, ('ALL', 8, 'Special'): 0, ('ALL', 8, 'Strike'): 0, ('ALL', 8, 'Wind'): 0, ('ALL', 9, 'Almighty'): 0, ('ALL', 9, 'Bad Status'): 0, ('ALL', 9, 'Dark'): 0, ('ALL', 9, 'Elec'): 0, ('ALL', 9, 'Enhance'): 0, ('ALL', 9, 'Fire'): 0, ('ALL', 9, 'Ice'): 0, ('ALL', 9, 'Light'): 0, ('ALL', 9, 'Passive'): 0, ('ALL', 9, 'Pierce'): 0, ('ALL', 9, 'Recovery'): 0, ('ALL', 9, 'Slash'): 0, ('ALL', 9, 'Special'): 0, ('ALL', 9, 'Strike'): 0, ('ALL', 9, 'Wind'): 0, ('BAD STATUS', 1, 'Almighty'): 0, ('BAD STATUS', 1, 'Bad Status'): 0, ('BAD STATUS', 1, 'Dark'): 0, ('BAD STATUS', 1, 'Elec'): 0, ('BAD STATUS', 1, 'Enhance'): 0, ('BAD STATUS', 1, 'Fire'): 0, ('BAD STATUS', 1, 'Ice'): 0, ('BAD STATUS', 1, 'Light'): 0, ('BAD STATUS', 1, 'Passive'): 0, ('BAD STATUS', 1, 'Pierce'): 0, ('BAD STATUS', 1, 'Recovery'): 0, ('BAD STATUS', 1, 'Slash'): 0, ('BAD STATUS', 1, 'Special'): 0, ('BAD STATUS', 1, 'Strike'): 0, ('BAD STATUS', 1, 'Wind'): 0, ('BAD STATUS', 2, 'Almighty'): 0, ('BAD STATUS', 2, 'Bad Status'): 0, ('BAD STATUS', 2, 'Dark'): 0, ('BAD STATUS', 2, 'Elec'): 0, ('BAD STATUS', 2, 'Enhance'): 0, ( ...
# 1755
# orpheus
# ['Rebellion', 'Evil Touch', 'Single Shot', 'Pulinpa', 'Assault Dive']
# ('FIRE', 1, 'Pierce')
# ('FIRE', 2, 'Bad Status')
# ('FIRE', 2, 'Enhance')
# ('FIRE', 2, 'Strike')
# ('FIRE', 3, 'Bad Status')
# 5

# %%
# NEVER RUN THIS
''' 
# make a all possible permutations of 'all_fucking_recipes' and put them all in a list
permutations_list = []
print("Generating all permutations for different lengths")
for r in range(1, 4):
    for permutation in itertools.permutations(all_fucking_recipes[:2], r):
        permutations_list.append(permutation)
        None

print("Finished creating all permutations for different lengths")
print("Creating list")


max_coverage = 0
for permutation in tqdm(permutations_list):
    # if permutation is of type 'Recipe'
    if isinstance(permutation, Recipe):
        permutation = [permutation]
    cvg = coverage_of_list_of_recipes(permutation)
    if cvg > max_coverage:
        max_coverage = cvg
        max_perm = permutation

for recipe in max_perm:
    for persona in recipe.personas:
        print(persona.name)
    print('--')
print(max_coverage)
'''
# Out:
# ' \n# make a all possible permutations of \'all_fucking_recipes\' and put them all in a list\npermutations_list = []\nprint("Generating all permutations for different lengths")\nfor r in range(1, 4):\n    for permutation in itertools.permutations(all_fucking_recipes[:2], r):\n        permutations_list.append(permutation)\n        None\n\nprint("Finished creating all permutations for different lengths")\nprint("Creating list")\n\n\nmax_coverage = 0\nfor permutation in tqdm(permutations_list):\n    # if permutation is of type \'Recipe\'\n    if isinstance(permutation, Recipe):\n        permutation = [permutation]\n    cvg = coverage_of_list_of_recipes(permutation)\n    if cvg > max_coverage:\n        max_coverage = cvg\n        max_perm = permutation\n\nfor recipe in max_perm:\n    for persona in recipe.personas:\n        print(persona.name)\n    print(\'--\')\nprint(max_coverage)\n'

# %%
def remove_duplicate_recipes(recipe_list):
    unique_recipes = {}

    for recipe in recipe_list:
        coverage = tuple(sorted(recipe.coverage_dict.items()))  # Convert dict to tuple for hashability

        if coverage in unique_recipes:
            # Compare the length of 'personas' and keep the one with fewer elements
            if len(recipe.personas) < len(unique_recipes[coverage].personas):
                unique_recipes[coverage] = recipe
        else:
            unique_recipes[coverage] = recipe

    return list(unique_recipes.values())


def remove_recipes_with_zero_coverage(recipe_list):
    return [recipe for recipe in recipe_list if sum(recipe.coverage_dict.values()) > 0]

all_fucking_recipes = remove_duplicate_recipes(all_fucking_recipes)
all_fucking_recipes = remove_recipes_with_zero_coverage(all_fucking_recipes)
filtered_recipes = all_fucking_recipes
print(len(filtered_recipes))

# %% [markdown]
# integer programming

# %%
dict_constraints = {}

for i in range(len(filtered_recipes)):
    recipe = filtered_recipes[i]
    coverage_dict = recipe.coverage_dict
    if i == len(filtered_recipes)-1:
        None
        # print(len(coverage_dict.keys()))
    for key, value, in coverage_dict.items():
        if value == True:
            # add empty list if key does not exist
            if key not in dict_constraints:
                dict_constraints[key] = []
            dict_constraints[key].append(i)
            
dict_constraints_keys = list(dict_constraints.keys())
dict_constraints_keys.sort()
#print(dict_constraints_keys)
#print(len(dict_constraints_keys))
''' 
for key in dict_constraints_keys:
    list_of_indexes = dict_constraints[key]
    string = ''
    for index in list_of_indexes:
        string += 'x' + str(index)
        # if not the last index print "+"
        if index != list_of_indexes[-1]:
            string += ' + '
    string += ' >= 1'
    
    # Open the file and append the string
    with open('contraints_output.txt', 'a') as f:
        f.write(string + '\\n')
'''

# Assuming dict_constraints and coverage_dict are your dictionaries
missing_keys = set(coverage_dict.keys()) - set(dict_constraints.keys())

# Now print the missing keys
for key in missing_keys:
    print(key)

print(len(missing_keys))
# Out:
# ('LIGHT', 6, 'Recovery')
# ('BAD STATUS', 3, 'Enhance')
# ('FIRE', 2, 'Light')
# ('SLASH', 1, 'Pierce')
# ('LIGHT', 4, 'Elec')
# ('FIRE', 7, 'Almighty')
# ('RECOVERY', 5, 'Fire')
# ('PIERCE', 2, 'Elec')
# ('LIGHT & DARK', 9, 'Wind')
# ('FIRE', 2, 'Passive')
# ('WIND', 1, 'Dark')
# ('SLASH', 6, 'Almighty')
# ('PIERCE', 9, 'Light')
# ('FIRE', 4, 'Pierce')
# ('LIGHT', 6, 'Pierce')
# ('BAD STATUS', 3, 'Fire')
# ('RECOVERY', 6, 'Slash')
# ('ELECTRICITY', 4, 'Elec')
# ('ALL', 7, 'Light')
# ('PIERCE', 9, 'Passive')
# ('LIGHT & DARK', 2, 'Recovery')
# ('WIND', 3, 'Strike')
# ('ICE', 5, 'Wind')
# ('FIRE', 7, 'Ice')
# ('PIERCE', 5, 'Enhance')
# ('STRIKE', 7, 'Light')
# ('STRIKE', 8, 'Wind')
# ('FIRE', 5, 'Pierce')
# ('LIGHT & DARK', 9, 'Dark')
# ('WIND', 6, 'Elec')
# ('SLASH', 8, 'Special')
# ('BAD STATUS', 7, 'Light')
# ('LIGHT & DARK', 5, 'Almighty')
# ('SLASH', 6, 'Ice')
# ('LIGHT & DARK', 6, 'Special')
# ('STRIKE', 7, 'Passive')
# ('ALL', 9, 'Pierce')
# ('SLASH', 4, 'Pierce')
# ('ELECTRICITY', 5, 'Elec')
# ('LIGHT & DARK', 2, 'Pierce')
# ('PIERCE', 5, 'Fire')
# ('STRIKE', 1, 'Recovery')
# ('ICE', 5, 'Dark')
# ('ICE', 1, 'Almighty')
# ('DARK', 7, 'Slash')
# ('SLASH', 3, 'Recovery')
# ('WIND', 9, 'Enhance')
# ('WIND', 1, 'Special')
# ('LIGHT & DARK', 5, 'Ice')
# ('DARK', 8, 'Fire')
# ('SLASH', 1, 'Light')
# ('DARK', 2, 'Strike')
# ('ELECTRICITY', 8, 'Enhance')
# ('DARK', 5, 'Bad Status')
# ('DARK', 3, 'Wind')
# ('LIGHT & DARK', 8, 'Passive')
# ('SLASH', 1, 'Passive')
# ('FIRE', 4, 'Light')
# ('ICE', 4, 'Light')
# ('WIND', 9, 'Fire')
# ('LIGHT', 6, 'Light')
# ('ICE', 1, 'Ice')
# ('RECOVERY', 9, 'Special')
# ('LIGHT & DARK', 9, 'Special')
# ('WIND', 4, 'Wind')
# ('PIERCE', 4, 'Elec')
# ('ELECTRICITY', 8, 'Fire')
# ('ICE', 4, 'Passive')
# ('DARK', 6, 'Bad Status')
# ('BAD STATUS', 4, 'Slash')
# ('LIGHT', 4, 'Strike')
# ('FIRE', 7, 'Recovery')
# ('DARK', 9, 'Special')
# ('LIGHT', 2, 'Enhance')
# ('ELECTRICITY', 3, 'Wind')
# ('DARK', 3, 'Dark')
# ('BAD STATUS', 6, 'Enhance')
# ('FIRE', 5, 'Light')
# ('STRIKE', 2, 'Elec')
# ('LIGHT', 7, 'Elec')
# ('SLASH', 6, 'Recovery')
# ('RECOVERY', 8, 'Fire')
# ('SLASH', 4, 'Light')
# ('FIRE', 5, 'Passive')
# ('LIGHT & DARK', 2, 'Light')
# ('WIND', 4, 'Dark')
# ('FIRE', 1, 'Enhance')
# ('RECOVERY', 7, 'Almighty')
# ('SLASH', 9, 'Almighty')
# ('FIRE', 7, 'Pierce')
# ('ELECTRICITY', 4, 'Strike')
# ('LIGHT', 2, 'Fire')
# ('BAD STATUS', 6, 'Fire')
# ('SLASH', 4, 'Passive')
# ('RECOVERY', 2, 'Passive')
# ('ICE', 7, 'Light')
# ('ELECTRICITY', 3, 'Dark')
# ('WIND', 2, 'Slash')
# ('LIGHT', 1, 'Almighty')
# ('SLASH', 6, 'Pierce')
# ('BAD STATUS', 3, 'Bad Status')
# ('BAD STATUS', 1, 'Wind')
# ('LIGHT & DARK', 5, 'Recovery')
# ('WIND', 6, 'Strike')
# ('PIERCE', 8, 'Enhance')
# ('LIGHT & DARK', 3, 'Elec')
# ('PIERCE', 1, 'Strike')
# ('ELECTRICITY', 1, 'Slash')
# ('ICE', 7, 'Passive')
# ('ICE', 3, 'Enhance')
# ('RECOVERY', 7, 'Ice')
# ('ALL', 6, 'Enhance')
# ('ICE', 1, 'Recovery')
# ('STRIKE', 6, 'Enhance')
# ('LIGHT', 3, 'Special')
# ('LIGHT & DARK', 5, 'Pierce')
# ('LIGHT', 1, 'Ice')
# ('PIERCE', 8, 'Fire')
# ('FIRE', 2, 'Slash')
# ('LIGHT', 5, 'Wind')
# ('BAD STATUS', 1, 'Dark')
# ('PIERCE', 5, 'Bad Status')
# ('PIERCE', 3, 'Wind')
# ('WIND', 3, 'Almighty')
# ('RECOVERY', 8, 'Ice')
# ('WIND', 4, 'Special')
# ('PIERCE', 9, 'Slash')
# ('ELECTRICITY', 2, 'Almighty')
# ('DARK', 6, 'Wind')
# ('ELECTRICITY', 3, 'Special')
# ('PIERCE', 4, 'Strike')
# ('DARK', 5, 'Passive')
# ('LIGHT', 5, 'Dark')
# ('STRIKE', 7, 'Slash')
# ('PIERCE', 3, 'Dark')
# ('WIND', 3, 'Ice')
# ('WIND', 9, 'Bad Status')
# ('WIND', 7, 'Wind')
# ('STRIKE', 9, 'Enhance')
# ('BAD STATUS', 7, 'Slash')
# ('LIGHT', 6, 'Special')
# ('LIGHT', 7, 'Strike')
# ('STRIKE', 2, 'Strike')
# ('ICE', 2, 'Elec')
# ('ELECTRICITY', 2, 'Ice')
# ('ALL', 1, 'Dark')
# ('ELECTRICITY', 8, 'Bad Status')
# ('ELECTRICITY', 6, 'Wind')
# ('LIGHT', 8, 'Wind')
# ('BAD STATUS', 9, 'Enhance')
# ('DARK', 2, 'Almighty')
# ('FIRE', 8, 'Elec')
# ('STRIKE', 1, 'Dark')
# ('BAD STATUS', 1, 'Special')
# ('BAD STATUS', 2, 'Strike')
# ('STRIKE', 5, 'Elec')
# ('SLASH', 9, 'Recovery')
# ('RECOVERY', 7, 'Recovery')
# ('RECOVERY', 5, 'Light')
# ('SLASH', 7, 'Elec')
# ('LIGHT & DARK', 5, 'Light')
# ('WIND', 7, 'Dark')
# ('FIRE', 3, 'Fire')
# ('LIGHT', 1, 'Recovery')
# ('ELECTRICITY', 7, 'Strike')
# ('SLASH', 1, 'Slash')
# ('ALL', 9, 'Special')
# ('BAD STATUS', 9, 'Fire')
# ('RECOVERY', 5, 'Passive')
# ('LIGHT', 8, 'Dark')
# ('RECOVERY', 1, 'Enhance')
# ('ELECTRICITY', 6, 'Dark')
# ('SLASH', 2, 'Fire')
# ('LIGHT', 4, 'Almighty')
# ('RECOVERY', 7, 'Pierce')
# ('LIGHT & DARK', 1, 'Enhance')
# ('BAD STATUS', 6, 'Bad Status')
# ('BAD STATUS', 8, 'Almighty')
# ('LIGHT', 5, 'Special')
# ('LIGHT & DARK', 4, 'Wind')
# ('PIERCE', 2, 'Almighty')
# ('FIRE', 4, 'Slash')
# ('ICE', 4, 'Slash')
# ('LIGHT & DARK', 6, 'Elec')
# ('PIERCE', 3, 'Special')
# ('LIGHT', 6, 'Slash')
# ('LIGHT', 1, 'Pierce')
# ('ICE', 6, 'Enhance')
# ('ELECTRICITY', 9, 'Wind')
# ('FIRE', 1, 'Bad Status')
# ('ALL', 1, 'Special')
# ('RECOVERY', 8, 'Pierce')
# ('LIGHT & DARK', 1, 'Fire')
# ('STRIKE', 1, 'Special')
# ('WIND', 3, 'Recovery')
# ('LIGHT', 4, 'Ice')
# ('BAD STATUS', 8, 'Ice')
# ('FIRE', 5, 'Slash')
# ('LIGHT & DARK', 4, 'Dark')
# ('WIND', 1, 'Elec')
# ('SLASH', 3, 'Special')
# ('PIERCE', 2, 'Ice')
# ('PIERCE', 8, 'Bad Status')
# ('PIERCE', 6, 'Wind')
# ('ELECTRICITY', 2, 'Recovery')
# ('WIND', 6, 'Almighty')
# ('SLASH', 4, 'Slash')
# ('WIND', 7, 'Special')
# ('ICE', 3, 'Bad Status')
# ('LIGHT & DARK', 2, 'Slash')
# ('DARK', 8, 'Light')
# ('ELECTRICITY', 9, 'Dark')
# ('RECOVERY', 4, 'Enhance')
# ('ALL', 6, 'Bad Status')
# ('ELECTRICITY', 5, 'Almighty')
# ('WIND', 3, 'Pierce')
# ('LIGHT', 8, 'Special')
# ('ELECTRICITY', 6, 'Special')
# ('STRIKE', 6, 'Bad Status')
# ('STRIKE', 4, 'Wind')
# ('LIGHT & DARK', 9, 'Elec')
# ('PIERCE', 7, 'Strike')
# ('DARK', 8, 'Passive')
# ('ELECTRICITY', 2, 'Pierce')
# ('DARK', 4, 'Enhance')
# ('ICE', 9, 'Enhance')
# ('PIERCE', 6, 'Dark')
# ('WIND', 6, 'Ice')
# ('ICE', 2, 'Strike')
# ('RECOVERY', 7, 'Light')
# ('DARK', 2, 'Recovery')
# ('FIRE', 7, 'Special')
# ('FIRE', 8, 'Strike')
# ('STRIKE', 5, 'Strike')
# ('FIRE', 9, 'Wind')
# ('ICE', 5, 'Elec')
# ('WIND', 9, 'Passive')
# ('ALL', 8, 'Ice')
# ('ELECTRICITY', 5, 'Ice')
# ('LIGHT', 1, 'Light')
# ('SLASH', 6, 'Special')
# ('SLASH', 7, 'Strike')
# ('STRIKE', 4, 'Dark')
# ('LIGHT & DARK', 4, 'Special')
# ('RECOVERY', 3, 'Enhance')
# ('STRIKE', 8, 'Elec')
# ('RECOVERY', 8, 'Light')
# ('DARK', 1, 'Bad Status')
# ('FIRE', 6, 'Fire')
# ('LIGHT', 4, 'Recovery')
# ('ELECTRICITY', 9, 'Special')
# ('BAD STATUS', 8, 'Recovery')
# ('STRIKE', 9, 'Bad Status')
# ('LIGHT', 2, 'Light')
# ('PIERCE', 2, 'Recovery')
# ('FIRE', 9, 'Dark')
# ('FIRE', 1, 'Wind')
# ('RECOVERY', 8, 'Passive')
# ('SLASH', 5, 'Fire')
# ('LIGHT & DARK', 6, 'Strike')
# ('RECOVERY', 3, 'Fire')
# ('STRIKE', 2, 'Almighty')
# ('LIGHT', 7, 'Almighty')
# ('BAD STATUS', 9, 'Bad Status')
# ('LIGHT & DARK', 7, 'Wind')
# ('LIGHT', 2, 'Passive')
# ('WIND', 3, 'Light')
# ('PIERCE', 6, 'Special')
# ('LIGHT', 4, 'Pierce')
# ('ICE', 8, 'Fire')
# ('BAD STATUS', 8, 'Pierce')
# ('DARK', 3, 'Elec')
# ('ICE', 1, 'Special')
# ('PIERCE', 2, 'Pierce')
# ('ELECTRICITY', 2, 'Light')
# ('ICE', 3, 'Wind')
# ('STRIKE', 3, 'Almighty')
# ('RECOVERY', 6, 'Enhance')
# ('STRIKE', 4, 'Special')
# ('WIND', 6, 'Recovery')
# ('STRIKE', 2, 'Ice')
# ('LIGHT', 7, 'Ice')
# ('SLASH', 9, 'Dark')
# ('RECOVERY', 1, 'Bad Status')
# ('STRIKE', 6, 'Wind')
# ('LIGHT & DARK', 1, 'Bad Status')
# ('LIGHT & DARK', 7, 'Dark')
# ('WIND', 4, 'Elec')
# ('ELECTRICITY', 2, 'Passive')
# ('LIGHT & DARK', 3, 'Almighty')
# ('ELECTRICITY', 5, 'Recovery')
# ('RECOVERY', 5, 'Slash')
# ('ELECTRICITY', 3, 'Elec')
# ('ICE', 6, 'Bad Status')
# ('LIGHT & DARK', 5, 'Slash')
# ('FIRE', 6, 'Ice')
# ('RECOVERY', 6, 'Fire')
# ('LIGHT & DARK', 9, 'Strike')
# ('FIRE', 9, 'Special')
# ('WIND', 6, 'Pierce')
# ('ICE', 3, 'Dark')
# ('STRIKE', 3, 'Ice')
# ('SLASH', 5, 'Ice')
# ('ELECTRICITY', 5, 'Pierce')
# ('LIGHT & DARK', 3, 'Ice')
# ('DARK', 7, 'Enhance')
# ('ICE', 5, 'Strike')
# ('DARK', 1, 'Wind')
# ('STRIKE', 8, 'Strike')
# ('BAD STATUS', 1, 'Elec')
# ('RECOVERY', 4, 'Bad Status')
# ('STRIKE', 9, 'Wind')
# ('LIGHT', 4, 'Light')
# ('SLASH', 9, 'Special')
# ('RECOVERY', 7, 'Special')
# ('BAD STATUS', 8, 'Light')
# ('LIGHT & DARK', 7, 'Special')
# ('LIGHT & DARK', 8, 'Strike')
# ('PIERCE', 2, 'Light')
# ('DARK', 4, 'Bad Status')
# ('ICE', 9, 'Bad Status')
# ('BAD STATUS', 8, 'Passive')
# ('LIGHT', 7, 'Recovery')
# ('STRIKE', 2, 'Recovery')
# ('DARK', 1, 'Dark')
# ('BAD STATUS', 4, 'Enhance')
# ('FIRE', 3, 'Light')
# ('ICE', 2, 'Almighty')
# ('PIERCE', 2, 'Passive')
# ('DARK', 8, 'Slash')
# ('LIGHT', 5, 'Elec')
# ('FIRE', 8, 'Almighty')
# ('STRIKE', 9, 'Dark')
# ('STRIKE', 5, 'Almighty')
# ('PIERCE', 3, 'Elec')
# ('SLASH', 2, 'Light')
# ('FIRE', 3, 'Passive')
# ('DARK', 3, 'Strike')
# ('RECOVERY', 1, 'Wind')
# ('SLASH', 7, 'Almighty')
# ('WIND', 6, 'Light')
# ('BAD STATUS', 9, 'Passive')
# ('STRIKE', 3, 'Recovery')
# ('STRIKE', 2, 'Pierce')
# ('DARK', 2, 'Dark')
# ('BAD STATUS', 4, 'Fire')
# ('LIGHT', 7, 'Pierce')
# ('SLASH', 2, 'Passive')
# ('DARK', 6, 'Elec')
# ('RECOVERY', 7, 'Slash')
# ('ICE', 2, 'Ice')
# ('ELECTRICITY', 5, 'Light')
# ('ALL', 8, 'Light')
# ('ICE', 6, 'Wind')
# ('LIGHT & DARK', 3, 'Recovery')
# ('WIND', 4, 'Strike')
# ('FIRE', 8, 'Ice')
# ('WIND', 2, 'Enhance')
# ('LIGHT', 1, 'Slash')
# ('SLASH', 8, 'Almighty')
# ('FIRE', 6, 'Pierce')
# ('WIND', 7, 'Elec')
# ('LIGHT & DARK', 6, 'Almighty')
# ('SLASH', 7, 'Ice')
# ('STRIKE', 3, 'Pierce')
# ('RECOVERY', 1, 'Dark')
# ('ELECTRICITY', 1, 'Enhance')
# ('LIGHT & DARK', 1, 'Passive')
# ('RECOVERY', 8, 'Slash')
# ('SLASH', 5, 'Pierce')
# ('LIGHT', 8, 'Elec')
# ('ELECTRICITY', 6, 'Elec')
# ('LIGHT & DARK', 3, 'Pierce')
# ('RECOVERY', 9, 'Fire')
# ('WIND', 2, 'Fire')
# ('ICE', 6, 'Dark')
# ('BAD STATUS', 3, 'Elec')
# ('LIGHT', 2, 'Slash')
# ('RECOVERY', 6, 'Bad Status')
# ('PIERCE', 1, 'Wind')
# ('RECOVERY', 4, 'Wind')
# ('WIND', 1, 'Almighty')
# ('SLASH', 8, 'Ice')
# ('ELECTRICITY', 1, 'Fire')
# ('LIGHT & DARK', 6, 'Ice')
# ('DARK', 9, 'Fire')
# ('DARK', 2, 'Special')
# ('ELECTRICITY', 4, 'Dark')
# ('WIND', 3, 'Slash')
# ('DARK', 4, 'Wind')
# ('ICE', 9, 'Wind')
# ('PIERCE', 9, 'Enhance')
# ('ELECTRICITY', 2, 'Slash')
# ('LIGHT & DARK', 9, 'Almighty')
# ('PIERCE', 1, 'Dark')
# ('RECOVERY', 4, 'Dark')
# ('WIND', 1, 'Ice')
# ('WIND', 5, 'Wind')
# ('PIERCE', 5, 'Elec')
# ('ICE', 2, 'Recovery')
# ('STRIKE', 7, 'Enhance')
# ('ELECTRICITY', 9, 'Elec')
# ('DARK', 7, 'Bad Status')
# ('LIGHT', 5, 'Strike')
# ('FIRE', 8, 'Recovery')
# ('PIERCE', 9, 'Fire')
# ('STRIKE', 5, 'Recovery')
# ('DARK', 4, 'Dark')
# ('ICE', 9, 'Dark')
# ('BAD STATUS', 7, 'Enhance')
# ('ICE', 5, 'Almighty')
# ('FIRE', 6, 'Light')
# ('STRIKE', 3, 'Light')
# ('SLASH', 7, 'Recovery')
# ('LIGHT & DARK', 9, 'Ice')
# ('PIERCE', 6, 'Elec')
# ('SLASH', 5, 'Light')
# ('RECOVERY', 3, 'Light')
# ('ICE', 2, 'Pierce')
# ('FIRE', 6, 'Passive')
# ('LIGHT & DARK', 3, 'Light')
# ('DARK', 6, 'Strike')
# ('STRIKE', 3, 'Passive')
# ('WIND', 5, 'Dark')
# ('FIRE', 8, 'Pierce')
# ('ELECTRICITY', 4, 'Special')
# ('LIGHT', 3, 'Fire')
# ('BAD STATUS', 7, 'Fire')
# ('SLASH', 5, 'Passive')
# ('RECOVERY', 3, 'Passive')
# ('ICE', 8, 'Light')
# ('SLASH', 1, 'Enhance')
# ('ICE', 5, 'Ice')
# ('SLASH', 8, 'Recovery')
# ('SLASH', 7, 'Pierce')
# ('BAD STATUS', 4, 'Bad Status')
# ('BAD STATUS', 2, 'Wind')
# ('LIGHT & DARK', 6, 'Recovery')
# ('WIND', 7, 'Strike')
# ('PIERCE', 4, 'Dark')
# ('WIND', 8, 'Wind')
# ('PIERCE', 1, 'Special')
# ('ICE', 8, 'Passive')
# ('LIGHT', 4, 'Slash')
# ('BAD STATUS', 8, 'Slash')
# ('FIRE', 4, 'Enhance')
# ('ELECTRICITY', 6, 'Strike')
# ('ICE', 4, 'Enhance')
# ('LIGHT', 8, 'Strike')
# ('PIERCE', 2, 'Slash')
# ('LIGHT', 6, 'Enhance')
# ('ELECTRICITY', 7, 'Wind')
# ('DARK', 3, 'Almighty')
# ('FIRE', 9, 'Elec')
# ('SLASH', 1, 'Fire')
# ('SLASH', 8, 'Pierce')
# ('BAD STATUS', 3, 'Strike')
# ('WIND', 1, 'Recovery')
# ('LIGHT & DARK', 6, 'Pierce')
# ('FIRE', 3, 'Slash')
# ('BAD STATUS', 2, 'Dark')
# ('WIND', 2, 'Bad Status')
# ('FIRE', 5, 'Enhance')
# ('WIND', 8, 'Dark')
# ('FIRE', 4, 'Fire')
# ('WIND', 4, 'Almighty')
# ('LIGHT', 6, 'Fire')
# ('SLASH', 2, 'Slash')
# ('WIND', 5, 'Special')
# ('RECOVERY', 6, 'Passive')
# ('ELECTRICITY', 1, 'Bad Status')
# ('ELECTRICITY', 7, 'Dark')
# ('SLASH', 4, 'Enhance')
# ('DARK', 3, 'Ice')
# ('WIND', 6, 'Slash')
# ('ELECTRICITY', 3, 'Almighty')
# ('DARK', 7, 'Wind')
# ('WIND', 1, 'Pierce')
# ('FIRE', 1, 'Elec')
# ('LIGHT & DARK', 2, 'Enhance')
# ('LIGHT & DARK', 9, 'Recovery')
# ('LIGHT & DARK', 7, 'Elec')
# ('PIERCE', 4, 'Special')
# ('PIERCE', 5, 'Strike')
# ('ELECTRICITY', 5, 'Slash')
# ('WIND', 4, 'Ice')
# ('ALL', 9, 'Fire')
# ('ALL', 2, 'Special')
# ('ICE', 5, 'Recovery')
# ('LIGHT & DARK', 2, 'Fire')
# ('LIGHT', 7, 'Special')
# ('LIGHT & DARK', 9, 'Pierce')
# ('ICE', 3, 'Elec')
# ('STRIKE', 2, 'Special')
# ('ELECTRICITY', 3, 'Ice')
# ('LIGHT', 9, 'Wind')
# ('PIERCE', 6, 'Strike')
# ('BAD STATUS', 1, 'Almighty')
# ('BAD STATUS', 2, 'Special')
# ('PIERCE', 9, 'Bad Status')
# ('STRIKE', 6, 'Elec')
# ('PIERCE', 7, 'Wind')
# ('WIND', 8, 'Special')
# ('SLASH', 8, 'Light')
# ('ICE', 5, 'Pierce')
# ('LIGHT & DARK', 6, 'Light')
# ('ALL', 7, 'Bad Status')
# ('ELECTRICITY', 7, 'Special')
# ('ELECTRICITY', 8, 'Strike')
# ('STRIKE', 7, 'Bad Status')
# ('SLASH', 8, 'Passive')
# ('LIGHT', 9, 'Dark')
# ('SLASH', 3, 'Fire')
# ('BAD STATUS', 1, 'Ice')
# ('LIGHT', 5, 'Almighty')
# ('BAD STATUS', 7, 'Bad Status')
# ('BAD STATUS', 5, 'Wind')
# ('PIERCE', 7, 'Dark')
# ('PIERCE', 3, 'Almighty')
# ('DARK', 3, 'Recovery')
# ('WIND', 1, 'Light')
# ('FIRE', 9, 'Strike')
# ('DARK', 1, 'Elec')
# ('ALL', 1, 'Almighty')
# ('DARK', 6, 'Almighty')
# ('STRIKE', 5, 'Dark')
# ('WIND', 1, 'Passive')
# ('BAD STATUS', 6, 'Strike')
# ('STRIKE', 9, 'Elec')
# ('WIND', 4, 'Recovery')
# ('LIGHT', 5, 'Ice')
# ('SLASH', 1, 'Bad Status')
# ('FIRE', 6, 'Slash')
# ('BAD STATUS', 5, 'Dark')
# ('RECOVERY', 9, 'Light')
# ('DARK', 3, 'Pierce')
# ('STRIKE', 3, 'Slash')
# ('PIERCE', 3, 'Ice')
# ('LIGHT & DARK', 9, 'Light')
# ('FIRE', 7, 'Fire')
# ('ELECTRICITY', 3, 'Recovery')
# ('WIND', 7, 'Almighty')
# ('FIRE', 1, 'Strike')
# ('SLASH', 5, 'Slash')
# ('RECOVERY', 3, 'Slash')
# ('FIRE', 4, 'Bad Status')
# ('ICE', 4, 'Bad Status')
# ('RECOVERY', 9, 'Passive')
# ('LIGHT & DARK', 3, 'Slash')
# ('FIRE', 2, 'Wind')
# ('WIND', 2, 'Passive')
# ('SLASH', 6, 'Fire')
# ('DARK', 9, 'Light')
# ('LIGHT', 8, 'Almighty')
# ('DARK', 6, 'Ice')
# ('RECOVERY', 5, 'Enhance')
# ('STRIKE', 1, 'Ice')
# ('ELECTRICITY', 6, 'Almighty')
# ('LIGHT', 9, 'Special')
# ('WIND', 4, 'Pierce')
# ('LIGHT & DARK', 5, 'Enhance')
# ('ELECTRICITY', 1, 'Passive')
# ('ICE', 8, 'Slash')
# ('PIERCE', 7, 'Special')
# ('PIERCE', 8, 'Strike')
# ('DARK', 9, 'Passive')
# ('ELECTRICITY', 3, 'Pierce')
# ('RECOVERY', 1, 'Elec')
# ('PIERCE', 9, 'Wind')
# ('WIND', 7, 'Ice')
# ('ICE', 2, 'Special')
# ('ICE', 3, 'Strike')
# ('FIRE', 5, 'Bad Status')
# ('BAD STATUS', 1, 'Recovery')
# ('FIRE', 8, 'Special')
# ('FIRE', 2, 'Dark')
# ('LIGHT & DARK', 5, 'Fire')
# ('ALL', 7, 'Wind')
# ('STRIKE', 5, 'Special')
# ('STRIKE', 6, 'Strike')
# ('ICE', 6, 'Elec')
# ('LIGHT', 8, 'Ice')
# ('ELECTRICITY', 6, 'Ice')
# ('SLASH', 4, 'Bad Status')
# ('RECOVERY', 2, 'Bad Status')
# ('STRIKE', 7, 'Wind')
# ('LIGHT & DARK', 2, 'Bad Status')
# ('SLASH', 7, 'Special')
# ('LIGHT & DARK', 4, 'Almighty')
# ('BAD STATUS', 5, 'Special')
# ('ICE', 1, 'Fire')
# ('ICE', 7, 'Bad Status')
# ('BAD STATUS', 1, 'Pierce')
# ('ELECTRICITY', 9, 'Almighty')
# ('LIGHT', 5, 'Recovery')
# ('LIGHT', 3, 'Light')
# ('PIERCE', 3, 'Recovery')
# ('STRIKE', 7, 'Dark')
# ('LIGHT & DARK', 4, 'Ice')
# ('PIERCE', 1, 'Elec')
# ('DARK', 8, 'Enhance')
# ('ICE', 2, 'Slash')
# ('RECOVERY', 4, 'Elec')
# ('LIGHT & DARK', 8, 'Wind')
# ('DARK', 1, 'Strike')
# ('PIERCE', 6, 'Almighty')
# ('SLASH', 1, 'Wind')
# ('LIGHT', 3, 'Passive')
# ('DARK', 6, 'Recovery')
# ('WIND', 4, 'Light')
# ('BAD STATUS', 7, 'Passive')
# ('LIGHT', 5, 'Pierce')
# ('STRIKE', 9, 'Strike')
# ('DARK', 4, 'Elec')
# ('ELECTRICITY', 9, 'Ice')
# ('ICE', 9, 'Elec')
# ('PIERCE', 3, 'Pierce')
# ('ELECTRICITY', 3, 'Light')
# ('ICE', 4, 'Wind')
# ('STRIKE', 8, 'Dark')
# ('STRIKE', 4, 'Almighty')
# ('RECOVERY', 7, 'Enhance')
# ('WIND', 7, 'Recovery')
# ('LIGHT & DARK', 8, 'Dark')
# ('WIND', 5, 'Elec')
# ('ELECTRICITY', 3, 'Passive')
# ('PIERCE', 6, 'Ice')
# ('STRIKE', 1, 'Pierce')
# ('LIGHT', 1, 'Enhance')
# ('ELECTRICITY', 6, 'Recovery')
# ('LIGHT', 8, 'Recovery')
# ('SLASH', 8, 'Slash')
# ('SLASH', 3, 'Pierce')
# ('LIGHT & DARK', 6, 'Slash')
# ('FIRE', 5, 'Wind')
# ('FIRE', 9, 'Almighty')
# ('SLASH', 9, 'Fire')
# ('RECOVERY', 7, 'Fire')
# ('RECOVERY', 8, 'Enhance')
# ('WIND', 7, 'Pierce')
# ('ICE', 4, 'Dark')
# ('STRIKE', 4, 'Ice')
# ('RECOVERY', 1, 'Strike')
# ('BAD STATUS', 1, 'Light')
# ('FIRE', 4, 'Passive')
# ('SLASH', 4, 'Wind')
# ('RECOVERY', 2, 'Wind')
# ('LIGHT', 6, 'Passive')
# ('LIGHT', 1, 'Fire')
# ('LIGHT', 8, 'Pierce')
# ('ELECTRICITY', 6, 'Pierce')
# ('BAD STATUS', 1, 'Passive')
# ('ICE', 5, 'Special')
# ('ICE', 6, 'Strike')
# ('WIND', 1, 'Slash')
# ('ICE', 7, 'Wind')
# ('LIGHT & DARK', 4, 'Recovery')
# ('FIRE', 9, 'Ice')
# ('WIND', 3, 'Enhance')
# ('STRIKE', 8, 'Special')
# ('FIRE', 1, 'Almighty')
# ('BAD STATUS', 2, 'Elec')
# ('RECOVERY', 5, 'Bad Status')
# ('LIGHT', 5, 'Light')
# ('WIND', 8, 'Elec')
# ('LIGHT & DARK', 5, 'Bad Status')
# ('LIGHT & DARK', 7, 'Almighty')
# ('RECOVERY', 2, 'Dark')
# ('LIGHT & DARK', 8, 'Special')
# ('ELECTRICITY', 2, 'Enhance')
# ('PIERCE', 3, 'Light')
# ('ELECTRICITY', 9, 'Recovery')
# ('LIGHT & DARK', 2, 'Passive')
# ('RECOVERY', 9, 'Slash')
# ('ELECTRICITY', 7, 'Elec')
# ('LIGHT & DARK', 9, 'Slash')
# ('LIGHT & DARK', 4, 'Pierce')
# ('WIND', 3, 'Fire')
# ('ALL', 1, 'Light')
# ('ICE', 7, 'Dark')
# ('RECOVERY', 4, 'Strike')
# ('ICE', 3, 'Almighty')
# ('PIERCE', 3, 'Passive')
# ('STRIKE', 1, 'Light')
# ('DARK', 9, 'Slash')
# ('PIERCE', 6, 'Recovery')
# ('SLASH', 9, 'Ice')
# ('ELECTRICITY', 2, 'Fire')
# ('ELECTRICITY', 9, 'Pierce')
# ('LIGHT & DARK', 7, 'Ice')
# ('SLASH', 3, 'Light')
# ('STRIKE', 6, 'Almighty')
# ('DARK', 3, 'Special')
# ('DARK', 4, 'Strike')
# ('ICE', 9, 'Strike')
# ('STRIKE', 1, 'Passive')
# ('WIND', 7, 'Light')
# ('DARK', 5, 'Wind')
# ('STRIKE', 4, 'Recovery')
# ('SLASH', 3, 'Passive')
# ('DARK', 7, 'Elec')
# ('PIERCE', 6, 'Pierce')
# ('ICE', 3, 'Ice')
# ('ELECTRICITY', 6, 'Light')
# ('LIGHT', 8, 'Light')
# ('WIND', 5, 'Strike')
# ('ICE', 1, 'Pierce')
# ('DARK', 2, 'Fire')
# ('DARK', 8, 'Bad Status')
# ('FIRE', 9, 'Recovery')
# ('STRIKE', 4, 'Pierce')
# ('LIGHT', 4, 'Enhance')
# ('DARK', 5, 'Dark')
# ('BAD STATUS', 8, 'Enhance')
# ('FIRE', 7, 'Light')
# ('DARK', 1, 'Almighty')
# ('PIERCE', 2, 'Enhance')
# ('LIGHT', 9, 'Elec')
# ('STRIKE', 9, 'Almighty')
# ('PIERCE', 7, 'Elec')
# ('SLASH', 6, 'Light')
# ('BAD STATUS', 4, 'Elec')
# ('FIRE', 7, 'Passive')
# ('LIGHT', 3, 'Slash')
# ('LIGHT & DARK', 4, 'Light')
# ('RECOVERY', 5, 'Wind')
# ('FIRE', 3, 'Enhance')
# ('FIRE', 9, 'Pierce')
# ('LIGHT', 4, 'Fire')
# ('DARK', 6, 'Dark')
# ('BAD STATUS', 8, 'Fire')
# ('SLASH', 6, 'Passive')
# ('FIRE', 1, 'Recovery')
# ('PIERCE', 2, 'Fire')
# ('LIGHT & DARK', 4, 'Passive')
# ('LIGHT', 1, 'Bad Status')
# ('DARK', 1, 'Ice')
# ('SLASH', 2, 'Enhance')
# ('WIND', 4, 'Slash')
# ('ELECTRICITY', 9, 'Light')
# ('BAD STATUS', 3, 'Wind')
# ('LIGHT & DARK', 7, 'Recovery')
# ('WIND', 8, 'Strike')
# ('WIND', 6, 'Enhance')
# ('BAD STATUS', 5, 'Elec')
# ('STRIKE', 9, 'Ice')
# ('RECOVERY', 8, 'Bad Status')
# ('ELECTRICITY', 3, 'Slash')
# ('RECOVERY', 5, 'Dark')
# ('ELECTRICITY', 5, 'Enhance')
# ('ALL', 8, 'Enhance')
# ('PIERCE', 6, 'Light')
# ('RECOVERY', 1, 'Almighty')
# ('LIGHT & DARK', 5, 'Passive')
# ('ICE', 3, 'Recovery')
# ('DARK', 2, 'Ice')
# ('DARK', 5, 'Special')
# ('SLASH', 9, 'Pierce')
# ('LIGHT', 2, 'Bad Status')
# ('LIGHT & DARK', 7, 'Pierce')
# ('ICE', 1, 'Light')
# ('WIND', 6, 'Fire')
# ('STRIKE', 6, 'Recovery')
# ('BAD STATUS', 3, 'Dark')
# ('ICE', 6, 'Almighty')
# ('STRIKE', 4, 'Light')
# ('PIERCE', 5, 'Wind')
# ('WIND', 3, 'Bad Status')
# ('ELECTRICITY', 5, 'Fire')
# ('ICE', 1, 'Passive')
# ('ALL', 8, 'Fire')
# ('BAD STATUS', 1, 'Slash')
# ('ICE', 3, 'Pierce')
# ('RECOVERY', 1, 'Ice')
# ('DARK', 6, 'Special')
# ('DARK', 7, 'Strike')
# ('ELECTRICITY', 2, 'Bad Status')
# ('ELECTRICITY', 4, 'Almighty')
# ('STRIKE', 4, 'Passive')
# ('FIRE', 2, 'Elec')
# ('DARK', 8, 'Wind')
# ('FIRE', 9, 'Light')
# ('ICE', 6, 'Ice')
# ('ALL', 9, 'Slash')
# ('PIERCE', 5, 'Dark')
# ('PIERCE', 1, 'Almighty')
# ('RECOVERY', 4, 'Almighty')
# ('PIERCE', 9, 'Elec')
# ('WIND', 9, 'Wind')
# ('DARK', 1, 'Recovery')
# ('LIGHT', 5, 'Slash')
# ('LIGHT', 9, 'Strike')
# ('ELECTRICITY', 4, 'Ice')
# ('PIERCE', 3, 'Slash')
# ('LIGHT', 7, 'Enhance')
# ('STRIKE', 9, 'Recovery')
# ('DARK', 8, 'Dark')
# ('ELECTRICITY', 8, 'Wind')
# ('ALL', 7, 'Elec')
# ('DARK', 4, 'Almighty')
# ('ICE', 9, 'Almighty')
# ('BAD STATUS', 3, 'Special')
# ('BAD STATUS', 4, 'Strike')
# ('STRIKE', 7, 'Elec')
# ('SLASH', 9, 'Light')
# ('DARK', 1, 'Pierce')
# ('STRIKE', 1, 'Slash')
# ('PIERCE', 1, 'Ice')
# ('LIGHT & DARK', 7, 'Light')
# ('RECOVERY', 4, 'Ice')
# ('RECOVERY', 8, 'Wind')
# ('FIRE', 6, 'Enhance')
# ('WIND', 9, 'Dark')
# ('WIND', 5, 'Almighty')
# ('LIGHT', 7, 'Fire')
# ('STRIKE', 3, 'Enhance')
# ('STRIKE', 2, 'Fire')
# ('SLASH', 3, 'Slash')
# ('SLASH', 9, 'Passive')
# ('RECOVERY', 7, 'Passive')
# ('BAD STATUS', 5, 'Strike')
# ('ELECTRICITY', 8, 'Dark')
# ('LIGHT', 2, 'Wind')
# ('LIGHT', 4, 'Bad Status')
# ('DARK', 4, 'Ice')
# ('ICE', 9, 'Ice')
# ('BAD STATUS', 8, 'Bad Status')
# ('SLASH', 5, 'Enhance')
# ('WIND', 7, 'Slash')
# ('BAD STATUS', 6, 'Wind')
# ('LIGHT & DARK', 3, 'Enhance')
# ('PIERCE', 2, 'Bad Status')
# ('PIERCE', 4, 'Almighty')
# ('DARK', 2, 'Pierce')
# ('LIGHT', 1, 'Passive')
# ('RECOVERY', 1, 'Recovery')
# ('LIGHT & DARK', 8, 'Elec')
# ('PIERCE', 5, 'Special')
# ('LIGHT', 8, 'Slash')
# ('ELECTRICITY', 6, 'Slash')
# ('SLASH', 1, 'Elec')
# ('ICE', 8, 'Enhance')
# ('STRIKE', 3, 'Fire')
# ('WIND', 5, 'Ice')
# ('ALL', 3, 'Special')
# ('ICE', 6, 'Recovery')
# ('LIGHT & DARK', 3, 'Fire')
# ('ICE', 4, 'Elec')
# ('LIGHT', 2, 'Dark')
# ('SLASH', 2, 'Bad Status')
# ('FIRE', 7, 'Slash')
# ('BAD STATUS', 6, 'Dark')
# ('BAD STATUS', 2, 'Almighty')
# ('PIERCE', 4, 'Ice')
# ('PIERCE', 8, 'Wind')
# ('WIND', 6, 'Bad Status')
# ('ELECTRICITY', 4, 'Recovery')
# ('WIND', 8, 'Almighty')
# ('SLASH', 6, 'Slash')
# ('WIND', 9, 'Special')
# ('LIGHT & DARK', 4, 'Slash')
# ('WIND', 3, 'Passive')
# ('ELECTRICITY', 5, 'Bad Status')
# ('FIRE', 1, 'Dark')
# ('ELECTRICITY', 7, 'Almighty')
# ('FIRE', 5, 'Elec')
# ('ELECTRICITY', 8, 'Special')
# ('DARK', 1, 'Light')
# ('PIERCE', 1, 'Recovery')
# ('RECOVERY', 4, 'Recovery')
# ('PIERCE', 9, 'Strike')
# ('ELECTRICITY', 9, 'Slash')
# ('BAD STATUS', 2, 'Ice')
# ('ELECTRICITY', 4, 'Pierce')
# ('SLASH', 4, 'Elec')
# ('RECOVERY', 2, 'Elec')
# ('PIERCE', 8, 'Dark')
# ('WIND', 8, 'Ice')
# ('ICE', 2, 'Enhance')
# ('DARK', 4, 'Recovery')
# ('ICE', 9, 'Recovery')
# ('DARK', 2, 'Light')
# ('STRIKE', 7, 'Strike')
# ('ELECTRICITY', 7, 'Ice')
# ('ICE', 7, 'Elec')
# ('PIERCE', 6, 'Slash')
# ('ALL', 6, 'Dark')
# ('PIERCE', 1, 'Pierce')
# ('RECOVERY', 4, 'Pierce')
# ('DARK', 7, 'Almighty')
# ('STRIKE', 6, 'Dark')
# ('BAD STATUS', 6, 'Special')
# ('BAD STATUS', 7, 'Strike')
# ('ICE', 1, 'Slash')
# ('WIND', 5, 'Recovery')
# ('BAD STATUS', 8, 'Wind')
# ('DARK', 2, 'Passive')
# ('ICE', 2, 'Fire')
# ('DARK', 4, 'Pierce')
# ('ICE', 9, 'Pierce')
# ('STRIKE', 4, 'Slash')
# ('FIRE', 8, 'Fire')
# ('FIRE', 1, 'Special')
# ('STRIKE', 5, 'Fire')
# ('PIERCE', 4, 'Recovery')
# ('FIRE', 3, 'Wind')
# ('SLASH', 7, 'Fire')
# ('SLASH', 8, 'Enhance')
# ('LIGHT', 9, 'Almighty')
# ('WIND', 5, 'Pierce')
# ('BAD STATUS', 9, 'Wind')
# ('LIGHT & DARK', 6, 'Enhance')
# ('SLASH', 1, 'Strike')
# ('PIERCE', 7, 'Almighty')
# ('SLASH', 2, 'Wind')
# ('LIGHT', 4, 'Passive')
# ('FIRE', 9, 'Slash')
# ('PIERCE', 8, 'Special')
# ('DARK', 5, 'Elec')
# ('ICE', 3, 'Special')
# ('ICE', 4, 'Strike')
# ('FIRE', 6, 'Bad Status')
# ('PIERCE', 4, 'Pierce')
# ('ELECTRICITY', 4, 'Light')
# ('BAD STATUS', 2, 'Recovery')
# ('ALL', 6, 'Special')
# ('SLASH', 8, 'Fire')
# ('STRIKE', 3, 'Bad Status')
# ('FIRE', 3, 'Dark')
# ('LIGHT & DARK', 6, 'Fire')
# ('WIND', 1, 'Enhance')
# ('ALL', 8, 'Wind')
# ('STRIKE', 6, 'Special')
# ('LIGHT', 9, 'Ice')
# ('WIND', 8, 'Recovery')
# ('SLASH', 5, 'Bad Status')
# ('RECOVERY', 3, 'Bad Status')
# ('BAD STATUS', 9, 'Dark')
# ('LIGHT & DARK', 3, 'Bad Status')
# ('LIGHT & DARK', 1, 'Wind')
# ('ELECTRICITY', 4, 'Passive')
# ('PIERCE', 7, 'Ice')
# ('BAD STATUS', 5, 'Almighty')
# ('SLASH', 2, 'Dark')
# ('ELECTRICITY', 7, 'Recovery')
# ('PIERCE', 1, 'Light')
# ('SLASH', 9, 'Slash')
# ('FIRE', 5, 'Strike')
# ('LIGHT & DARK', 7, 'Slash')
# ('ICE', 8, 'Bad Status')
# ('WIND', 6, 'Passive')
# ('BAD STATUS', 2, 'Pierce')
# ('RECOVERY', 9, 'Enhance')
# ('WIND', 1, 'Fire')
# ('WIND', 8, 'Pierce')
# ('LIGHT & DARK', 9, 'Enhance')
# ('SLASH', 4, 'Strike')
# ('RECOVERY', 2, 'Strike')
# ('STRIKE', 5, 'Ice')
# ('PIERCE', 1, 'Passive')
# ('LIGHT & DARK', 2, 'Strike')
# ('ELECTRICITY', 5, 'Passive')
# ('BAD STATUS', 5, 'Ice')
# ('ELECTRICITY', 7, 'Pierce')
# ('LIGHT & DARK', 1, 'Dark')
# ('DARK', 9, 'Enhance')
# ('RECOVERY', 5, 'Elec')
# ('DARK', 1, 'Special')
# ('ICE', 7, 'Strike')
# ('DARK', 7, 'Recovery')
# ('WIND', 5, 'Light')
# ('LIGHT & DARK', 9, 'Fire')
# ('STRIKE', 9, 'Special')
# ('FIRE', 2, 'Almighty')
# ('BAD STATUS', 9, 'Special')
# ('PIERCE', 4, 'Light')
# ('ICE', 5, 'Fire')
# ('LIGHT', 9, 'Recovery')
# ('PIERCE', 4, 'Passive')
# ('FIRE', 2, 'Ice')
# ('STRIKE', 2, 'Light')
# ('LIGHT', 7, 'Light')
# ('PIERCE', 7, 'Recovery')
# ('FIRE', 6, 'Wind')
# ('STRIKE', 3, 'Wind')
# ('STRIKE', 7, 'Almighty')
# ('DARK', 1, 'Slash')
# ('RECOVERY', 1, 'Special')
# ('BAD STATUS', 2, 'Light')
# ('DARK', 5, 'Strike')
# ('LIGHT & DARK', 1, 'Special')
# ('SLASH', 5, 'Wind')
# ('RECOVERY', 3, 'Wind')
# ('LIGHT', 7, 'Passive')
# ('STRIKE', 2, 'Passive')
# ('WIND', 8, 'Light')
# ('LIGHT', 3, 'Enhance')
# ('LIGHT', 9, 'Pierce')
# ('DARK', 8, 'Elec')
# ('ICE', 6, 'Special')
# ('PIERCE', 7, 'Pierce')
# ('ELECTRICITY', 7, 'Light')
# ('BAD STATUS', 5, 'Recovery')
# ('ICE', 8, 'Wind')
# ('STRIKE', 8, 'Almighty')
# ('DARK', 2, 'Slash')
# ('WIND', 4, 'Enhance')
# ('STRIKE', 7, 'Ice')
# ('SLASH', 8, 'Bad Status')
# ('DARK', 3, 'Fire')
# ('LIGHT & DARK', 6, 'Bad Status')
# ('WIND', 9, 'Elec')
# ('ELECTRICITY', 7, 'Passive')
# ('LIGHT & DARK', 8, 'Almighty')
# ('STRIKE', 5, 'Pierce')
# ('RECOVERY', 3, 'Dark')
# ('ELECTRICITY', 3, 'Enhance')
# ('SLASH', 1, 'Almighty')
# ('LIGHT & DARK', 3, 'Passive')
# ('ELECTRICITY', 8, 'Elec')
# ('BAD STATUS', 5, 'Pierce')
# ('WIND', 4, 'Fire')
# ('ICE', 8, 'Dark')
# ('RECOVERY', 4, 'Special')
# ('RECOVERY', 5, 'Strike')
# ('ICE', 4, 'Almighty')
# ('STRIKE', 8, 'Ice')
# ('RECOVERY', 6, 'Wind')
# ('WIND', 1, 'Bad Status')
# ('ELECTRICITY', 3, 'Fire')
# ('LIGHT & DARK', 8, 'Ice')
# ('RECOVERY', 8, 'Elec')
# ('FIRE', 2, 'Recovery')
# ('DARK', 4, 'Special')
# ('ICE', 9, 'Special')
# ('BAD STATUS', 1, 'Enhance')
# ('LIGHT', 2, 'Elec')
# ('FIRE', 5, 'Almighty')
# ('BAD STATUS', 6, 'Elec')
# ('RECOVERY', 9, 'Bad Status')
# ('ELECTRICITY', 4, 'Slash')
# ('ICE', 4, 'Ice')
# ('LIGHT & DARK', 9, 'Bad Status')
# ('LIGHT', 9, 'Light')
# ('RECOVERY', 6, 'Dark')
# ('SLASH', 4, 'Almighty')
# ('ALL', 9, 'Enhance')
# ('PIERCE', 7, 'Light')
# ('FIRE', 2, 'Pierce')
# ('RECOVERY', 2, 'Almighty')
# ('BAD STATUS', 1, 'Fire')
# ('DARK', 9, 'Bad Status')
# ('ICE', 2, 'Light')
# ('PIERCE', 1, 'Slash')
# ('LIGHT', 5, 'Enhance')
# ('STRIKE', 7, 'Recovery')
# ('FIRE', 8, 'Light')
# ('PIERCE', 7, 'Passive')
# ('ICE', 7, 'Almighty')
# ('FIRE', 5, 'Ice')
# ('PIERCE', 3, 'Enhance')
# ('STRIKE', 5, 'Light')
# ('ICE', 2, 'Passive')
# ('PIERCE', 8, 'Elec')
# ('SLASH', 7, 'Light')
# ('BAD STATUS', 5, 'Light')
# ('FIRE', 8, 'Passive')
# ('RECOVERY', 2, 'Ice')
# ('DARK', 8, 'Strike')
# ('ALL', 1, 'Enhance')
# ('STRIKE', 5, 'Passive')
# ('LIGHT', 5, 'Fire')
# ('STRIKE', 1, 'Enhance')
# ('STRIKE', 8, 'Recovery')
# ('DARK', 7, 'Dark')
# ('STRIKE', 7, 'Pierce')
# ('SLASH', 7, 'Passive')
# ('PIERCE', 3, 'Fire')
# ('SLASH', 3, 'Enhance')
# ('ICE', 7, 'Ice')
# ('WIND', 5, 'Slash')
# ('BAD STATUS', 4, 'Wind')
# ('LIGHT & DARK', 8, 'Recovery')
# ('WIND', 9, 'Strike')
# ('SLASH', 1, 'Recovery')
# ('WIND', 7, 'Enhance')
# ('RECOVERY', 6, 'Special')
# ('DARK', 6, 'Fire')
# ('STRIKE', 1, 'Fire')
# ('STRIKE', 8, 'Pierce')
# ('PIERCE', 4, 'Slash')
# ('LIGHT', 8, 'Enhance')
# ('ELECTRICITY', 6, 'Enhance')
# ('DARK', 5, 'Almighty')
# ('LIGHT & DARK', 6, 'Passive')
# ('ICE', 4, 'Recovery')
# ('LIGHT', 3, 'Bad Status')
# ('LIGHT & DARK', 8, 'Pierce')
# ('WIND', 7, 'Fire')
# ('BAD STATUS', 4, 'Dark')
# ('RECOVERY', 8, 'Strike')
# ('BAD STATUS', 8, 'Elec')
# ('LIGHT', 7, 'Slash')
# ('STRIKE', 2, 'Slash')
# ('RECOVERY', 9, 'Wind')
# ('WIND', 2, 'Wind')
# ('FIRE', 7, 'Enhance')
# ('WIND', 4, 'Bad Status')
# ('ELECTRICITY', 6, 'Fire')
# ('LIGHT', 8, 'Fire')
# ('BAD STATUS', 2, 'Slash')
# ('LIGHT', 2, 'Strike')
# ('FIRE', 5, 'Recovery')
# ('ICE', 4, 'Pierce')
# ('DARK', 7, 'Special')
# ('SLASH', 6, 'Enhance')
# ('DARK', 5, 'Ice')
# ('ELECTRICITY', 1, 'Wind')
# ('WIND', 8, 'Slash')
# ('ELECTRICITY', 3, 'Bad Status')
# ('FIRE', 3, 'Elec')
# ('LIGHT & DARK', 4, 'Enhance')
# ('DARK', 9, 'Wind')
# ('SLASH', 4, 'Recovery')
# ('RECOVERY', 2, 'Recovery')
# ('BAD STATUS', 9, 'Elec')
# ('ELECTRICITY', 7, 'Slash')
# ('SLASH', 2, 'Elec')
# ('RECOVERY', 9, 'Dark')
# ('ELECTRICITY', 9, 'Enhance')
# ('WIND', 2, 'Dark')
# ('RECOVERY', 5, 'Almighty')
# ('ELECTRICITY', 2, 'Strike')
# ('ICE', 7, 'Recovery')
# ('LIGHT', 6, 'Bad Status')
# ('ALL', 4, 'Special')
# ('LIGHT & DARK', 9, 'Passive')
# ('LIGHT & DARK', 4, 'Fire')
# ('ICE', 5, 'Light')
# ('ELECTRICITY', 1, 'Dark')
# ('RECOVERY', 2, 'Pierce')
# ('DARK', 9, 'Dark')
# ('BAD STATUS', 1, 'Bad Status')
# ('ALL', 8, 'Elec')
# ('BAD STATUS', 3, 'Almighty')
# ('BAD STATUS', 4, 'Special')
# ('STRIKE', 8, 'Light')
# ('PIERCE', 6, 'Enhance')
# ('LIGHT & DARK', 1, 'Elec')
# ('ELECTRICITY', 9, 'Fire')
# ('ICE', 5, 'Passive')
# ('ICE', 1, 'Enhance')
# ('ICE', 7, 'Pierce')
# ('RECOVERY', 5, 'Ice')
# ('LIGHT & DARK', 8, 'Light')
# ('ALL', 9, 'Bad Status')
# ('STRIKE', 8, 'Passive')
# ('STRIKE', 4, 'Enhance')
# ('PIERCE', 6, 'Fire')
# ('LIGHT', 5, 'Bad Status')
# ('BAD STATUS', 3, 'Ice')
# ('LIGHT', 3, 'Wind')
# ('BAD STATUS', 7, 'Wind')
# ('PIERCE', 3, 'Bad Status')
# ('PIERCE', 9, 'Dark')
# ('PIERCE', 5, 'Almighty')
# ('DARK', 5, 'Recovery')
# ('WIND', 2, 'Special')
# ('LIGHT', 9, 'Slash')
# ('FIRE', 9, 'Enhance')
# ('DARK', 3, 'Light')
# ('STRIKE', 4, 'Fire')
# ('PIERCE', 7, 'Slash')
# ('ALL', 7, 'Dark')
# ('DARK', 8, 'Almighty')
# ('ELECTRICITY', 1, 'Special')
# ('STRIKE', 1, 'Bad Status')
# ('BAD STATUS', 8, 'Strike')
# ('PIERCE', 2, 'Strike')
# ('DARK', 3, 'Passive')
# ('LIGHT', 3, 'Dark')
# ('SLASH', 3, 'Bad Status')
# ('FIRE', 8, 'Slash')
# ('BAD STATUS', 7, 'Dark')
# ('DARK', 5, 'Pierce')
# ('PIERCE', 5, 'Ice')
# ('STRIKE', 5, 'Slash')
# ('WIND', 7, 'Bad Status')
# ('FIRE', 9, 'Fire')
# ('RECOVERY', 2, 'Light')
# ('WIND', 9, 'Almighty')
# ('FIRE', 2, 'Special')
# ('SLASH', 7, 'Slash')
# ('FIRE', 3, 'Strike')
# ('BAD STATUS', 5, 'Slash')
# ('FIRE', 4, 'Wind')
# ('WIND', 4, 'Passive')
# ('BAD STATUS', 9, 'Strike')
# ('LIGHT', 8, 'Bad Status')
# ('DARK', 8, 'Ice')
# ('SLASH', 9, 'Enhance')
# ('ELECTRICITY', 8, 'Almighty')
# ('ELECTRICITY', 6, 'Bad Status')
# ('LIGHT', 6, 'Wind')
# ('FIRE', 6, 'Elec')
# ('LIGHT & DARK', 7, 'Enhance')
# ('SLASH', 2, 'Strike')
# ('STRIKE', 3, 'Elec')
# ('DARK', 6, 'Pierce')
# ('RECOVERY', 5, 'Recovery')
# ('PIERCE', 9, 'Special')
# ('SLASH', 1, 'Dark')
# ('SLASH', 5, 'Elec')
# ('RECOVERY', 3, 'Elec')
# ('WIND', 9, 'Ice')
# ('FIRE', 1, 'Fire')
# ('FIRE', 7, 'Bad Status')
# ('RECOVERY', 8, 'Almighty')
# ('ELECTRICITY', 5, 'Strike')
# ('BAD STATUS', 3, 'Recovery')
# ('FIRE', 4, 'Dark')
# ('LIGHT & DARK', 7, 'Fire')
# ('STRIKE', 7, 'Special')
# ('ELECTRICITY', 8, 'Ice')
# ('LIGHT', 6, 'Dark')
# ('LIGHT & DARK', 1, 'Strike')
# ('SLASH', 6, 'Bad Status')
# ('ICE', 8, 'Elec')
# ('LIGHT', 2, 'Almighty')
# ('RECOVERY', 5, 'Pierce')
# ('LIGHT & DARK', 4, 'Bad Status')
# ('BAD STATUS', 6, 'Almighty')
# ('LIGHT & DARK', 2, 'Wind')
# ('BAD STATUS', 7, 'Special')
# ('ICE', 3, 'Fire')
# ('BAD STATUS', 3, 'Pierce')
# ('ELECTRICITY', 9, 'Bad Status')
# ('FIRE', 5, 'Dark')
# ('DARK', 5, 'Light')
# ('STRIKE', 6, 'Fire')
# ('PIERCE', 5, 'Recovery')
# ('ALL', 5, 'Almighty')
# ('LIGHT', 2, 'Ice')
# ('SLASH', 4, 'Dark')
# ('BAD STATUS', 6, 'Ice')
# ('STRIKE', 1, 'Wind')
# ('LIGHT & DARK', 2, 'Dark')
# ('RECOVERY', 6, 'Elec')
# ('SLASH', 1, 'Special')
# ('PIERCE', 6, 'Bad Status')
# ('PIERCE', 8, 'Almighty')
# ('SLASH', 3, 'Wind')
# ('LIGHT', 5, 'Passive')
# ('DARK', 1, 'Enhance')
# ('DARK', 8, 'Recovery')
# ('ICE', 1, 'Bad Status')
# ('DARK', 6, 'Light')
# ('FIRE', 1, 'Ice')
# ('FIRE', 4, 'Special')
# ('ICE', 4, 'Special')
# ('PIERCE', 5, 'Pierce')
# ('STRIKE', 4, 'Bad Status')
# ('ICE', 5, 'Slash')
# ('WIND', 9, 'Recovery')
# ('DARK', 6, 'Passive')
# ('DARK', 1, 'Fire')
# ('DARK', 2, 'Enhance')
# ('DARK', 8, 'Pierce')
# ('PIERCE', 8, 'Ice')
# ('STRIKE', 8, 'Slash')
# ('SLASH', 3, 'Dark')
# ('ELECTRICITY', 8, 'Recovery')
# ('STRIKE', 9, 'Fire')
# ('FIRE', 5, 'Special')
# ('FIRE', 6, 'Strike')
# ('LIGHT & DARK', 8, 'Slash')
# ('FIRE', 7, 'Wind')
# ('WIND', 7, 'Passive')
# ('FIRE', 9, 'Bad Status')
# ('STRIKE', 3, 'Strike')
# ('WIND', 9, 'Pierce')
# ('SLASH', 4, 'Special')
# ('RECOVERY', 2, 'Special')
# ('RECOVERY', 3, 'Strike')
# ('SLASH', 5, 'Strike')
# ('STRIKE', 6, 'Ice')
# ('BAD STATUS', 3, 'Light')
# ('LIGHT & DARK', 2, 'Special')
# ('LIGHT & DARK', 3, 'Strike')
# ('SLASH', 6, 'Wind')
# ('RECOVERY', 8, 'Recovery')
# ('ELECTRICITY', 6, 'Passive')
# ('LIGHT', 8, 'Passive')
# ('ELECTRICITY', 8, 'Pierce')
# ('SLASH', 8, 'Elec')
# ('BAD STATUS', 3, 'Passive')
# ('ICE', 7, 'Special')
# ('ICE', 8, 'Strike')
# ('LIGHT', 2, 'Recovery')
# ('BAD STATUS', 6, 'Recovery')
# ('DARK', 3, 'Slash')
# ('FIRE', 7, 'Dark')
# ('FIRE', 3, 'Almighty')
# ('SLASH', 9, 'Bad Status')
# ('RECOVERY', 7, 'Bad Status')
# ('RECOVERY', 1, 'Fire')
# ('LIGHT & DARK', 7, 'Bad Status')
# ('BAD STATUS', 9, 'Almighty')
# ('LIGHT & DARK', 5, 'Wind')
# ('SLASH', 6, 'Dark')
# ('ELECTRICITY', 4, 'Enhance')
# ('SLASH', 2, 'Almighty')
# ('PIERCE', 5, 'Light')
# ('LIGHT', 2, 'Pierce')
# ('ICE', 6, 'Fire')
# ('BAD STATUS', 6, 'Pierce')
# ('RECOVERY', 2, 'Slash')
# ('PIERCE', 5, 'Passive')
# ('ICE', 1, 'Wind')
# ('RECOVERY', 6, 'Strike')
# ('FIRE', 3, 'Ice')
# ('PIERCE', 1, 'Enhance')
# ('PIERCE', 8, 'Recovery')
# ('ELECTRICITY', 9, 'Passive')
# ('ELECTRICITY', 4, 'Fire')
# ('BAD STATUS', 9, 'Ice')
# ('LIGHT & DARK', 5, 'Dark')
# ('RECOVERY', 9, 'Elec')
# ('WIND', 2, 'Elec')
# ('ICE', 7, 'Slash')
# ('LIGHT & DARK', 1, 'Almighty')
# ('SLASH', 2, 'Ice')
# ('WIND', 9, 'Light')
# ('ELECTRICITY', 1, 'Elec')
# ('PIERCE', 6, 'Passive')
# ('DARK', 9, 'Elec')
# ('PIERCE', 1, 'Fire')
# ('RECOVERY', 4, 'Fire')
# ('PIERCE', 8, 'Pierce')
# ('ICE', 1, 'Dark')
# ('ELECTRICITY', 8, 'Light')
# ('WIND', 5, 'Enhance')
# ('LIGHT & DARK', 1, 'Ice')
# ('DARK', 4, 'Fire')
# ('ICE', 9, 'Fire')
# ('ELECTRICITY', 8, 'Passive')
# ('STRIKE', 6, 'Pierce')
# ('PIERCE', 4, 'Enhance')
# ('WIND', 5, 'Fire')
# ('DARK', 5, 'Slash')
# ('RECOVERY', 5, 'Special')
# ('SLASH', 8, 'Strike')
# ('BAD STATUS', 6, 'Light')
# ('FIRE', 9, 'Passive')
# ('LIGHT & DARK', 5, 'Special')
# ('SLASH', 9, 'Wind')
# ('RECOVERY', 7, 'Wind')
# ('STRIKE', 2, 'Enhance')
# ('DARK', 2, 'Bad Status')
# ('FIRE', 3, 'Recovery')
# ('BAD STATUS', 6, 'Passive')
# ('PIERCE', 4, 'Fire')
# ('LIGHT', 1, 'Wind')
# ('BAD STATUS', 2, 'Enhance')
# ('FIRE', 1, 'Light')
# ('BAD STATUS', 9, 'Recovery')
# ('DARK', 6, 'Slash')
# ('LIGHT', 3, 'Elec')
# ('SLASH', 2, 'Recovery')
# ('WIND', 8, 'Enhance')
# ('FIRE', 6, 'Almighty')
# ('BAD STATUS', 7, 'Elec')
# ('WIND', 1, 'Strike')
# ('FIRE', 1, 'Passive')
# ('STRIKE', 9, 'Pierce')
# ('RECOVERY', 7, 'Dark')
# ('ELECTRICITY', 7, 'Enhance')
# ('SLASH', 5, 'Almighty')
# ('RECOVERY', 3, 'Almighty')
# ('PIERCE', 8, 'Light')
# ('FIRE', 3, 'Pierce')
# ('LIGHT & DARK', 7, 'Passive')
# ('BAD STATUS', 2, 'Fire')
# ('BAD STATUS', 9, 'Pierce')
# ('ALL', 8, 'Recovery')
# ('ICE', 3, 'Light')
# ('LIGHT', 1, 'Dark')
# ('WIND', 8, 'Fire')
# ('SLASH', 2, 'Pierce')
# ('ALL', 6, 'Light')
# ('PIERCE', 8, 'Passive')
# ('LIGHT & DARK', 1, 'Recovery')
# ('WIND', 2, 'Strike')
# ('RECOVERY', 9, 'Strike')
# ('ICE', 8, 'Almighty')
# ('STRIKE', 6, 'Light')
# ('WIND', 3, 'Wind')
# ('RECOVERY', 8, 'Dark')
# ('ELECTRICITY', 7, 'Fire')
# ('ICE', 3, 'Passive')
# ('BAD STATUS', 3, 'Slash')
# ('ELECTRICITY', 1, 'Strike')
# ('RECOVERY', 3, 'Ice')
# ('DARK', 8, 'Special')
# ('DARK', 9, 'Strike')
# ('ELECTRICITY', 4, 'Bad Status')
# ('ELECTRICITY', 2, 'Wind')
# ('STRIKE', 6, 'Passive')
# ('FIRE', 4, 'Elec')
# ('RECOVERY', 1, 'Pierce')
# ('LIGHT', 6, 'Elec')
# ('LIGHT & DARK', 1, 'Pierce')
# ('ICE', 8, 'Ice')
# ('PIERCE', 1, 'Bad Status')
# ('WIND', 3, 'Dark')
# ('RECOVERY', 6, 'Almighty')
# ('ICE', 6, 'Pierce')
# ('DARK', 7, 'Fire')
# ('ELECTRICITY', 2, 'Dark')
# ('PIERCE', 5, 'Slash')
# ('LIGHT', 9, 'Enhance')
# ('DARK', 2, 'Wind')
# ('LIGHT', 1, 'Special')
# ('PIERCE', 7, 'Enhance')
# ('STRIKE', 9, 'Light')
# ('LIGHT & DARK', 2, 'Elec')
# ('DARK', 1, 'Passive')
# ('RECOVERY', 8, 'Special')
# ('BAD STATUS', 9, 'Light')
# ('RECOVERY', 6, 'Ice')
# ('WIND', 5, 'Bad Status')
# ('STRIKE', 9, 'Passive')
# ('FIRE', 8, 'Enhance')
# ('LIGHT', 9, 'Fire')
# ('STRIKE', 5, 'Enhance')
# ('LIGHT', 2, 'Special')
# ('LIGHT', 3, 'Strike')
# ('FIRE', 6, 'Recovery')
# ('PIERCE', 7, 'Fire')
# ('SLASH', 7, 'Enhance')
# ('LIGHT', 4, 'Wind')
# ('WIND', 9, 'Slash')
# ('BAD STATUS', 5, 'Enhance')
# ('PIERCE', 4, 'Bad Status')
# ('STRIKE', 1, 'Elec')
# ('PIERCE', 2, 'Wind')
# ('SLASH', 5, 'Recovery')
# ('RECOVERY', 3, 'Recovery')
# ('WIND', 3, 'Special')
# ('ELECTRICITY', 8, 'Slash')
# ('RECOVERY', 1, 'Light')
# ('SLASH', 3, 'Elec')
# ('LIGHT & DARK', 1, 'Light')
# ('ELECTRICITY', 2, 'Special')
# ('ELECTRICITY', 3, 'Strike')
# ('ICE', 8, 'Recovery')
# ('DARK', 7, 'Ice')
# ('LIGHT', 7, 'Bad Status')
# ('ALL', 5, 'Special')
# ('BAD STATUS', 5, 'Fire')
# ('STRIKE', 2, 'Bad Status')
# ('ELECTRICITY', 4, 'Wind')
# ('RECOVERY', 1, 'Passive')
# ('ICE', 6, 'Light')
# ('LIGHT', 4, 'Dark')
# ('RECOVERY', 3, 'Pierce')
# ('BAD STATUS', 2, 'Bad Status')
# ('BAD STATUS', 8, 'Dark')
# ('BAD STATUS', 4, 'Almighty')
# ('PIERCE', 2, 'Dark')
# ('WIND', 8, 'Bad Status')
# ('WIND', 6, 'Wind')
# ('ICE', 6, 'Passive')
# ('FIRE', 4, 'Strike')
# ('BAD STATUS', 6, 'Slash')
# ('LIGHT', 6, 'Strike')
# ('ICE', 8, 'Pierce')
# ('ELECTRICITY', 7, 'Bad Status')
# ('ELECTRICITY', 5, 'Wind')
# ('FIRE', 7, 'Elec')
# ('BAD STATUS', 1, 'Strike')
# ('RECOVERY', 6, 'Recovery')
# ('BAD STATUS', 4, 'Ice')
# ('FIRE', 1, 'Slash')
# ('SLASH', 6, 'Elec')
# ('RECOVERY', 4, 'Light')
# ('LIGHT & DARK', 4, 'Elec')
# ('WIND', 6, 'Dark')
# ('FIRE', 2, 'Fire')
# ('RECOVERY', 9, 'Almighty')
# ('WIND', 2, 'Almighty')
# ('ALL', 9, 'Strike')
# ('RECOVERY', 4, 'Passive')
# ('DARK', 4, 'Light')
# ('ICE', 9, 'Light')
# ('ELECTRICITY', 5, 'Dark')
# ('PIERCE', 8, 'Slash')
# ('ALL', 8, 'Dark')
# ('ELECTRICITY', 1, 'Almighty')
# ('RECOVERY', 6, 'Pierce')
# ('DARK', 9, 'Almighty')
# ('LIGHT', 4, 'Special')
# ('BAD STATUS', 8, 'Special')
# ('ICE', 3, 'Slash')
# ('LIGHT & DARK', 5, 'Elec')
# ('PIERCE', 2, 'Special')
# ('DARK', 4, 'Passive')
# ('ICE', 9, 'Passive')
# ('PIERCE', 3, 'Strike')
# ('PIERCE', 4, 'Wind')
# ('ICE', 5, 'Enhance')
# ('RECOVERY', 9, 'Ice')
# ('STRIKE', 6, 'Slash')
# ('WIND', 2, 'Ice')
# ('ALL', 7, 'Fire')
# ('STRIKE', 7, 'Fire')
# ('FIRE', 3, 'Special')
# ('STRIKE', 8, 'Enhance')
# ('STRIKE', 1, 'Strike')
# ('ICE', 1, 'Elec')
# ('WIND', 5, 'Passive')
# ('ELECTRICITY', 1, 'Ice')
# ('LIGHT', 9, 'Bad Status')
# ('DARK', 9, 'Ice')
# ('STRIKE', 2, 'Wind')
# ('LIGHT', 7, 'Wind')
# ('LIGHT & DARK', 8, 'Enhance')
# ('SLASH', 2, 'Special')
# ('SLASH', 3, 'Strike')
# ('PIERCE', 7, 'Bad Status')
# ('STRIKE', 4, 'Elec')
# ('PIERCE', 9, 'Almighty')
# ('DARK', 7, 'Pierce')
# ('WIND', 6, 'Special')
# ('ICE', 2, 'Bad Status')
# ('STRIKE', 8, 'Fire')
# ('FIRE', 8, 'Bad Status')
# ('ELECTRICITY', 5, 'Special')
# ('BAD STATUS', 4, 'Recovery')
# ('ALL', 8, 'Special')
# ('STRIKE', 5, 'Bad Status')
# ('LIGHT & DARK', 8, 'Fire')
# ('LIGHT', 7, 'Dark')
# ('SLASH', 7, 'Bad Status')
# ('STRIKE', 2, 'Dark')
# ('LIGHT', 3, 'Almighty')
# ('DARK', 3, 'Enhance')
# ('BAD STATUS', 5, 'Bad Status')
# ('BAD STATUS', 7, 'Almighty')
# ('LIGHT & DARK', 3, 'Wind')
# ('STRIKE', 9, 'Slash')
# ('PIERCE', 9, 'Ice')
# ('RECOVERY', 6, 'Light')
# ('BAD STATUS', 2, 'Passive')
# ('FIRE', 7, 'Strike')
# ('BAD STATUS', 9, 'Slash')
# ('ICE', 4, 'Fire')
# ('BAD STATUS', 4, 'Pierce')
# ('WIND', 8, 'Passive')
# ('ALL', 7, 'Ice')
# ('FIRE', 6, 'Dark')
# ('SLASH', 6, 'Strike')
# ('STRIKE', 3, 'Dark')
# ('LIGHT & DARK', 4, 'Strike')
# ('RECOVERY', 2, 'Enhance')
# ('RECOVERY', 9, 'Recovery')
# ('WIND', 2, 'Recovery')
# ('LIGHT', 3, 'Ice')
# ('SLASH', 5, 'Dark')
# ('BAD STATUS', 7, 'Ice')
# ('SLASH', 9, 'Elec')
# ('LIGHT & DARK', 3, 'Dark')
# ('RECOVERY', 7, 'Elec')
# ('FIRE', 5, 'Fire')
# ('ELECTRICITY', 1, 'Recovery')
# ('ICE', 7, 'Enhance')
# ('DARK', 9, 'Recovery')
# ('ELECTRICITY', 9, 'Strike')
# ('RECOVERY', 1, 'Slash')
# ('LIGHT', 1, 'Elec')
# ('LIGHT & DARK', 1, 'Slash')
# ('DARK', 7, 'Light')
# ('FIRE', 4, 'Almighty')
# ('SLASH', 4, 'Fire')
# ('RECOVERY', 2, 'Fire')
# ('LIGHT & DARK', 5, 'Strike')
# ('LIGHT', 6, 'Almighty')
# ('RECOVERY', 9, 'Pierce')
# ('WIND', 2, 'Pierce')
# ('ICE', 6, 'Slash')
# ('SLASH', 1, 'Ice')
# ('DARK', 7, 'Passive')
# ('ELECTRICITY', 1, 'Pierce')
# ('ICE', 7, 'Fire')
# ('DARK', 9, 'Pierce')
# ('ICE', 1, 'Strike')
# ('ICE', 2, 'Wind')
# ('FIRE', 6, 'Special')
# ('FIRE', 4, 'Ice')
# ('PIERCE', 9, 'Recovery')
# ('STRIKE', 3, 'Special')
# ('FIRE', 8, 'Wind')
# ('LIGHT', 6, 'Ice')
# ('STRIKE', 4, 'Strike')
# ('ALL', 9, 'Almighty')
# ('STRIKE', 5, 'Wind')
# ('WIND', 3, 'Elec')
# ('SLASH', 5, 'Special')
# ('LIGHT & DARK', 2, 'Almighty')
# ('RECOVERY', 3, 'Special')
# ('BAD STATUS', 4, 'Light')
# ('LIGHT & DARK', 3, 'Special')
# ('SLASH', 7, 'Wind')
# ('LIGHT', 9, 'Passive')
# ('DARK', 5, 'Enhance')
# ('RECOVERY', 4, 'Slash')
# ('ELECTRICITY', 2, 'Elec')
# ('ICE', 5, 'Bad Status')
# ('BAD STATUS', 4, 'Passive')
# ('ICE', 8, 'Special')
# ('LIGHT', 3, 'Recovery')
# ('PIERCE', 9, 'Pierce')
# ('ICE', 2, 'Dark')
# ('BAD STATUS', 7, 'Recovery')
# ('STRIKE', 8, 'Bad Status')
# ('ALL', 9, 'Ice')
# ('DARK', 4, 'Slash')
# ('ICE', 9, 'Slash')
# ('FIRE', 8, 'Dark')
# ('SLASH', 4, 'Ice')
# ('SLASH', 8, 'Wind')
# ('LIGHT & DARK', 2, 'Ice')
# ('STRIKE', 1, 'Almighty')
# ('DARK', 6, 'Enhance')
# ('LIGHT & DARK', 8, 'Bad Status')
# ('DARK', 5, 'Fire')
# ('LIGHT & DARK', 6, 'Wind')
# ('SLASH', 7, 'Dark')
# ('SLASH', 3, 'Almighty')
# ('WIND', 2, 'Light')
# ('BAD STATUS', 5, 'Passive')
# ('LIGHT', 3, 'Pierce')
# ('BAD STATUS', 7, 'Pierce')
# ('DARK', 2, 'Elec')
# ('ELECTRICITY', 1, 'Light')
# ('SLASH', 9, 'Strike')
# ('RECOVERY', 7, 'Strike')
# ('LIGHT & DARK', 7, 'Strike')
# ('WIND', 1, 'Wind')
# ('SLASH', 8, 'Dark')
# ('DARK', 3, 'Bad Status')
# ('LIGHT & DARK', 6, 'Dark')
# ('LIGHT', 1, 'Strike')
# ('FIRE', 4, 'Recovery')
# ('SLASH', 3, 'Ice')
# 1655

# %%
# Out:
# 99
# 36

# %%
a = []
list_of_row = []
index = 0
for key in dict_constraints_keys:
    coverage_index_list = dict_constraints[key]
    list_of_row = []
    print(key, index)
    for i in range(len(filtered_recipes)):
        if i == 0:
            g = 0
        if i in coverage_index_list:
            list_of_row.append(1)
        else:
            list_of_row.append(0)
    a.append(list_of_row)
    list_of_row = []
    index += 1
# Out:
# ('ALL', 1, 'Bad Status') 0
# ('ALL', 1, 'Elec') 1
# ('ALL', 1, 'Fire') 2
# ('ALL', 1, 'Ice') 3
# ('ALL', 1, 'Passive') 4
# ('ALL', 1, 'Pierce') 5
# ('ALL', 1, 'Recovery') 6
# ('ALL', 1, 'Slash') 7
# ('ALL', 1, 'Strike') 8
# ('ALL', 1, 'Wind') 9
# ('ALL', 2, 'Almighty') 10
# ('ALL', 2, 'Bad Status') 11
# ('ALL', 2, 'Dark') 12
# ('ALL', 2, 'Elec') 13
# ('ALL', 2, 'Enhance') 14
# ('ALL', 2, 'Fire') 15
# ('ALL', 2, 'Ice') 16
# ('ALL', 2, 'Light') 17
# ('ALL', 2, 'Passive') 18
# ('ALL', 2, 'Pierce') 19
# ('ALL', 2, 'Recovery') 20
# ('ALL', 2, 'Slash') 21
# ('ALL', 2, 'Strike') 22
# ('ALL', 2, 'Wind') 23
# ('ALL', 3, 'Almighty') 24
# ('ALL', 3, 'Bad Status') 25
# ('ALL', 3, 'Dark') 26
# ('ALL', 3, 'Elec') 27
# ('ALL', 3, 'Enhance') 28
# ('ALL', 3, 'Fire') 29
# ('ALL', 3, 'Ice') 30
# ('ALL', 3, 'Light') 31
# ('ALL', 3, 'Passive') 32
# ('ALL', 3, 'Pierce') 33
# ('ALL', 3, 'Recovery') 34
# ('ALL', 3, 'Slash') 35
# ('ALL', 3, 'Strike') 36
# ('ALL', 3, 'Wind') 37
# ('ALL', 4, 'Almighty') 38
# ('ALL', 4, 'Bad Status') 39
# ('ALL', 4, 'Dark') 40
# ('ALL', 4, 'Elec') 41
# ('ALL', 4, 'Enhance') 42
# ('ALL', 4, 'Fire') 43
# ('ALL', 4, 'Ice') 44
# ('ALL', 4, 'Light') 45
# ('ALL', 4, 'Passive') 46
# ('ALL', 4, 'Pierce') 47
# ('ALL', 4, 'Recovery') 48
# ('ALL', 4, 'Slash') 49
# ('ALL', 4, 'Strike') 50
# ('ALL', 4, 'Wind') 51
# ('ALL', 5, 'Bad Status') 52
# ('ALL', 5, 'Dark') 53
# ('ALL', 5, 'Elec') 54
# ('ALL', 5, 'Enhance') 55
# ('ALL', 5, 'Fire') 56
# ('ALL', 5, 'Ice') 57
# ('ALL', 5, 'Light') 58
# ('ALL', 5, 'Passive') 59
# ('ALL', 5, 'Pierce') 60
# ('ALL', 5, 'Recovery') 61
# ('ALL', 5, 'Slash') 62
# ('ALL', 5, 'Strike') 63
# ('ALL', 5, 'Wind') 64
# ('ALL', 6, 'Almighty') 65
# ('ALL', 6, 'Elec') 66
# ('ALL', 6, 'Fire') 67
# ('ALL', 6, 'Ice') 68
# ('ALL', 6, 'Passive') 69
# ('ALL', 6, 'Pierce') 70
# ('ALL', 6, 'Recovery') 71
# ('ALL', 6, 'Slash') 72
# ('ALL', 6, 'Strike') 73
# ('ALL', 6, 'Wind') 74
# ('ALL', 7, 'Almighty') 75
# ('ALL', 7, 'Enhance') 76
# ('ALL', 7, 'Passive') 77
# ('ALL', 7, 'Pierce') 78
# ('ALL', 7, 'Recovery') 79
# ('ALL', 7, 'Slash') 80
# ('ALL', 7, 'Special') 81
# ('ALL', 7, 'Strike') 82
# ('ALL', 8, 'Almighty') 83
# ('ALL', 8, 'Bad Status') 84
# ('ALL', 8, 'Passive') 85
# ('ALL', 8, 'Pierce') 86
# ('ALL', 8, 'Slash') 87
# ('ALL', 8, 'Strike') 88
# ('ALL', 9, 'Dark') 89
# ('ALL', 9, 'Elec') 90
# ('ALL', 9, 'Light') 91
# ('ALL', 9, 'Passive') 92
# ('ALL', 9, 'Recovery') 93
# ('ALL', 9, 'Wind') 94
# ('FIRE', 1, 'Pierce') 95
# ('FIRE', 2, 'Bad Status') 96
# ('FIRE', 2, 'Enhance') 97
# ('FIRE', 2, 'Strike') 98
# ('FIRE', 3, 'Bad Status') 99

# %%
import numpy as np

# Assuming 'a' is your matrix
a = np.array(a)


advanced_constrasints_matrix_path = "matrix_advanced.txt"

# erase all contents of 'matrix_a.txt'
open(advanced_constrasints_matrix_path, 'w').close()

# Save the matrix to a text file
np.savetxt(advanced_constrasints_matrix_path, a, fmt='%s')

# %%
# Step 1: Read the matrix 'a' from the file
with open(advanced_constrasints_matrix_path, 'r') as file:
    matrix_a = np.loadtxt(file)

# Number of recipes (n) and tags (m)
n, m = matrix_a.shape

print(n, m)
# Out:
# 100 8551

# %%
import pulp
import numpy as np
from tqdm import tqdm

# Step 1: Read the matrix 'a' from the file
with open(advanced_constrasints_matrix_path, 'r') as file:
    matrix_a = np.loadtxt(file)


# Number of recipes (n) and tags (m)
m, n = matrix_a.shape  # Note that m is the number of tags, n is the number of recipes

# Create the problem variable
prob = pulp.LpProblem("Recipe_Selection", pulp.LpMinimize)

# Decision variables
x = [pulp.LpVariable(f'x{j}', cat='Binary') for j in range(n)]

# Objective function
prob += pulp.lpSum(x)

# Constraints
for i in tqdm(range(m)):  # for each tag
    prob += pulp.lpSum(matrix_a[i][j] * x[j] for j in range(n)) >= 1, f"TagCoverage{i}"

# Solve the problem
prob.solve()

# Print the results
print("Status:", pulp.LpStatus[prob.status])
print("Minimum number of recipes:", pulp.value(prob.objective))
selected_recipes = [j for j in range(n) if x[j].varValue == 1]
print("Selected recipes (indexed at j):", selected_recipes)
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 23.35it/s]
# Status: Optimal
# Minimum number of recipes: 14.0
# Selected recipes (indexed at j): [0, 4601, 5743, 6366, 6868, 7537, 7551, 7890, 8006, 8234, 8355, 8442, 8537, 8549]

# %%
# !jupyter nbconvert --to script advanced_most_eficient_inheritance.ipynb
# Out:
# [NbConvertApp] Converting notebook advanced_most_eficient_inheritance.ipynb to script
# [NbConvertApp] Writing 37364 bytes to advanced_most_eficient_inheritance.py

# %% [markdown]
# Next code refers to a failed attempt at a genetic algorithm
