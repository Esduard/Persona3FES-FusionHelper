# %%
from collections import Counter
from matplotlib import pyplot as plt


class PredicitionHolder():

    def __init__(self, persona_list, slot_number, inherit_type, possible_skills):
        # open file to data variable
        with open("/home/eduardo/Documents/Persona3/AutoTelos/kikuriHime/predictions_{}//predictions_logs-{}-optimal_recipes.txt_{}.log".format(inherit_type,inherit_type,slot_number), "r") as f:
            log_file_content = f.readlines()

        self.persona_list = persona_list

        self.predictions = exclude_lines_with_duplicates(log_file_content)

        self.possible_skills = possible_skills

        # Initialize a counter with all possible values set to 0
        value_counts_with_all_possible = Counter({value: 0 for value in possible_skills})

        # Flatten the list of lists
        all_values = [item for sublist in self.predictions for item in sublist]

        # Update this counter with the actual occurrences
        value_counts_with_all_possible.update(all_values)
        self.value_counts_with_all_possible =  value_counts_with_all_possible


        # sum all values in the counter
        total = sum(value_counts_with_all_possible.values())

        # Create a dictionary with the percentage of each value
        percentage = {key: value/total for key, value in value_counts_with_all_possible.items()}

        self.percentage = percentage

    def show(self):

        print("Persona List: ", self.persona_list)

        # Now to visualize these counts as a histogram, ensuring all possible values are included
        plt.figure(figsize=(12, 8))
        plt.bar(self.value_counts_with_all_possible.keys(), self.value_counts_with_all_possible.values())
        plt.xlabel('Skill Names')
        plt.ylabel('Counts')
        plt.title('Histogram of Skill Occurrences Including All Possible Values')
        plt.xticks(rotation=90, ha="right")
        plt.tight_layout()  # Adjust layout to make room for the rotated x-axis labels
        plt.show()




# Function to parse each line as a list and check for duplicates
def exclude_lines_with_duplicates(log_lines):
    unique_lines = []  # This will hold only the lines without any duplicates
    for line_str in log_lines:
        try:
            # Parsing the string to a list
            line_list = eval(line_str)
            # Check for duplicates: Add to unique_lines only if there are no duplicates
            if len(line_list) == len(set(line_list)):
                unique_lines.append(line_list)
        except Exception as e:
            # In case of an error in parsing, you can decide how to handle it,
            # for example, by logging the error or skipping the line.
            # This example will skip the line.
            pass
    return unique_lines

# %%
import re

class InheritanceTypeHolder():


    def __init__(self, inherit_type):
        #open the file
        #'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\fusion_navigator\\logs_optimal_solutions\\logs-{}-optimal_recipes.txt'
        with open('/home/eduardo/Documents/Persona3/AutoTelos/fusion_navigator/logs_optimal_solutions/logs-{}-optimal_recipes.txt'.format(inherit_type), 'r') as file:
            file_content = file.read()
            predictionHolders = parse_file(file_content,inherit_type)
        
        self.predictionHolders = predictionHolders

def parse_personas(persona_string):
    return re.findall(r"\('([\w\s-]+)', \d+, '([\w\s]+)'\)", persona_string)


def parse_skills(skill_string):
    return [skill.strip().strip("'").strip('"') for skill in skill_string.strip('[]').split(',')]

def parse_file(file_content,inherit_type):
    predictionHolders = []
    sections = file_content.split('------------------------\n')

    for section in sections:
        if section.strip() == '':
            continue

        personas = re.findall(r"Personas: \[([^\]]+)\]", section)
        skills = re.findall(r"Skills: \[([^\]]+)\]", section)
        result_persona = re.search(r"Resulting Persona: ([\w\s]+?)\s*$", section, re.MULTILINE)
        base_skills_amount = re.search(r"Base Skills Ammount: (\d+)", section)
        inherit_slots_amount = re.search(r"Inherited Skills Ammount: (\d+)", section)
        save_state_slot = re.search(r"key f(\d+)", section)

        if personas and skills and result_persona and base_skills_amount and inherit_slots_amount and save_state_slot:
            persona_list = parse_personas(personas[0])
            #print(persona_list)
            skill_set = parse_skills(skills[0])
            #TODO maybe i should plot the coverage
            save_state_slot = int(save_state_slot.group(1))
            

            ph = PredicitionHolder(persona_list,save_state_slot, inherit_type, skill_set)

            #recipe = RecipeController(skill_set, base_skills_amount, inherit_slots_amount, result_persona_name, fusion_spread_type, save_state_slot)
            predictionHolders.append(ph)

    return predictionHolders

# %%
all_holder = InheritanceTypeHolder("BAD STATUS")

for holder in all_holder.predictionHolders:
    holder.show()
# Out:
# Persona List:  [('alice', 'Death'), ('okuninushi', 'Temperance'), ('take-mikazuchi', 'Emperor')]
# Persona List:  [('hecatoncheires', 'Hanged Man'), ('surt', 'Magician'), ('fortuna', 'Fortune')]
# Persona List:  [('helel', 'Star'), ('power', 'Justice'), ('valkyrie', 'Strength')]
# Persona List:  [('kali', 'Strength'), ('pazuzu', 'Devil'), ('cu chulainn', 'Tower')]
# Persona List:  [('loki', 'Fool'), ('laksmi', 'Empress'), ('inugami', 'Hanged Man')]
# Persona List:  [('lucifer', 'Judgment'), ('scathach', 'Priestess'), ('genbu', 'Temperance')]
# Persona List:  [('siegfried', 'Strength'), ('throne', 'Justice'), ('chimera', 'Chariot')]
# Persona List:  [('skadi', 'Empress'), ('odin', 'Emperor'), ('daisoujou', 'Hierophant')]
# Persona List:  [('ubelluris', 'Hanged Man'), ('mot', 'Death'), ('vetala', 'Devil')]
# Persona List:  [('vishnu', 'Sun'), ('orobas', 'Magician'), ('gurr', 'Moon')]

# %%
print(all_holder.predictionHolders[0].percentage)
# Out:
# {'Charmdi': 0.0, 'Zionga': 0.015154536390827518, 'Apt Pupil': 0.034695912263210366, 'Mighty Swing': 0.0, 'Getsu-ei': 0.0, 'Mazio': 0.01674975074775673, 'Repel Dark': 0.0317048853439681, 'Die for Me!': 0.021136590229312063, 'Megido': 0.004785643070787637, 'Spirit Drain': 0.009172482552342971, 'Marin Karin': 0.1686939182452642, 'Zan-ei': 0.0, 'Maragion': 0.010169491525423728, 'Pulinpa': 0.17128614157527416, 'Fire Boost': 0.07597208374875374, 'Auto-Tarukaja': 0.05443668993020937, 'Agilao': 0.012761714855433698, 'Zio': 0.03509471585244267, 'Marakunda': 0.0386839481555334, 'Elec Break': 0.04327018943170489, 'Matarukaja': 0.03369890329012961, 'Evil Touch': 0.1415752741774676, 'Agidyne': 0.006779661016949152, 'Elec Boost': 0.07417746759720838}

# %%
# Create a dictionary to store the percentages
percentages = {}

for holder in all_holder.predictionHolders:
    # Get the "percentage" dictionary from the holder
    percentage_dict = holder.percentage  # Assuming 'percentage' is an attribute of holder

    # Iterate over the items in the percentage dictionary
    for key, value in percentage_dict.items():
        # If the key is already in the percentages dictionary, append the value to the list
        if key in percentages:
            percentages[key].append(value)
        # Otherwise, add a new list with the value to the percentages dictionary
        else:
            percentages[key] = [value]

# Now, percentages is a dictionary where the keys are the keys from the percentage dictionaries,
# and the values are lists of values for each key from all percentage dictionaries

# Print the keys and their corresponding lists of values
for key, values in percentages.items():
    print(f"{key}: {values}")
# Out:
# Charmdi: [0.0]
# Zionga: [0.015154536390827518]
# Apt Pupil: [0.034695912263210366, 0.06156530408773679, 0.10443668993020937]
# Mighty Swing: [0.0]
# Getsu-ei: [0.0]
# Mazio: [0.01674975074775673]
# Repel Dark: [0.0317048853439681]
# Die for Me!: [0.021136590229312063]
# Megido: [0.004785643070787637, 0.004785643070787637]
# Spirit Drain: [0.009172482552342971]
# Marin Karin: [0.1686939182452642]
# Zan-ei: [0.0, 0.0, 0.0]
# Maragion: [0.010169491525423728]
# Pulinpa: [0.17128614157527416]
# Fire Boost: [0.07597208374875374, 0.12861415752741776]
# Auto-Tarukaja: [0.05443668993020937, 0.10628115653040877, 0.09147557328015953, 0.054636091724825524]
# Agilao: [0.012761714855433698]
# Zio: [0.03509471585244267, 0.07397806580259222, 0.09471585244267199, 0.04112662013958126]
# Marakunda: [0.0386839481555334, 0.07278165503489531]
# Elec Break: [0.04327018943170489]
# Matarukaja: [0.03369890329012961, 0.06430707876370888]
# Evil Touch: [0.1415752741774676]
# Agidyne: [0.006779661016949152]
# Elec Boost: [0.07417746759720838]
# Magaru: [0.03339980059820538, 0.03649052841475573]
# Wind Boost: [0.1271186440677966, 0.11306081754735793, 0.07517447657028914]
# Ragnarok: [0.005483549351944167]
# Wind Amp: [0.0780159521435693, 0.07258225324027916, 0.04885343968095713, 0.04007976071784646]
# Megidola: [0.005982053838484547, 0.016450648055832504]
# Bufu: [0.06380857427716849]
# Elec Amp: [0.06954137587238285, 0.06899302093718844]
# Dodge Wind: [0.09745762711864407]
# Garu: [0.06979062811565304]
# High Counter: [0.058325024925224324, 0.0707876370887338, 0.0, 0.060069790628115655, 0.0]
# Rakukaja: [0.1296111665004985, 0.1363409770687936, 0.07557328015952143]
# Mind Charge: [0.0682951146560319, 0.072382851445663, 0.06261216350947159, 0.034695912263210366]
# Evade Strike: [0.06455633100697906]
# Gigantic Fist: [0.0]
# Salvation: [0.0, 0.0, 0.0]
# Morning Star: [0.007178464606181456]
# Auto-Sukukaja: [0.10667996011964108]
# Dodge Slash: [0.1090727816550349]
# Power Slash: [0.0]
# Revolution: [0.10448654037886342]
# Media: [0.0]
# Hama: [0.0]
# Primal Force: [0.0]
# Cleave: [0.0, 0.0]
# Spell Master: [0.045862412761714856, 0.04461615154536391, 0.02971086739780658]
# Absorb Slash: [0.04885343968095713]
# Mahama: [0.0]
# Me Patra: [0.0, 0.0, 0.0]
# Victory Cry: [0.04187437686939183, 0.047108673978065806]
# Bash: [0.0, 0.0]
# Mabufu: [0.04067796610169491]
# Tarukaja: [0.1353938185443669, 0.13160518444666003, 0.11545363908275175, 0.07298105682951146]
# Garudyne: [0.006979062811565304]
# Diarama: [0.0]
# Mazionga: [0.016201395812562313]
# Sexy Dance: [0.20463609172482553]
# Power Charge: [0.06505483549351944, 0.07951146560319043]
# Null Distress: [0.056580259222333, 0.03938185443668993]
# Arrow Rain: [0.0]
# Deathbound: [0.0]
# Matarunda: [0.0685443668993021]
# Virus Breath: [0.1602691924227318]
# Torrent Shot: [0.0]
# Blade of Fury: [0.0]
# Poison Arrow: [0.0]
# Enradi: [0.0]
# Bufudyne: [0.020937188434695914]
# Maragidyne: [0.020189431704885345]
# Amrita: [0.0, 0.0]
# Resist Fire: [0.11764705882352941]
# Stagnant Air: [0.037637088733798604]
# Null Fire: [0.10294117647058823]
# Single Shot: [0.0]
# Poisma: [0.24925224327018944]
# Null Dark: [0.10269192422731804, 0.05443668993020937]
# Ice Break: [0.10692921236291127]
# Mabufula: [0.026171485543369892]
# Megidolaon: [0.007726819541375872]
# Bufula: [0.03265204386839481]
# Mamudoon: [0.07228315054835494]
# Mabufudyne: [0.012213359920239282]
# Myriad Arrows: [0.0]
# Mamudo: [0.11415752741774676]
# Dekunda: [0.11340977068793619]
# Brave Blade: [0.0]
# Mudo: [0.1532901296111665]
# Sukunda: [0.14880358923230308]
# Resist Strike: [0.07103688933200399]
# Auto-Rakukaja: [0.11465603190428714]
# Magarudyne: [0.014705882352941176]
# Makarakarn: [0.05333998005982054]
# Counterstrike: [0.0847457627118644]
# Hamaon: [0.0]
# Agi: [0.06380857427716849]
# Vicious Strike: [0.0]
# Auto-Masuku: [0.05259222333000997]
# Hama Boost: [0.0780159521435693]
# Mahamaon: [0.0]
# Dekaja: [0.06729810568295115, 0.03913260219341974]
# Mediarahan: [0.0]
# Resist Dark: [0.07577268195413758]
# Bewilder: [0.24675972083748754]
# Vorpal Blade: [0.0]
# Tempest Slash: [0.0]
# Auto-Mataru: [0.05508474576271186]
# Recarmdra: [0.0, 0.0]
# Counter: [0.08853439680957129, 0.052642073778664006]
# Growth 3: [0.06759720837487537]
# Samsara: [0.0]
# Patra: [0.0]
# Diarahan: [0.0]
# Unshaken Will: [0.030109670987038883]
# Vile Assault: [0.0]
# Ice Amp: [0.06719840478564307]
# Niflheim: [0.008374875373878364]
# Absorb Fire: [0.03429710867397807]
# Maziodyne: [0.010568295114656031]
# Recarm: [0.0]
# Null Panic: [0.05623130608175474]
# Thunder Reign: [0.007377866400797607]
# Sukukaja: [0.11286141575274178, 0.07557328015952143]
# Herculean Strike: [0.0]
# Maragi: [0.022681954137587237]
# Provoke: [0.20937188434695914]
# Evil Smile: [0.15029910269192423]
# Null Fear: [0.04312063808574277]
# Rebellion: [0.08399800598205384]
# Kill Rush: [0.0]
# Tentarafoo: [0.15004985044865404]
# Double Fangs: [0.0]
# Ghastly Wail: [0.08823529411764706]
# Mudoon: [0.04735792622133599]
# Panta Rhei: [0.003988035892323031, 0.0029910269192422734]
# Magarula: [0.010219341974077766]
# Foul Breath: [0.02218344965104686]
# Ice Boost: [0.07058823529411765]
# God's Hand: [0.0]
# Akasha Arts: [0.0]
# Dodge Strike: [0.05363908275174477]
# Raging Tiger: [0.12243270189431704]
# Ziodyne: [0.007178464606181456]
# Twin Shot: [0.0]
# Wind Break: [0.03609172482552343]
# Garula: [0.01156530408773679]
# Sharp Student: [0.04905284147557328]
# Poison Mist: [0.13838484546360919]
# Trafuri: [0.02193419740777667]
# Sonic Punch: [0.0]

# %%
import pandas as pd
# 'C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\skills_list\\skills.csv'
skills_csv_path = "/home/eduardo/Documents/Persona3/AutoTelos/skills_list/skills.csv"
df = pd.read_csv(skills_csv_path)

#print(df)

skill_type_dict = df.set_index('skill')['type'].to_dict()

skill_rank_dict = df.set_index('skill')['rank'].to_dict()

print(skill_type_dict)
print(skill_rank_dict)
# Out:
# {'Cleave': 'Slash', 'Power Slash': 'Slash', 'Getsu-ei': 'Slash', 'Zan-ei': 'Slash', 'Gale Slash': 'Slash', 'Mighty Swing': 'Slash', 'Fatal End': 'Slash', 'Blade of Fury': 'Slash', 'Deathbound': 'Slash', "Heaven's Blade": 'Slash', 'Tempest Slash': 'Slash', 'Brave Blade': 'Slash', 'Scarlet Havoc': 'Slash', 'Vorpal Blade': 'Slash', 'Bash': 'Strike', 'Assault Dive': 'Strike', 'Sonic Punch': 'Strike', 'Swift Strike': 'Strike', 'Kill Rush': 'Strike', 'Herculean Strike': 'Strike', 'Gigantic Fist': 'Strike', 'Heat Wave': 'Strike', 'Vicious Strike': 'Strike', 'Akasha Arts': 'Strike', "God's Hand": 'Strike', 'Shadow Hound': 'Strike', 'Weary Thrust': 'Strike', 'Single Shot': 'Pierce', 'Double Fangs': 'Pierce', 'Holy Arrow': 'Pierce', 'Twin Shot': 'Pierce', 'Cruel Attack': 'Pierce', 'Torrent Shot': 'Pierce', 'Vile Assault': 'Pierce', 'Poison Arrow': 'Pierce', 'Arrow Rain': 'Pierce', 'Myriad Arrows': 'Pierce', 'Pralaya': 'Pierce', 'Primal Force': 'Pierce', 'Agi': 'Fire', 'Maragi': 'Fire', 'Agilao': 'Fire', 'Maragion': 'Fire', 'Agidyne': 'Fire', 'Maragidyne': 'Fire', 'Ragnarok': 'Fire', 'Ardhanari': 'Fire', 'Maralagidyne': 'Fire', 'Bufu': 'Ice', 'Mabufu': 'Ice', 'Bufula': 'Ice', 'Mabufula': 'Ice', 'Bufudyne': 'Ice', 'Mabufudyne': 'Ice', 'Niflheim': 'Ice', 'King and I': 'Ice', 'Zio': 'Elec', 'Mazio': 'Elec', 'Zionga': 'Elec', 'Mazionga': 'Elec', 'Ziodyne': 'Elec', 'Maziodyne': 'Elec', 'Thunder Reign': 'Elec', 'Thunder Call': 'Elec', 'Garu': 'Wind', 'Magaru': 'Wind', 'Garula': 'Wind', 'Magarula': 'Wind', 'Garudyne': 'Wind', 'Magarudyne': 'Wind', 'Panta Rhei': 'Wind', 'Hama': 'Light', 'Mahama': 'Light', 'Hamaon': 'Light', 'Mahamaon': 'Light', 'Samsara': 'Light', 'Justice': 'Light', 'Mudo': 'Dark', 'Mamudo': 'Dark', 'Mudoon': 'Dark', 'Mamudoon': 'Dark', 'Die for Me!': 'Dark', 'Foul Breath': 'Almighty', 'Life Drain': 'Almighty', 'Stagnant Air': 'Almighty', 'Spirit Drain': 'Almighty', 'Megido': 'Almighty', 'Megidola': 'Almighty', 'Megidolaon': 'Almighty', 'Black Viper': 'Almighty', 'Morning Star': 'Almighty', 'Armageddon': 'Almighty', 'Jack Brothers': 'Almighty', 'Last Judge': 'Almighty', 'Raktapaksha': 'Almighty', 'Bewilder': 'Bad Status', 'Poisma': 'Bad Status', 'Eerie Sound': 'Bad Status', 'Marin Karin': 'Bad Status', 'Provoke': 'Bad Status', 'Pulinpa': 'Bad Status', 'Infuriate': 'Bad Status', 'Poison Mist': 'Bad Status', 'Sexy Dance': 'Bad Status', 'Evil Touch': 'Bad Status', 'Evil Smile': 'Bad Status', 'Tentarafoo': 'Bad Status', 'Virus Breath': 'Bad Status', 'Ghastly Wail': 'Bad Status', 'Dreamfest': 'Bad Status', 'Summer Dream': 'Bad Status', 'Trickster': 'Bad Status', 'Patra': 'Recovery', 'Charmdi': 'Recovery', 'Enradi': 'Recovery', 'Posumudi': 'Recovery', 'Re Patra': 'Recovery', 'Dia': 'Recovery', 'Me Patra': 'Recovery', 'Media': 'Recovery', 'Diarama': 'Recovery', 'Recarm': 'Recovery', 'Mediarama': 'Recovery', 'Samarecarm': 'Recovery', 'Diarahan': 'Recovery', 'Amrita': 'Recovery', 'Mediarahan': 'Recovery', 'Salvation': 'Recovery', 'Cadenza': 'Recovery', 'Frolic': 'Recovery', 'Rakukaja': 'Enhance', 'Rakunda': 'Enhance', 'Rebellion': 'Enhance', 'Sukukaja': 'Enhance', 'Sukunda': 'Enhance', 'Tarukaja': 'Enhance', 'Tarunda': 'Enhance', 'Dekunda': 'Enhance', 'Revolution': 'Enhance', 'Elec Break': 'Enhance', 'Fire Break': 'Enhance', 'Ice Break': 'Enhance', 'Marakunda': 'Enhance', 'Masukunda': 'Enhance', 'Matarunda': 'Enhance', 'Power Charge': 'Enhance', 'Wind Break': 'Enhance', 'Dekaja': 'Enhance', 'Marakukaja': 'Enhance', 'Masukukaja': 'Enhance', 'Matarukaja': 'Enhance', 'Mind Charge': 'Enhance', 'Makarakarn': 'Enhance', 'Tetrakarn': 'Enhance', 'Best Friends': 'Enhance', 'Infinity': 'Enhance', 'Valhalla': 'Enhance', 'Recarmdra': 'Special', 'Trafuri': 'Special', 'Raging Tiger': 'Passive', 'Elec Boost': 'Passive', 'Fire Boost': 'Passive', 'Growth 1': 'Passive', 'Ice Boost': 'Passive', 'Wind Boost': 'Passive', 'Charm Boost': 'Passive', 'Distress Boost': 'Passive', 'Fear Boost': 'Passive', 'Panic Boost': 'Passive', 'Poison Boost': 'Passive', 'Rage ...
# {'Cleave': 1, 'Power Slash': 2, 'Getsu-ei': 3, 'Zan-ei': 3, 'Gale Slash': 3, 'Mighty Swing': 4, 'Fatal End': 4, 'Blade of Fury': 5, 'Deathbound': 6, "Heaven's Blade": 7, 'Tempest Slash': 7, 'Brave Blade': 8, 'Scarlet Havoc': 99, 'Vorpal Blade': 8, 'Bash': 1, 'Assault Dive': 2, 'Sonic Punch': 2, 'Swift Strike': 3, 'Kill Rush': 3, 'Herculean Strike': 4, 'Gigantic Fist': 5, 'Heat Wave': 5, 'Vicious Strike': 6, 'Akasha Arts': 7, "God's Hand": 8, 'Shadow Hound': 99, 'Weary Thrust': 6, 'Single Shot': 1, 'Double Fangs': 2, 'Holy Arrow': 2, 'Twin Shot': 3, 'Cruel Attack': 4, 'Torrent Shot': 4, 'Vile Assault': 5, 'Poison Arrow': 5, 'Arrow Rain': 6, 'Myriad Arrows': 7, 'Pralaya': 8, 'Primal Force': 8, 'Agi': 1, 'Maragi': 2, 'Agilao': 3, 'Maragion': 4, 'Agidyne': 5, 'Maragidyne': 6, 'Ragnarok': 9, 'Ardhanari': 99, 'Maralagidyne': 99, 'Bufu': 1, 'Mabufu': 2, 'Bufula': 3, 'Mabufula': 4, 'Bufudyne': 5, 'Mabufudyne': 6, 'Niflheim': 9, 'King and I': 99, 'Zio': 1, 'Mazio': 2, 'Zionga': 3, 'Mazionga': 4, 'Ziodyne': 5, 'Maziodyne': 6, 'Thunder Reign': 9, 'Thunder Call': 99, 'Garu': 1, 'Magaru': 2, 'Garula': 3, 'Magarula': 4, 'Garudyne': 5, 'Magarudyne': 6, 'Panta Rhei': 9, 'Hama': 2, 'Mahama': 3, 'Hamaon': 4, 'Mahamaon': 5, 'Samsara': 9, 'Justice': 99, 'Mudo': 2, 'Mamudo': 3, 'Mudoon': 4, 'Mamudoon': 5, 'Die for Me!': 9, 'Foul Breath': 2, 'Life Drain': 3, 'Stagnant Air': 3, 'Spirit Drain': 4, 'Megido': 6, 'Megidola': 7, 'Megidolaon': 8, 'Black Viper': 9, 'Morning Star': 9, 'Armageddon': 99, 'Jack Brothers': 99, 'Last Judge': 99, 'Raktapaksha': 99, 'Bewilder': 1, 'Poisma': 1, 'Eerie Sound': 2, 'Marin Karin': 2, 'Provoke': 2, 'Pulinpa': 2, 'Infuriate': 3, 'Poison Mist': 3, 'Sexy Dance': 3, 'Evil Touch': 3, 'Evil Smile': 4, 'Tentarafoo': 4, 'Virus Breath': 5, 'Ghastly Wail': 8, 'Dreamfest': 99, 'Summer Dream': 99, 'Trickster': 99, 'Patra': 1, 'Charmdi': 2, 'Enradi': 2, 'Posumudi': 2, 'Re Patra': 2, 'Dia': 2, 'Me Patra': 3, 'Media': 3, 'Diarama': 3, 'Recarm': 4, 'Mediarama': 5, 'Samarecarm': 5, 'Diarahan': 5, 'Amrita': 6, 'Mediarahan': 7, 'Salvation': 9, 'Cadenza': 99, 'Frolic': 99, 'Rakukaja': 2, 'Rakunda': 2, 'Rebellion': 2, 'Sukukaja': 2, 'Sukunda': 2, 'Tarukaja': 2, 'Tarunda': 2, 'Dekunda': 3, 'Revolution': 3, 'Elec Break': 4, 'Fire Break': 4, 'Ice Break': 4, 'Marakunda': 4, 'Masukunda': 4, 'Matarunda': 4, 'Power Charge': 4, 'Wind Break': 4, 'Dekaja': 5, 'Marakukaja': 5, 'Masukukaja': 5, 'Matarukaja': 5, 'Mind Charge': 5, 'Makarakarn': 7, 'Tetrakarn': 7, 'Best Friends': 99, 'Infinity': 99, 'Valhalla': 99, 'Recarmdra': 7, 'Trafuri': 8, 'Raging Tiger': 1, 'Elec Boost': 2, 'Fire Boost': 2, 'Growth 1': 2, 'Ice Boost': 2, 'Wind Boost': 2, 'Charm Boost': 3, 'Distress Boost': 3, 'Fear Boost': 3, 'Panic Boost': 3, 'Poison Boost': 3, 'Rage Boost': 3, 'Sharp Student': 5, 'Counter': 3, 'Dodge Elec': 3, 'Dodge Fire': 3, 'Dodge Ice': 3, 'Dodge Pierce': 3, 'Dodge Slash': 3, 'Dodge Strike': 3, 'Dodge Wind': 3, 'Growth 2': 3, 'Cool Breeze': 4, 'Elec Amp': 4, 'Evade Elec': 4, 'Evade Fire': 4, 'Evade Ice': 4, 'Evade Wind': 4, 'Fast Retreat': 4, 'Fire Amp': 4, 'Growth 3': 4, 'Hama Boost': 4, 'Ice Amp': 4, 'Mudo Boost': 4, 'Survive Dark': 4, 'Survive Light': 4, 'Wind Amp': 4, 'Counterstrike': 4, 'Invigorate 1': 4, 'Regenerate 1': 4, 'Resist Dark': 4, 'Resist Elec': 4, 'Resist Fire': 4, 'Resist Ice': 4, 'Resist Light': 4, 'Resist Wind': 4, 'Alertness': 5, 'Apt Pupil': 3, 'Endure Dark': 5, 'Endure Light': 5, 'Evade Pierce': 5, 'Evade Slash': 5, 'Evade Strike': 5, 'High Counter': 5, 'Null Charm': 5, 'Null Distress': 5, 'Null Fear': 5, 'Null Freeze': 5, 'Null Panic': 5, 'Null Poison': 5, 'Null Rage': 5, 'Null Shock': 5, 'Spring of Life': 5, 'Invigorate 2': 5, 'Null Dark': 5, 'Null Elec': 5, 'Null Fire': 5, 'Null Ice': 5, 'Null Light': 5, 'Null Wind': 5, 'Regenerate 2': 5, 'Resist Pierce': 5, 'Resist Slash': 5, 'Resist Strike': 5, '1hSwd Master': 6, '2hSwd Master': 6, 'Auto-Maraku': 6, 'Auto-Masuku': 6, 'Auto-Mataru': 6, 'Auto-Rakukaja': 3, 'Auto-Sukukaja': 3, 'Auto-Tar ...

# %%
# Create a dictionary to store the skills by type and rank
skills_by_type_and_rank = {}

for key, values in percentages.items():
    # Get the skill type and rank from the dictionaries
    skill_type = skill_type_dict[key]
    skill_rank = skill_rank_dict[key]

    # Create a tuple of skill type and rank
    type_and_rank = (skill_type, skill_rank)

    # If the type and rank is already in the dictionary, append the skill to the list
    if type_and_rank in skills_by_type_and_rank:
        skills_by_type_and_rank[type_and_rank].append(key)
    # Otherwise, add a new list with the skill to the dictionary
    else:
        skills_by_type_and_rank[type_and_rank] = [key]

# Now, skills_by_type_and_rank is a dictionary where the keys are tuples of skill type and rank,
# and the values are lists of skills with that type and rank

# Print the type and rank and their corresponding lists of skills
for type_and_rank, skills in skills_by_type_and_rank.items():
    print(f"{type_and_rank}: {skills}")
# Out:
# ('Recovery', 2): ['Charmdi', 'Enradi']
# ('Elec', 3): ['Zionga']
# ('Passive', 3): ['Apt Pupil', 'Auto-Tarukaja', 'Dodge Wind', 'Auto-Sukukaja', 'Dodge Slash', 'Auto-Rakukaja', 'Counter', 'Dodge Strike']
# ('Slash', 4): ['Mighty Swing']
# ('Slash', 3): ['Getsu-ei', 'Zan-ei']
# ('Elec', 2): ['Mazio']
# ('Passive', 6): ['Repel Dark', 'Auto-Masuku', 'Auto-Mataru']
# ('Dark', 9): ['Die for Me!']
# ('Almighty', 6): ['Megido']
# ('Almighty', 4): ['Spirit Drain']
# ('Bad Status', 2): ['Marin Karin', 'Pulinpa', 'Provoke']
# ('Fire', 4): ['Maragion']
# ('Passive', 2): ['Fire Boost', 'Elec Boost', 'Wind Boost', 'Ice Boost']
# ('Fire', 3): ['Agilao']
# ('Elec', 1): ['Zio']
# ('Enhance', 4): ['Marakunda', 'Elec Break', 'Power Charge', 'Matarunda', 'Ice Break', 'Wind Break']
# ('Enhance', 5): ['Matarukaja', 'Mind Charge', 'Dekaja']
# ('Bad Status', 3): ['Evil Touch', 'Sexy Dance', 'Poison Mist']
# ('Fire', 5): ['Agidyne']
# ('Wind', 2): ['Magaru']
# ('Fire', 9): ['Ragnarok']
# ('Passive', 4): ['Wind Amp', 'Elec Amp', 'Resist Fire', 'Counterstrike', 'Hama Boost', 'Resist Dark', 'Growth 3', 'Ice Amp']
# ('Almighty', 7): ['Megidola']
# ('Ice', 1): ['Bufu']
# ('Wind', 1): ['Garu']
# ('Passive', 5): ['High Counter', 'Evade Strike', 'Null Distress', 'Null Fire', 'Null Dark', 'Resist Strike', 'Null Panic', 'Null Fear', 'Sharp Student']
# ('Enhance', 2): ['Rakukaja', 'Tarukaja', 'Sukunda', 'Sukukaja', 'Rebellion']
# ('Strike', 5): ['Gigantic Fist']
# ('Recovery', 9): ['Salvation']
# ('Almighty', 9): ['Morning Star']
# ('Slash', 2): ['Power Slash']
# ('Enhance', 3): ['Revolution', 'Dekunda']
# ('Recovery', 3): ['Media', 'Me Patra', 'Diarama']
# ('Light', 2): ['Hama']
# ('Pierce', 8): ['Primal Force']
# ('Slash', 1): ['Cleave']
# ('Passive', 9): ['Spell Master', 'Victory Cry', 'Unshaken Will']
# ('Passive', 8): ['Absorb Slash']
# ('Light', 3): ['Mahama']
# ('Strike', 1): ['Bash']
# ('Ice', 2): ['Mabufu']
# ('Wind', 5): ['Garudyne']
# ('Elec', 4): ['Mazionga']
# ('Pierce', 6): ['Arrow Rain']
# ('Slash', 6): ['Deathbound']
# ('Bad Status', 5): ['Virus Breath']
# ('Pierce', 4): ['Torrent Shot']
# ('Slash', 5): ['Blade of Fury']
# ('Pierce', 5): ['Poison Arrow', 'Vile Assault']
# ('Ice', 5): ['Bufudyne']
# ('Fire', 6): ['Maragidyne']
# ('Recovery', 6): ['Amrita']
# ('Almighty', 3): ['Stagnant Air']
# ('Pierce', 1): ['Single Shot']
# ('Bad Status', 1): ['Poisma', 'Bewilder']
# ('Ice', 4): ['Mabufula']
# ('Almighty', 8): ['Megidolaon']
# ('Ice', 3): ['Bufula']
# ('Dark', 5): ['Mamudoon']
# ('Ice', 6): ['Mabufudyne']
# ('Pierce', 7): ['Myriad Arrows']
# ('Dark', 3): ['Mamudo']
# ('Slash', 8): ['Brave Blade', 'Vorpal Blade']
# ('Dark', 2): ['Mudo']
# ('Wind', 6): ['Magarudyne']
# ('Enhance', 7): ['Makarakarn']
# ('Light', 4): ['Hamaon']
# ('Fire', 1): ['Agi']
# ('Strike', 6): ['Vicious Strike']
# ('Light', 5): ['Mahamaon']
# ('Recovery', 7): ['Mediarahan']
# ('Slash', 7): ['Tempest Slash']
# ('Special', 7): ['Recarmdra']
# ('Light', 9): ['Samsara']
# ('Recovery', 1): ['Patra']
# ('Recovery', 5): ['Diarahan']
# ('Ice', 9): ['Niflheim']
# ('Passive', 7): ['Absorb Fire']
# ('Elec', 6): ['Maziodyne']
# ('Recovery', 4): ['Recarm']
# ('Elec', 9): ['Thunder Reign']
# ('Strike', 4): ['Herculean Strike']
# ('Fire', 2): ['Maragi']
# ('Bad Status', 4): ['Evil Smile', 'Tentarafoo']
# ('Strike', 3): ['Kill Rush']
# ('Pierce', 2): ['Double Fangs']
# ('Bad Status', 8): ['Ghastly Wail']
# ('Dark', 4): ['Mudoon']
# ('Wind', 9): ['Panta Rhei']
# ('Wind', 4): ['Magarula']
# ('Almighty', 2): ['Foul Breath']
# ('Strike', 8): ["God's Hand"]
# ('Strike', 7): ['Akasha Arts']
# ('Passive', 1): ['Raging Tiger']
# ('Elec', 5): ['Ziodyne']
# ('Pierce', 3): ['Twin Shot']
# ('Wind', 3): ['Garula']
# ('Special', 8): ['Trafuri']
# ('Strike', 2): ['Sonic Punch']

# %%
# load '/home/eduardo/Documents/Persona3/AutoTelos/inheritance_calculator/inheritance.csv' into a dataframe
inheritance_df = pd.read_csv('/home/eduardo/Documents/Persona3/AutoTelos/inheritance_calculator/inheritance.csv')


# Convert the DataFrame to a dictionary where each key is an inheritance type
# and its value is another dictionary of skill types and their probabilities.
inheritance_dict = inheritance_df.set_index('Inheritance Type').T.to_dict('dict')

print(inheritance_dict['BAD STATUS'])
# Out:
# {'Slash': 0.0, 'Strike': 0.0, 'Pierce': 0.0, 'Fire': 0.2, 'Ice': 0.2, 'Elec': 0.2, 'Wind': 0.2, 'Light': 0.0, 'Dark': 1.0, 'Recovery': 0.0, 'Enhance': 1.0, 'Bad Status': 3.8, 'Special': 1.0, 'Almighty': 0.2, 'Passive': 1.0}

# %%
percentages


inheritance_dict_specific_type = inheritance_dict['BAD STATUS']


for key, values in percentages.items():
    for type_and_rank, skills in skills_by_type_and_rank.items():
        skill_type = type_and_rank[0]

        ratio_for_type = inheritance_dict_specific_type[skill_type]

        ratio_is_not_zero = False

        for s in skills:
            if ratio_for_type == 0 and s == key:
                print(f"Skill: {key}, Type: {skill_type}, Ratio: {ratio_for_type}, Probabilities: {values}")
                for v in values:
                    if v > 0:
                        ratio_is_not_zero = True
                        print('ratio is not zero')

if (ratio_is_not_zero):
    print('ratio is not zero')
# Out:
# Skill: Charmdi, Type: Recovery, Ratio: 0.0, Probabilities: [0.0]
# Skill: Mighty Swing, Type: Slash, Ratio: 0.0, Probabilities: [0.0]
# Skill: Getsu-ei, Type: Slash, Ratio: 0.0, Probabilities: [0.0]
# Skill: Zan-ei, Type: Slash, Ratio: 0.0, Probabilities: [0.0, 0.0, 0.0]
# Skill: Gigantic Fist, Type: Strike, Ratio: 0.0, Probabilities: [0.0]
# Skill: Salvation, Type: Recovery, Ratio: 0.0, Probabilities: [0.0, 0.0, 0.0]
# Skill: Power Slash, Type: Slash, Ratio: 0.0, Probabilities: [0.0]
# Skill: Media, Type: Recovery, Ratio: 0.0, Probabilities: [0.0]
# Skill: Hama, Type: Light, Ratio: 0.0, Probabilities: [0.0]
# Skill: Primal Force, Type: Pierce, Ratio: 0.0, Probabilities: [0.0]
# Skill: Cleave, Type: Slash, Ratio: 0.0, Probabilities: [0.0, 0.0]
# Skill: Mahama, Type: Light, Ratio: 0.0, Probabilities: [0.0]
# Skill: Me Patra, Type: Recovery, Ratio: 0.0, Probabilities: [0.0, 0.0, 0.0]
# Skill: Bash, Type: Strike, Ratio: 0.0, Probabilities: [0.0, 0.0]
# Skill: Diarama, Type: Recovery, Ratio: 0.0, Probabilities: [0.0]
# Skill: Arrow Rain, Type: Pierce, Ratio: 0.0, Probabilities: [0.0]
# Skill: Deathbound, Type: Slash, Ratio: 0.0, Probabilities: [0.0]
# Skill: Torrent Shot, Type: Pierce, Ratio: 0.0, Probabilities: [0.0]
# Skill: Blade of Fury, Type: Slash, Ratio: 0.0, Probabilities: [0.0]
# Skill: Poison Arrow, Type: Pierce, Ratio: 0.0, Probabilities: [0.0]
# Skill: Enradi, Type: Recovery, Ratio: 0.0, Probabilities: [0.0]
# Skill: Amrita, Type: Recovery, Ratio: 0.0, Probabilities: [0.0, 0.0]
# Skill: Single Shot, Type: Pierce, Ratio: 0.0, Probabilities: [0.0]
# Skill: Myriad Arrows, Type: Pierce, Ratio: 0.0, Probabilities: [0.0]
# Skill: Brave Blade, Type: Slash, Ratio: 0.0, Probabilities: [0.0]
# Skill: Hamaon, Type: Light, Ratio: 0.0, Probabilities: [0.0]
# Skill: Vicious Strike, Type: Strike, Ratio: 0.0, Probabilities: [0.0]
# Skill: Mahamaon, Type: Light, Ratio: 0.0, Probabilities: [0.0]
# Skill: Mediarahan, Type: Recovery, Ratio: 0.0, Probabilities: [0.0]
# Skill: Vorpal Blade, Type: Slash, Ratio: 0.0, Probabilities: [0.0]
# Skill: Tempest Slash, Type: Slash, Ratio: 0.0, Probabilities: [0.0]
# Skill: Samsara, Type: Light, Ratio: 0.0, Probabilities: [0.0]
# Skill: Patra, Type: Recovery, Ratio: 0.0, Probabilities: [0.0]
# Skill: Diarahan, Type: Recovery, Ratio: 0.0, Probabilities: [0.0]
# Skill: Vile Assault, Type: Pierce, Ratio: 0.0, Probabilities: [0.0]
# Skill: Recarm, Type: Recovery, Ratio: 0.0, Probabilities: [0.0]
# Skill: Herculean Strike, Type: Strike, Ratio: 0.0, Probabilities: [0.0]
# Skill: Kill Rush, Type: Strike, Ratio: 0.0, Probabilities: [0.0]
# Skill: Double Fangs, Type: Pierce, Ratio: 0.0, Probabilities: [0.0]
# Skill: God's Hand, Type: Strike, Ratio: 0.0, Probabilities: [0.0]
# Skill: Akasha Arts, Type: Strike, Ratio: 0.0, Probabilities: [0.0]
# Skill: Twin Shot, Type: Pierce, Ratio: 0.0, Probabilities: [0.0]
# Skill: Sonic Punch, Type: Strike, Ratio: 0.0, Probabilities: [0.0]
