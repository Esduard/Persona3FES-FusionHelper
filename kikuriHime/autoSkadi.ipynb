# %%
class Rectangle:
    def __init__(self, x, y, width, height):
        self.x = x
        self.y = y
        self.width = width
        self.height = height
    def __str__(self):
        return f"Rectangle(x={self.x}, y={self.y}, width={self.width}, height={self.height})"
        

rectangle_list = []

x = 477
y = 1007
width = 1001 - x
height = 1078 - y

for i in range(3,4):
    rec = Rectangle(x,y + (height * i), width, height)
    rectangle_list.append(rec)

x = 1012
for i in range(4):
    rec = Rectangle(x,y + (height * i), width, height)
    rectangle_list.append(rec)

# %%
print(len(rectangle_list))
# Out:
# 5

# %%
veriification_rectangle = Rectangle(467, 83, 657 - 467, 145 - 83)

# %%
import pyautogui
import os
import time

def timer(seconds):
    # Start a 5-second timer
    for i in range(seconds, 0, -1):
        print(f"Remaining: {i} seconds")
        time.sleep(1)

def screenshot(id):
    # Specify the directory where you want to save the screenshot
    directory = r"C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou"

    # Ensure the directory exists
    os.makedirs(directory, exist_ok=True)

    # Capture the screenshot
    screenshot = pyautogui.screenshot()

    # Save the screenshot to the specified directory
    screenshot.save(os.path.join(directory, f"{id}.png"))

import pydirectinput
import time

def changeTelos():
    # Press the 'l' key
    pydirectinput.press('l')
    


    # Press the 'm' key
    pydirectinput.press('m')
    

def timed_input(seconds, key):
    pydirectinput.press(key)
    time.sleep(seconds)

def change3wayFusion():
    for i in range(3):
        # Press the 'l' key
        timed_input(0.01, 'l')

    timed_input(0.01, 'm')
    
    for i in range(2):
        # Press the 'l' key
        timed_input(0.01, 'w')
        
    
    timed_input(0.01, 'm')

    for i in range(1):
        # Press the 'l' key
        timed_input(0.01, 'w')
        
    # Press the 'm' key
    pydirectinput.keyDown('f4')
    pydirectinput.keyUp('f4')
    timed_input(0.01, 'm')
    pydirectinput.keyDown('f4')
    pydirectinput.keyUp('f4')

# %%
# open 'skills.csv'
import pandas as pd


file_path = "C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\skills_list\\skills.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Create a list of all the skills in the CSV file
list_skill_csv = df['skill'].tolist()

print(list_skill_csv)

list_skill_csv = ['Victory Cry', 'Auto-Tarukaja', 'Megidolaon', 'Fire Amp', 'Mediarahan', 'Samarecarm', 'Akasha Arts', 'Mind Charge', 'Growth 3', 'Deathbound', 'Maragidyne', 'Auto-Rakukaja', 'Unshaken Will', 'Wind Amp', 'Regenerate 3', 'Spell Master', 'Wind Boost', 'High Counter', 'Tempest Slash', 'Weary Thrust', 'Tetrakarn']
# Out:
# ['Cleave', 'Power Slash', 'Getsu-ei', 'Zan-ei', 'Gale Slash', 'Mighty Swing', 'Fatal End', 'Blade of Fury', 'Deathbound', "Heaven's Blade", 'Tempest Slash', 'Brave Blade', 'Scarlet Havoc', 'Vorpal Blade', 'Bash', 'Assault Dive', 'Sonic Punch', 'Swift Strike', 'Kill Rush', 'Herculean Strike', 'Gigantic Fist', 'Heat Wave', 'Vicious Strike', 'Akasha Arts', "God's Hand", 'Shadow Hound', 'Weary Thrust', 'Single Shot', 'Double Fangs', 'Holy Arrow', 'Twin Shot', 'Cruel Attack', 'Torrent Shot', 'Vile Assault', 'Poison Arrow', 'Arrow Rain', 'Myriad Arrows', 'Pralaya', 'Primal Force', 'Agi', 'Maragi', 'Agilao', 'Maragion', 'Agidyne', 'Maragidyne', 'Ragnarok', 'Ardhanari', 'Maralagidyne', 'Bufu', 'Mabufu', 'Bufula', 'Mabufula', 'Bufudyne', 'Mabufudyne', 'Niflheim', 'King and I', 'Zio', 'Mazio', 'Zionga', 'Mazionga', 'Ziodyne', 'Maziodyne', 'Thunder Reign', 'Thunder Call', 'Garu', 'Magaru', 'Garula', 'Magarula', 'Garudyne', 'Magarudyne', 'Panta Rhei', 'Hama', 'Mahama', 'Hamaon', 'Mahamaon', 'Samsara', 'Justice', 'Mudo', 'Mamudo', 'Mudoon', 'Mamudoon', 'Die for Me!', 'Foul Breath', 'Life Drain', 'Stagnant Air', 'Spirit Drain', 'Megido', 'Megidola', 'Megidolaon', 'Black Viper', 'Morning Star', 'Armageddon', 'Jack Brothers', 'Last Judge', 'Raktapaksha', 'Bewilder', 'Poisma', 'Eerie Sound', 'Marin Karin', 'Provoke', 'Pulinpa', 'Infuriate', 'Poison Mist', 'Sexy Dance', 'Evil Touch', 'Evil Smile', 'Tentarafoo', 'Virus Breath', 'Ghastly Wail', 'Dreamfest', 'Summer Dream', 'Trickster', 'Patra', 'Charmdi', 'Enradi', 'Posumudi', 'Re Patra', 'Dia', 'Me Patra', 'Media', 'Diarama', 'Recarm', 'Mediarama', 'Samarecarm', 'Diarahan', 'Amrita', 'Mediarahan', 'Salvation', 'Cadenza', 'Frolic', 'Rakukaja', 'Rakunda', 'Rebellion', 'Sukukaja', 'Sukunda', 'Tarukaja', 'Tarunda', 'Dekunda', 'Revolution', 'Elec Break', 'Fire Break', 'Ice Break', 'Marakunda', 'Masukunda', 'Matarunda', 'Power Charge', 'Wind Break', 'Dekaja', 'Marakukaja', 'Masukukaja', 'Matarukaja', 'Mind Charge', 'Makarakarn', 'Tetrakarn', 'Best Friends', 'Infinity', 'Valhalla', 'Recarmdra', 'Trafuri', 'Raging Tiger', 'Elec Boost', 'Fire Boost', 'Growth 1', 'Ice Boost', 'Wind Boost', 'Charm Boost', 'Distress Boost', 'Fear Boost', 'Panic Boost', 'Poison Boost', 'Rage Boost', 'Sharp Student', 'Counter', 'Dodge Elec', 'Dodge Fire', 'Dodge Ice', 'Dodge Pierce', 'Dodge Slash', 'Dodge Strike', 'Dodge Wind', 'Growth 2', 'Cool Breeze', 'Elec Amp', 'Evade Elec', 'Evade Fire', 'Evade Ice', 'Evade Wind', 'Fast Retreat', 'Fire Amp', 'Growth 3', 'Hama Boost', 'Ice Amp', 'Mudo Boost', 'Survive Dark', 'Survive Light', 'Wind Amp', 'Counterstrike', 'Invigorate 1', 'Regenerate 1', 'Resist Dark', 'Resist Elec', 'Resist Fire', 'Resist Ice', 'Resist Light', 'Resist Wind', 'Alertness', 'Apt Pupil', 'Endure Dark', 'Endure Light', 'Evade Pierce', 'Evade Slash', 'Evade Strike', 'High Counter', 'Null Charm', 'Null Distress', 'Null Fear', 'Null Freeze', 'Null Panic', 'Null Poison', 'Null Rage', 'Null Shock', 'Spring of Life', 'Invigorate 2', 'Null Dark', 'Null Elec', 'Null Fire', 'Null Ice', 'Null Light', 'Null Wind', 'Regenerate 2', 'Resist Pierce', 'Resist Slash', 'Resist Strike', '1hSwd Master', '2hSwd Master', 'Auto-Maraku', 'Auto-Masuku', 'Auto-Mataru', 'Auto-Rakukaja', 'Auto-Sukukaja', 'Auto-Tarukaja', 'Bow Master', 'Endure', 'Fist Master', 'Heavy Master', 'Invigorate 3', 'Regenerate 3', 'Repel Dark', 'Repel Light', 'Spear Master', 'Null Pierce', 'Null Slash', 'Null Strike', 'Repel Elec', 'Repel Fire', 'Repel Ice', 'Repel Wind', 'Absorb Elec', 'Absorb Fire', 'Absorb Ice', 'Absorb Wind', 'Ailment Boost', 'Divine Grace', 'Repel Pierce', 'Repel Slash', 'Repel Strike', 'Absorb Pierce', 'Absorb Slash', 'Absorb Strike', 'Arms Master', 'Enduring Soul', 'Spell Master', 'Unshaken Will', 'Victory Cry', 'Escape Route', 'Full Analysis', 'Healing Wave', 'Oracle', 'Support Scan', 'Third Eye']

# %%
import pyautogui
import numpy as np
import pickle
from PIL import Image
import pytesseract
import re
import difflib


pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # replace with your actual path

custom_config = r'--tessdata-dir "C:\Program Files\Tesseract-OCR\tessdata" --psm 13'









def get_images(number):

    found_skills = []
    
    for rectangle in rectangle_list:

        # Take a screenshot of the rectangle
        cropped_img = pyautogui.screenshot(region=(rectangle.x, rectangle.y, rectangle.width, rectangle.height))
        

        #cropped_img.show()
        #test
        #cropped_img = img.crop((rectangle.x, rectangle.y, rectangle.x + rectangle.width, rectangle.y + rectangle.height))

         # Convert the image to RGB
        rgb_img = cropped_img.convert('RGB')

        hex_color = '65dfcd'

        # Convert the target hex color to RGB
        target_r, target_g, target_b = tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))
        target_color = np.array([target_r, target_g, target_b])

        # Convert the image to a NumPy array
        img_array = np.array(rgb_img)

        # Calculate the Euclidean distance between each pixel's color and the target color
        color_distance = np.linalg.norm(img_array - target_color, axis=2)

        # Create a mask for pixels that are similar to the target color
        mask = color_distance < 85

        # Change the color of the pixels based on the mask
        img_array[mask] = [0, 0, 0]  # black
        img_array[~mask] = [255, 255, 255]  # white

        # Convert the NumPy array back to an image
        rgb_img = Image.fromarray(img_array)

        # Convert the image to grayscale
        gray_img = rgb_img.convert('L')

        # Apply a threshold to make it binary
        binary_img = gray_img.point(lambda x: 0 if x<128 else 255, '1')

        text = pytesseract.image_to_string(binary_img, config=custom_config)
        
        # 'remove all characters that are not letters, numbers, ' ' or '-'
        text = re.sub(r'[^a-zA-Z0-9 -]', '', text)

        # remove ' ' and '-' from the beginning and end of the string
        text = text.strip(' -')

        match = difflib.get_close_matches(text, list_skill_csv, n=1, cutoff=0.0)

        if match:
            best_match = match[0]
        else:
            best_match = ''  # No match found
            
    
        found_skills.append(best_match)
    
    return found_skills

# %%
import logging

desired_skills = [
    'High Counter',
    'Unshaken Will',
    'Panta Rhei',
    'Wind Boost',
    'Wind Amp',
    'Mind Charge',
    'Spell Master',
    'Salvation',
    ]

desired_skills_set = set(desired_skills)

# Create a logger
logging.basicConfig(filename='predictionsSkadi.log', level=logging.INFO)

skills_aquired = []
for i in range(6):
    if i == 2 or i == 3:
        skills_aquired.append(True)
    else:
        skills_aquired.append(False)

dictonary_number_key = { 
    1 : 'f6',
    2 : 'f7',
    3 : 'f8',
    4 : 'f9',
    5 : 'f1',
}

global_best_desire = 0

def verify_skills(predictions):
    global global_best_desire
    # Convert both lists to sets
    predictions_set = set(predictions)

    n = len(desired_skills_set & predictions_set)
    if n >= 1:
        if n > global_best_desire:
            global_best_desire = n
            pydirectinput.keyDown(dictonary_number_key[5])
            pydirectinput.keyUp(dictonary_number_key[5])
            print(f"Best desire: {global_best_desire}")
        if n == 5:
            return True
    return False

import pygetwindow as gw
import hashlib
import matplotlib.pyplot as plt


def check_window_change(active_window_title):
    # Check if the active window has changed
    if gw.getActiveWindow().title != active_window_title:
        print('Active window has changed. Stopping the program.')
        return True
    return False

verification_hash = None

def define_verification_rectangle():
    verify_image = pyautogui.screenshot(region=(veriification_rectangle.x, veriification_rectangle.y, veriification_rectangle.width, veriification_rectangle.height))
    
    # Convert the image to bytes
    image_bytes = verify_image.tobytes()

    # Create a hash of the image
    image_hash = hashlib.sha256(image_bytes).hexdigest()

    return image_hash


def verify_rectangle():
    verify_image = pyautogui.screenshot(region=(veriification_rectangle.x, veriification_rectangle.y, veriification_rectangle.width, veriification_rectangle.height))
    
    # Convert the image to bytes
    image_bytes = verify_image.tobytes()

    # Create a hash of the image
    image_hash = hashlib.sha256(image_bytes).hexdigest()

    if image_hash != verification_hash:
        print('Verification rectangle has changed. Stopping the program.')
        plt.imshow(verify_image)
        plt.show()
        return True

    return False


''' 
if verify_skills(predictions):
        print('found')
        pydirectinput.keyDown('esc')
        pydirectinput.keyUp('esc')
        print('esc key pressed')
        break
'''

timer(3)
# Press the F4 key
#pydirectinput.keyDown('f4')
#pydirectinput.keyUp('f4')
# Get the title of the currently active window
verification_hash = define_verification_rectangle()
active_window_title = gw.getActiveWindow().title
predict = True
while True:
    if check_window_change(active_window_title):
        break

    if verify_rectangle():
        pydirectinput.keyDown('f2')
        pydirectinput.keyUp('f2')
        predict = False
    
    pydirectinput.keyDown('p')
    pydirectinput.keyUp('p')

    predictions = get_images(i)
    # Log the predictions vector
    if predict:
        logging.info(f'{predictions}')
        print(predictions)
    else:
        predict = True
    if verify_skills(predictions):
        break

    if check_window_change(active_window_title):
        break
    
    change3wayFusion()
# Out:
# Remaining: 3 seconds
# Remaining: 2 seconds
# Remaining: 1 seconds
# ['Samarecarm', 'Unshaken Will', 'Growth 3', 'Auto-Tarukaja', 'Spell Master']
# Best desire: 2
# ['Samarecarm', 'Growth 3', 'Wind Boost', 'Wind Amp', 'Mediarahan']
# ['Wind Amp', 'High Counter', 'Regenerate 3', 'Spell Master', 'Auto-Rakukaja']
# Best desire: 3
# ['Auto-Rakukaja', 'Victory Cry', 'Samarecarm', 'Tempest Slash', 'Spell Master']
# ['Auto-Rakukaja', 'High Counter', 'Auto-Tarukaja', 'Mediarahan', 'Spell Master']
# ['Unshaken Will', 'Wind Boost', 'Spell Master', 'High Counter', 'Auto-Rakukaja']
# Best desire: 4
# ['Regenerate 3', 'Mind Charge', 'Fire Amp', 'Wind Boost', 'Spell Master']
# ['Unshaken Will', 'Mediarahan', 'Growth 3', 'Auto-Tarukaja', 'Spell Master']
# ['Auto-Rakukaja', 'Mediarahan', 'Growth 3', 'Unshaken Will', 'High Counter']
# ['Auto-Rakukaja', 'Wind Boost', 'Auto-Tarukaja', 'Growth 3', 'Fire Amp']
# ['Auto-Rakukaja', 'Fire Amp', 'Wind Boost', 'Samarecarm', 'Spell Master']
# ['Fire Amp', 'Auto-Tarukaja', 'Wind Boost', 'Spell Master', 'Wind Amp']
# ['Growth 3', 'Auto-Rakukaja', 'Wind Boost', 'Mediarahan', 'Spell Master']
# ['Victory Cry', 'Wind Amp', 'Mind Charge', 'Auto-Tarukaja', 'Wind Boost']
# ['High Counter', 'Wind Boost', 'Fire Amp', 'Auto-Rakukaja', 'Victory Cry']
# ['Mediarahan', 'Mind Charge', 'Auto-Tarukaja', 'Samarecarm', 'Growth 3']
# ['Growth 3', 'Wind Boost', 'Regenerate 3', 'Auto-Rakukaja', 'Spell Master']
# ['Mediarahan', 'Fire Amp', 'High Counter', 'Wind Boost', 'Growth 3']
# ['Wind Amp', 'Auto-Rakukaja', 'High Counter', 'Victory Cry', 'Auto-Tarukaja']
# ['Auto-Tarukaja', 'Auto-Rakukaja', 'Growth 3', 'Wind Boost', 'Samarecarm']
# ['Fire Amp', 'Wind Amp', 'Wind Boost', 'Auto-Tarukaja', 'Mind Charge']
# ['Samarecarm', 'Auto-Tarukaja', 'Wind Boost', 'Unshaken Will', 'Auto-Rakukaja']
# ['Fire Amp', 'Samarecarm', 'Growth 3', 'Regenerate 3', 'Wind Boost']
# ['Wind Boost', 'Samarecarm', 'Fire Amp', 'High Counter', 'Spell Master']
# ['Wind Boost', 'Auto-Rakukaja', 'Growth 3', 'Mind Charge', 'High Counter']
# ['Regenerate 3', 'Wind Boost', 'Mind Charge', 'Auto-Tarukaja', 'Mediarahan']
# ['Mind Charge', 'Spell Master', 'Wind Boost', 'Auto-Tarukaja', 'Samarecarm']
# ['Fire Amp', 'Wind Amp', 'High Counter', 'Mediarahan', 'Regenerate 3']
# ['Mediarahan', 'Unshaken Will', 'High Counter', 'Auto-Tarukaja', 'Auto-Rakukaja']
# ['Auto-Tarukaja', 'Regenerate 3', 'Unshaken Will', 'Victory Cry', 'Mind Charge']
# ['Growth 3', 'Wind Boost', 'Auto-Tarukaja', 'Mind Charge', 'High Counter']
# ['Mind Charge', 'Auto-Tarukaja', 'Samarecarm', 'Growth 3', 'Tempest Slash']
# ['Auto-Tarukaja', 'Mediarahan', 'Wind Boost', 'Auto-Rakukaja', 'Fire Amp']
# ['Wind Boost', 'Samarecarm', 'Spell Master', 'Auto-Rakukaja', 'Auto-Tarukaja']
# ['Auto-Tarukaja', 'Fire Amp', 'High Counter', 'Mind Charge', 'Mediarahan']
# ['Auto-Tarukaja', 'Mediarahan', 'Unshaken Will', 'Growth 3', 'Mind Charge']
# ['Auto-Tarukaja', 'Growth 3', 'Wind Boost', 'Mind Charge', 'Regenerate 3']
# ['Samarecarm', 'Auto-Tarukaja', 'Wind Amp', 'Growth 3', 'Auto-Rakukaja']
# ['Wind Amp', 'Wind Boost', 'Regenerate 3', 'Auto-Rakukaja', 'Fire Amp']
# ['Growth 3', 'High Counter', 'Victory Cry', 'Auto-Tarukaja', 'Auto-Rakukaja']
# ['Wind Boost', 'Wind Amp', 'High Counter', 'Mediarahan', 'Spell Master']
# ['Wind Boost', 'Fire Amp', 'Spell Master', 'Samarecarm', 'Mind Charge']
# ['Samarecarm', 'Victory Cry', 'Wind Boost', 'Auto-Tarukaja', 'Mind Charge']
# ['Samarecarm', 'Fire Amp', 'Growth 3', 'Wind Boost', 'Spell Master']
# ['Auto-Tarukaja', 'High Counter', 'Auto-Rakukaja', 'Wind Boost', 'Samarecarm']
# ['Wind Boost', 'Fire Amp', 'Regenerate 3', 'Auto-Rakukaja', 'Samarecarm']
# ['Auto-Rakukaja', 'Fire Amp', 'Growth 3', 'Wind Amp', 'Samarecarm']
# ['Wind Amp', 'Growth 3', 'Auto-Tarukaja', 'Mind Charge', 'Spell Master']
# ['Wind Boost', 'Fire Amp', 'Mediarahan', 'Victory Cry', 'Auto-Rakukaja']
# ['Growth 3', 'Wind Boost', 'Victory Cry', 'Spell Master', 'Fire Amp']
# ['High Counter', 'Wind Boost', 'Auto-Tarukaja', 'Regenerate 3', 'Mediarahan']
# ['Wind Amp', 'Samarecarm', 'Auto-Tarukaja', 'Fire Amp', 'Mind Charge']
# ['Auto-Rakukaja', 'Auto-Tarukaja', 'Fire Amp', 'Mediarahan', 'Wind Boost']
# ['Growth 3', 'Auto-Tarukaja', 'Mind Charge', 'Auto-Rakukaja', 'Unshaken Will']
# ['Auto-Rakukaja', 'Auto-Tarukaja', 'Fire Amp', 'Mind Charge', 'Wind Boost']
# ['Growth 3', 'Wind Amp', 'Regenerate 3', 'Mind Charge', 'Wind Boost']
# ['Victory Cry', 'Auto-Rakukaja', 'Wind Boost', 'Auto-Tarukaja', 'Tempest Slash']
# ['Fire Amp', 'Akasha Arts', 'Wind Boost', 'Megidolaon', 'Auto-Rakukaja']
# ['Mind Charge', 'Auto-Rakukaja', 'Regenerate 3', 'Samarecarm', 'Wind Amp']
# ['High Counter', 'Growth 3', 'Wind Boost', 'Wind Amp', 'Auto-Rakukaja']
# ['Regenerate 3', 'Wind Amp', 'Wind Boost', 'Growth 3', 'Unshaken Will']
# ['Auto-Rakukaja', 'Auto-Tarukaja', 'Growth 3', 'Samarecarm', 'Wind Boost']
# ['Unshaken Will', 'High Counter', 'Wind Boost', 'Fire Amp', 'Mediarahan']
# ['Fire Amp', 'Mediarahan', 'Samarecarm', 'Victory Cry', 'Wind Amp']
# ['Regenerate 3', 'High Counter', 'Wind Amp', 'Victory Cry', 'Auto-Tarukaja']
# ['Mind Charge', 'Growth 3', 'Victory Cry', 'Auto-Rakukaja', 'Deathbound']
# ['Wind Boost', 'Growth 3', 'Auto-Rakukaja', 'Fire Amp', 'Samarecarm']
# ['Wind Boost', 'Growth 3', 'Auto-Rakukaja', 'Regenerate 3', 'Auto-Tarukaja']
# ['Growth 3', 'Mind Charge', 'Auto-Tarukaja', 'High Counter', 'Samarecarm']
# ['Mediarahan', 'Wind Boost', 'Mind Charge', 'High Counter', 'Auto-Tarukaja']
# ['Growth 3', 'Wind Boost', 'Regenerate 3', 'Victory Cry', 'High Counter']
# ['Wind Boost', 'High Counter', 'Mediarahan', 'Spell Master', 'Fire Amp']
# ['Growth 3', 'Deathbound', 'Wind Boost', 'Fire Amp', 'Mediarahan']
# ['Wind Boost', 'Unshaken Will', 'Megidolaon', 'High Counter', 'Spell Master']
# ['Fire Amp', 'Auto-Rakukaja', 'Wind Boost', 'Mediarahan', 'Mind Charge']
# ['Wind Boost', 'Fire Amp', 'Spell Master', 'Auto-Rakukaja', 'Unshaken Will']
# ['Growth 3', 'Mind Charge', 'Wind Boost', 'Victory Cry', 'Auto-Tarukaja']
# ['Auto-Tarukaja', 'Megidolaon', 'Wind Boost', 'Mediarahan', 'Unshaken Will']
# ['Regenerate 3', 'Auto-Tarukaja', 'Wind Boost', 'Akasha Arts', 'Fire Amp']
# ['Wind Boost', 'Unshaken Will', 'Auto-Tarukaja', 'Fire Amp', 'Samarecarm']
# ['Unshaken Will', 'Fire Amp', 'Samarecarm', 'Auto-Rakukaja', 'Wind Boost']
# ['Regenerate 3', 'Wind Amp', 'Victory Cry', 'High Counter', 'Samarecarm']
# ['Mediarahan', 'Wind Boost', 'Auto-Tarukaja', 'Regenerate 3', 'Wind Amp']
# ['Growth 3', 'Samarecarm', 'Wind Amp', 'Fire Amp', 'Unshaken Will']
# ['Victory Cry', 'Auto-Rakukaja', 'High Counter', 'Wind Boost', 'Regenerate 3']
# ['Deathbound', 'Wind Boost', 'Spell Master', 'Mediarahan', 'Growth 3']
# ['Unshaken Will', 'Samarecarm', 'Auto-Rakukaja', 'Mind Charge', 'Fire Amp']
# ['Regenerate 3', 'Tempest Slash', 'Growth 3', 'Spell Master', 'Wind Amp']
# ['Auto-Rakukaja', 'Auto-Tarukaja', 'High Counter', 'Victory Cry', 'Spell Master']
# ['Wind Boost', 'Wind Amp', 'High Counter', 'Auto-Tarukaja', 'Mediarahan']
# ['Auto-Tarukaja', 'Growth 3', 'Wind Boost', 'Mediarahan', 'Fire Amp']
# ['Auto-Tarukaja', 'Victory Cry', 'Growth 3', 'High Counter', 'Fire Amp']
# ['Wind Boost', 'Auto-Rakukaja', 'High Counter', 'Unshaken Will', 'Mind Charge']
# ['Auto-Tarukaja', 'Wind Boost', 'Fire Amp', 'Megidolaon', 'Victory Cry']
# ['Fire Amp', 'Auto-Rakukaja', 'Wind Boost', 'Regenerate 3', 'Victory Cry']
# ['Regenerate 3', 'Mind Charge', 'Unshaken Will', 'Wind Boost', 'Auto-Tarukaja']
# ['Auto-Tarukaja', 'Auto-Rakukaja', 'Victory Cry', 'Mind Charge', 'Spell Master']
# ['Samarecarm', 'High Counter', 'Auto-Rakukaja', 'Mind Charge', 'Wind Amp']
# ['Auto-Tarukaja', 'Wind Amp', 'Mediarahan', 'Victory Cry', 'Fire Amp']
# ['Mediarahan', 'Fire Amp', 'Regenerate 3', 'Tempest Slash', 'Growth 3']
# ['Samarecarm', 'Regenerate 3', 'Mind Charge', 'Wind Boost', 'Megidolaon']
# ['Auto-Tarukaja', 'Deathbound', 'Growth 3', 'Mind Charge', 'Mediarahan']
# ['Regenerate 3', 'Auto-Tarukaja', 'Mind Charge', 'Auto-Rakukaja', 'Spell Master']
# ['Growth 3', 'Tempest Slash', 'Wind Boost', 'Samarecarm', 'Spell Master']
# ['Wind Boost', 'Auto-Tarukaja', 'Auto-Rakukaja', 'Regenerate 3', 'Fire Amp']
# ['Wind Boost', 'Fire Amp', 'Akasha Arts', 'Mediarahan', 'High Counter']
# ['Wind Boost', 'High Counter', 'Mediarahan', 'Deathbound', 'Fire Amp']
# ['Auto-Tarukaja', 'Mind Charge', 'High Counter', 'Mediarahan', 'Fire Amp']
# ['Spell Master', 'Auto-Rakukaja', 'Wind Boost', 'Fire Amp', 'Regenerate 3']
# ['Mediarahan', 'Wind Boost', 'Auto-Tarukaja', 'Wind Amp', 'Samarecarm']
# ['Auto-Tarukaja', 'Fire Amp', 'Growth 3', 'Victory Cry', 'Wind Boost']
# ['Auto-Rakukaja', 'Mind Charge', 'Regenerate 3', 'Wind Boost', 'Auto-Tarukaja']
# ['Growth 3', 'Mediarahan', 'Auto-Tarukaja', 'Wind Boost', 'Fire Amp']
# ['Auto-Rakukaja', 'Wind Amp', 'Spell Master', 'Victory Cry', 'Regenerate 3']
# ['Auto-Tarukaja', 'Fire Amp', 'Auto-Rakukaja', 'Wind Boost', 'Wind Amp']
# ['Mind Charge', 'Regenerate 3', 'Auto-Rakukaja', 'Samarecarm', 'Mediarahan']
# ['Auto-Tarukaja', 'Victory Cry', 'High Counter', 'Wind Boost', 'Megidolaon']
# ['Regenerate 3', 'Auto-Rakukaja', 'Fire Amp', 'Wind Boost', 'Samarecarm']
# ['Auto-Rakukaja', 'Mind Charge', 'Wind Boost', 'Mediarahan', 'High Counter']
# ['Growth 3', 'Auto-Rakukaja', 'Mind Charge', 'Wind Amp', 'Samarecarm']
# ['Wind Amp', 'Wind Boost', 'Mediarahan', 'Growth 3', 'Deathbound']
# ['Auto-Tarukaja', 'Mind Charge', 'Wind Boost', 'Samarecarm', 'Unshaken Will']
# ['Spell Master', 'Victory Cry', 'Wind Boost', 'Auto-Rakukaja', 'Akasha Arts']
# ['Mediarahan', 'Auto-Rakukaja', 'Wind Amp', 'Wind Boost', 'High Counter']
# ['Wind Amp', 'Auto-Rakukaja', 'Auto-Tarukaja', 'Mind Charge', 'Wind Boost']
# ['Mediarahan', 'Wind Amp', 'Auto-Rakukaja', 'Growth 3', 'Fire Amp']
# ['Mind Charge', 'Growth 3', 'Wind Boost', 'Auto-Tarukaja', 'Auto-Rakukaja']
# ['High Counter', 'Wind Boost', 'Regenerate 3', 'Fire Amp', 'Auto-Tarukaja']
# ['Wind Boost', 'Samarecarm', 'Auto-Rakukaja', 'Fire Amp', 'Wind Amp']
# ['Auto-Rakukaja', 'Wind Boost', 'Auto-Tarukaja', 'Wind Amp', 'Unshaken Will']
# ['Wind Boost', 'Unshaken Will', 'High Counter', 'Mind Charge', 'Wind Amp']
# Best desire: 5

# %%
global_best_desire
# Out:
# 5
