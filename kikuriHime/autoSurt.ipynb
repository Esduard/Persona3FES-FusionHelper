# %%
class Rectangle:
    def __init__(self, x, y, width, height):
        self.x = x
        self.y = y
        self.width = width
        self.height = height
    def __str__(self):
        return f"Rectangle(x={self.x}, y={self.y}, width={self.width}, height={self.height})"
        

class SkillAnalyzer():

    def __init__(self, interval_of_inheritance):
        x = 477
        y = 1007
        width = 1001 - x
        height = 1078 - y

        start, end = interval_of_inheritance

        number_list = list(range(start - 1, end))

        for i in number_list:
            if i < 4:
                x = 477
            else:
                x = 1012

            rec = Rectangle(x,y + (height * i), width, height)
            rectangle_list.append(rec)
        


rectangle_list = []

# %%
print(len(rectangle_list))
# Out:
# 5

# %%
veriification_rectangle = Rectangle(467, 83, 657 - 467, 145 - 83)

# %%
import pyautogui
import os
import time

def timer(seconds):
    # Start a 5-second timer
    for i in range(seconds, 0, -1):
        print(f"Remaining: {i} seconds")
        time.sleep(1)

def screenshot(id):
    # Specify the directory where you want to save the screenshot
    directory = r"C:\Users\Eduardo\Pictures\Screenshots\persona3ChiYou"

    # Ensure the directory exists
    os.makedirs(directory, exist_ok=True)

    # Capture the screenshot
    screenshot = pyautogui.screenshot()

    # Save the screenshot to the specified directory
    screenshot.save(os.path.join(directory, f"{id}.png"))

import pydirectinput
import time

def changeTelos():
    # Press the 'l' key
    pydirectinput.press('l')
    


    # Press the 'm' key
    pydirectinput.press('m')
    

def timed_input(seconds, key):
    pydirectinput.press(key)
    time.sleep(seconds)

def change3wayFusion():
    for i in range(3):
        # Press the 'l' key
        timed_input(0.01, 'l')

    timed_input(0.01, 'm')
    
    for i in range(2):
        # Press the 'l' key
        timed_input(0.01, 'w')
        
    
    timed_input(0.01, 'm')

    for i in range(1):
        # Press the 'l' key
        timed_input(0.01, 'w')
        
    # Press the 'm' key
    pydirectinput.keyDown('f4')
    pydirectinput.keyUp('f4')
    timed_input(0.01, 'm')
    pydirectinput.keyDown('f4')
    pydirectinput.keyUp('f4')

# %%
# open 'skills.csv'
import pandas as pd


file_path = "C:\\Users\\Eduardo\\Documents\\Projects\\AutoTelos\\Persona3FES-FusionHelper\\skills_list\\skills.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Create a list of all the skills in the CSV file
list_skill_csv = df['skill'].tolist()

print(list_skill_csv)

list_skill_csv = ['Counter', 'Power Slash', 'Victory Cry', 'Getsu-ei', 'Rakukaja', 'Dodge Ice', 'Survive Light', 'Mind Charge', 'Morning Star', 'Mudoon', 'Primal Force', 'Absorb Slash', 'Wind Amp', 'Mighty Swing', 'Spell Master', 'High Counter', 'Fire Boost', 'Zan-ei', 'Garula', 'Dodge Slash', 'Life Drain', 'Panta Rhei', 'Salvation']
# Out:
# ['Cleave', 'Power Slash', 'Getsu-ei', 'Zan-ei', 'Gale Slash', 'Mighty Swing', 'Fatal End', 'Blade of Fury', 'Deathbound', "Heaven's Blade", 'Tempest Slash', 'Brave Blade', 'Scarlet Havoc', 'Vorpal Blade', 'Bash', 'Assault Dive', 'Sonic Punch', 'Swift Strike', 'Kill Rush', 'Herculean Strike', 'Gigantic Fist', 'Heat Wave', 'Vicious Strike', 'Akasha Arts', "God's Hand", 'Shadow Hound', 'Weary Thrust', 'Single Shot', 'Double Fangs', 'Holy Arrow', 'Twin Shot', 'Cruel Attack', 'Torrent Shot', 'Vile Assault', 'Poison Arrow', 'Arrow Rain', 'Myriad Arrows', 'Pralaya', 'Primal Force', 'Agi', 'Maragi', 'Agilao', 'Maragion', 'Agidyne', 'Maragidyne', 'Ragnarok', 'Ardhanari', 'Maralagidyne', 'Bufu', 'Mabufu', 'Bufula', 'Mabufula', 'Bufudyne', 'Mabufudyne', 'Niflheim', 'King and I', 'Zio', 'Mazio', 'Zionga', 'Mazionga', 'Ziodyne', 'Maziodyne', 'Thunder Reign', 'Thunder Call', 'Garu', 'Magaru', 'Garula', 'Magarula', 'Garudyne', 'Magarudyne', 'Panta Rhei', 'Hama', 'Mahama', 'Hamaon', 'Mahamaon', 'Samsara', 'Justice', 'Mudo', 'Mamudo', 'Mudoon', 'Mamudoon', 'Die for Me!', 'Foul Breath', 'Life Drain', 'Stagnant Air', 'Spirit Drain', 'Megido', 'Megidola', 'Megidolaon', 'Black Viper', 'Morning Star', 'Armageddon', 'Jack Brothers', 'Last Judge', 'Raktapaksha', 'Bewilder', 'Poisma', 'Eerie Sound', 'Marin Karin', 'Provoke', 'Pulinpa', 'Infuriate', 'Poison Mist', 'Sexy Dance', 'Evil Touch', 'Evil Smile', 'Tentarafoo', 'Virus Breath', 'Ghastly Wail', 'Dreamfest', 'Summer Dream', 'Trickster', 'Patra', 'Charmdi', 'Enradi', 'Posumudi', 'Re Patra', 'Dia', 'Me Patra', 'Media', 'Diarama', 'Recarm', 'Mediarama', 'Samarecarm', 'Diarahan', 'Amrita', 'Mediarahan', 'Salvation', 'Cadenza', 'Frolic', 'Rakukaja', 'Rakunda', 'Rebellion', 'Sukukaja', 'Sukunda', 'Tarukaja', 'Tarunda', 'Dekunda', 'Revolution', 'Elec Break', 'Fire Break', 'Ice Break', 'Marakunda', 'Masukunda', 'Matarunda', 'Power Charge', 'Wind Break', 'Dekaja', 'Marakukaja', 'Masukukaja', 'Matarukaja', 'Mind Charge', 'Makarakarn', 'Tetrakarn', 'Best Friends', 'Infinity', 'Valhalla', 'Recarmdra', 'Trafuri', 'Raging Tiger', 'Elec Boost', 'Fire Boost', 'Growth 1', 'Ice Boost', 'Wind Boost', 'Charm Boost', 'Distress Boost', 'Fear Boost', 'Panic Boost', 'Poison Boost', 'Rage Boost', 'Sharp Student', 'Counter', 'Dodge Elec', 'Dodge Fire', 'Dodge Ice', 'Dodge Pierce', 'Dodge Slash', 'Dodge Strike', 'Dodge Wind', 'Growth 2', 'Cool Breeze', 'Elec Amp', 'Evade Elec', 'Evade Fire', 'Evade Ice', 'Evade Wind', 'Fast Retreat', 'Fire Amp', 'Growth 3', 'Hama Boost', 'Ice Amp', 'Mudo Boost', 'Survive Dark', 'Survive Light', 'Wind Amp', 'Counterstrike', 'Invigorate 1', 'Regenerate 1', 'Resist Dark', 'Resist Elec', 'Resist Fire', 'Resist Ice', 'Resist Light', 'Resist Wind', 'Alertness', 'Apt Pupil', 'Endure Dark', 'Endure Light', 'Evade Pierce', 'Evade Slash', 'Evade Strike', 'High Counter', 'Null Charm', 'Null Distress', 'Null Fear', 'Null Freeze', 'Null Panic', 'Null Poison', 'Null Rage', 'Null Shock', 'Spring of Life', 'Invigorate 2', 'Null Dark', 'Null Elec', 'Null Fire', 'Null Ice', 'Null Light', 'Null Wind', 'Regenerate 2', 'Resist Pierce', 'Resist Slash', 'Resist Strike', '1hSwd Master', '2hSwd Master', 'Auto-Maraku', 'Auto-Masuku', 'Auto-Mataru', 'Auto-Rakukaja', 'Auto-Sukukaja', 'Auto-Tarukaja', 'Bow Master', 'Endure', 'Fist Master', 'Heavy Master', 'Invigorate 3', 'Regenerate 3', 'Repel Dark', 'Repel Light', 'Spear Master', 'Null Pierce', 'Null Slash', 'Null Strike', 'Repel Elec', 'Repel Fire', 'Repel Ice', 'Repel Wind', 'Absorb Elec', 'Absorb Fire', 'Absorb Ice', 'Absorb Wind', 'Ailment Boost', 'Divine Grace', 'Repel Pierce', 'Repel Slash', 'Repel Strike', 'Absorb Pierce', 'Absorb Slash', 'Absorb Strike', 'Arms Master', 'Enduring Soul', 'Spell Master', 'Unshaken Will', 'Victory Cry', 'Escape Route', 'Full Analysis', 'Healing Wave', 'Oracle', 'Support Scan', 'Third Eye']

# %%
import pyautogui
import numpy as np
import pickle
from PIL import Image
import pytesseract
import re
import difflib


pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # replace with your actual path

custom_config = r'--tessdata-dir "C:\Program Files\Tesseract-OCR\tessdata" --psm 13'









def get_images(number):

    found_skills = []
    
    for rectangle in rectangle_list:

        # Take a screenshot of the rectangle
        cropped_img = pyautogui.screenshot(region=(rectangle.x, rectangle.y, rectangle.width, rectangle.height))
        

        #cropped_img.show()
        #test
        #cropped_img = img.crop((rectangle.x, rectangle.y, rectangle.x + rectangle.width, rectangle.y + rectangle.height))

         # Convert the image to RGB
        rgb_img = cropped_img.convert('RGB')

        hex_color = '65dfcd'

        # Convert the target hex color to RGB
        target_r, target_g, target_b = tuple(int(hex_color[i:i+2], 16) for i in (0, 2, 4))
        target_color = np.array([target_r, target_g, target_b])

        # Convert the image to a NumPy array
        img_array = np.array(rgb_img)

        # Calculate the Euclidean distance between each pixel's color and the target color
        color_distance = np.linalg.norm(img_array - target_color, axis=2)

        # Create a mask for pixels that are similar to the target color
        mask = color_distance < 85

        # Change the color of the pixels based on the mask
        img_array[mask] = [0, 0, 0]  # black
        img_array[~mask] = [255, 255, 255]  # white

        # Convert the NumPy array back to an image
        rgb_img = Image.fromarray(img_array)

        # Convert the image to grayscale
        gray_img = rgb_img.convert('L')

        # Apply a threshold to make it binary
        binary_img = gray_img.point(lambda x: 0 if x<128 else 255, '1')

        text = pytesseract.image_to_string(binary_img, config=custom_config)
        
        # 'remove all characters that are not letters, numbers, ' ' or '-'
        text = re.sub(r'[^a-zA-Z0-9 -]', '', text)

        # remove ' ' and '-' from the beginning and end of the string
        text = text.strip(' -')

        match = difflib.get_close_matches(text, list_skill_csv, n=1, cutoff=0.0)

        if match:
            best_match = match[0]
        else:
            best_match = ''  # No match found
            
    
        found_skills.append(best_match)
    
    return found_skills

# %%
import logging

desired_skills = [
    'High Counter',
    'Unshaken Will',
    'Panta Rhei',
    'Wind Boost',
    'Wind Amp',
    'Mind Charge',
    'Spell Master',
    'Salvation',
    ]

desired_skills_set = set(desired_skills)

# Create a logger
logging.basicConfig(filename='predictionsSurt.log', level=logging.INFO)

skills_aquired = []
for i in range(6):
    if i == 2 or i == 3:
        skills_aquired.append(True)
    else:
        skills_aquired.append(False)

dictonary_number_key = { 
    1 : 'f6',
    2 : 'f7',
    3 : 'f8',
    4 : 'f9',
    5 : 'f1',
}

global_best_desire = 3

def verify_skills(predictions):
    global global_best_desire
    # Convert both lists to sets
    predictions_set = set(predictions)

    n = len(desired_skills_set & predictions_set)
    if n >= 1:
        if n > global_best_desire:
            global_best_desire = n
            pydirectinput.keyDown(dictonary_number_key[5])
            pydirectinput.keyUp(dictonary_number_key[5])
            print(f"Best desire: {global_best_desire}")
        if n == 5:
            return True
    return False

import pygetwindow as gw
import hashlib
import matplotlib.pyplot as plt


def check_window_change(active_window_title):
    # Check if the active window has changed
    if gw.getActiveWindow().title != active_window_title:
        print('Active window has changed. Stopping the program.')
        return True
    return False

verification_hash = None

def define_verification_rectangle():
    verify_image = pyautogui.screenshot(region=(veriification_rectangle.x, veriification_rectangle.y, veriification_rectangle.width, veriification_rectangle.height))
    
    # Convert the image to bytes
    image_bytes = verify_image.tobytes()

    # Create a hash of the image
    image_hash = hashlib.sha256(image_bytes).hexdigest()

    return image_hash


def verify_rectangle():
    verify_image = pyautogui.screenshot(region=(veriification_rectangle.x, veriification_rectangle.y, veriification_rectangle.width, veriification_rectangle.height))
    
    # Convert the image to bytes
    image_bytes = verify_image.tobytes()

    # Create a hash of the image
    image_hash = hashlib.sha256(image_bytes).hexdigest()

    if image_hash != verification_hash:
        print('Verification rectangle has changed. Stopping the program.')
        plt.imshow(verify_image)
        plt.show()
        return True

    return False


''' 
if verify_skills(predictions):
        print('found')
        pydirectinput.keyDown('esc')
        pydirectinput.keyUp('esc')
        print('esc key pressed')
        break
'''

timer(3)
# Press the F4 key
#pydirectinput.keyDown('f4')
#pydirectinput.keyUp('f4')
# Get the title of the currently active window
verification_hash = define_verification_rectangle()
active_window_title = gw.getActiveWindow().title
predict = True
while True:
    if check_window_change(active_window_title):
        break

    if verify_rectangle():
        pydirectinput.keyDown('f2')
        pydirectinput.keyUp('f2')
        predict = False
    
    pydirectinput.keyDown('p')
    pydirectinput.keyUp('p')

    predictions = get_images(i)
    # Log the predictions vector
    if predict:
        logging.info(f'{predictions}')
        print(predictions)
    else:
        predict = True
    if verify_skills(predictions):
        break

    if check_window_change(active_window_title):
        break
    
    change3wayFusion()
# Out:
# Remaining: 3 seconds
# Remaining: 2 seconds
# Remaining: 1 seconds
# ['Victory Cry', 'Rakukaja', 'Dodge Ice', 'Wind Amp', 'Absorb Slash']
# ['Dodge Ice', 'Absorb Slash', 'Rakukaja', 'Wind Amp', 'Dodge Slash']
# ['Survive Light', 'Counter', 'Dodge Slash', 'Wind Amp', 'Rakukaja']
# ['Rakukaja', 'Victory Cry', 'Mudoon', 'Survive Light', 'Dodge Slash']
# ['Rakukaja', 'Counter', 'Getsu-ei', 'Mudoon', 'Spell Master']
# ['High Counter', 'Wind Amp', 'Dodge Slash', 'Salvation', 'Mudoon']
# ['Dodge Ice', 'Wind Amp', 'Mudoon', 'Mighty Swing', 'Victory Cry']
# ['Zan-ei', 'Wind Amp', 'Dodge Ice', 'High Counter', 'Survive Light']
# ['Survive Light', 'Victory Cry', 'Spell Master', 'High Counter', 'Dodge Slash']
# ['Zan-ei', 'Salvation', 'Mind Charge', 'Survive Light', 'Mudoon']
# ['Rakukaja', 'Dodge Slash', 'Victory Cry', 'Counter', 'Mighty Swing']
# ['Power Slash', 'Mudoon', 'Absorb Slash', 'Dodge Slash', 'Dodge Ice']
# ['Absorb Slash', 'Survive Light', 'Wind Amp', 'Salvation', 'Mudoon']
# ['Getsu-ei', 'Mind Charge', 'Wind Amp', 'Rakukaja', 'Victory Cry']
# ['Dodge Slash', 'Spell Master', 'High Counter', 'Counter', 'Mind Charge']
# ['Mind Charge', 'Dodge Slash', 'Power Slash', 'Dodge Ice', 'Mighty Swing']
# ['Rakukaja', 'Mudoon', 'Victory Cry', 'Dodge Slash', 'Counter']
# ['Rakukaja', 'Dodge Slash', 'Mudoon', 'Absorb Slash', 'Dodge Ice']
# ['Survive Light', 'Life Drain', 'Counter', 'Dodge Ice', 'Dodge Slash']
# ['Zan-ei', 'Mudoon', 'Dodge Ice', 'Dodge Slash', 'Mind Charge']
# ['Survive Light', 'Wind Amp', 'Rakukaja', 'High Counter', 'Spell Master']
# ['Wind Amp', 'Salvation', 'Counter', 'Dodge Slash', 'Power Slash']
# ['Rakukaja', 'Survive Light', 'Dodge Ice', 'Life Drain', 'Victory Cry']
# ['Dodge Ice', 'Counter', 'Rakukaja', 'Dodge Slash', 'Mudoon']
# ['Survive Light', 'Mind Charge', 'Victory Cry', 'High Counter', 'Mudoon']
# ['Wind Amp', 'Victory Cry', 'Salvation', 'Rakukaja', 'Counter']
# ['Dodge Ice', 'Wind Amp', 'High Counter', 'Dodge Slash', 'Rakukaja']
# ['Rakukaja', 'Counter', 'Mind Charge', 'Salvation', 'High Counter']
# ['Victory Cry', 'Salvation', 'Counter', 'Mudoon', 'Dodge Slash']
# ['Rakukaja', 'Dodge Slash', 'Victory Cry', 'Mudoon', 'Counter']
# ['Mighty Swing', 'Getsu-ei', 'Dodge Slash', 'Dodge Ice', 'Rakukaja']
# ['Mudoon', 'Survive Light', 'Zan-ei', 'Dodge Ice', 'Mighty Swing']
# ['Mind Charge', 'Dodge Slash', 'Dodge Ice', 'Spell Master', 'Rakukaja']
# ['Mind Charge', 'Counter', 'Dodge Slash', 'Rakukaja', 'Mudoon']
# ['Mind Charge', 'Morning Star', 'Rakukaja', 'Dodge Slash', 'Counter']
# ['Mudoon', 'Mind Charge', 'Counter', 'High Counter', 'Dodge Ice']
# ['Dodge Slash', 'Mighty Swing', 'Dodge Ice', 'Victory Cry', 'Survive Light']
# ['Wind Amp', 'Mudoon', 'Dodge Slash', 'Counter', 'Victory Cry']
# ['Getsu-ei', 'Rakukaja', 'Victory Cry', 'Power Slash', 'High Counter']
# ['Counter', 'Dodge Slash', 'Rakukaja', 'High Counter', 'Mind Charge']
# ['Counter', 'Getsu-ei', 'Rakukaja', 'Dodge Ice', 'Zan-ei']
# ['Survive Light', 'High Counter', 'Rakukaja', 'Dodge Slash', 'Dodge Ice']
# ['Rakukaja', 'Mudoon', 'Mind Charge', 'High Counter', 'Counter']
# ['Survive Light', 'Rakukaja', 'High Counter', 'Life Drain', 'Dodge Slash']
# ['Counter', 'Mind Charge', 'Rakukaja', 'Dodge Ice', 'Getsu-ei']
# ['Life Drain', 'Dodge Ice', 'Mind Charge', 'Dodge Slash', 'Rakukaja']
# ['Mind Charge', 'Survive Light', 'Rakukaja', 'High Counter', 'Power Slash']
# ['Rakukaja', 'Spell Master', 'Dodge Slash', 'Counter', 'Wind Amp']
# ['Dodge Ice', 'Rakukaja', 'Salvation', 'Wind Amp', 'Counter']
# ['Getsu-ei', 'Mudoon', 'Primal Force', 'Mind Charge', 'Dodge Ice']
# ['Life Drain', 'Power Slash', 'Zan-ei', 'Rakukaja', 'Dodge Ice']
# ['Mind Charge', 'Counter', 'Life Drain', 'Dodge Slash', 'Getsu-ei']
# ['Dodge Ice', 'Wind Amp', 'Absorb Slash', 'Spell Master', 'Survive Light']
# ['Dodge Slash', 'Rakukaja', 'Counter', 'Salvation', 'Wind Amp']
# ['Power Slash', 'Wind Amp', 'Getsu-ei', 'Mind Charge', 'Survive Light']
# ['Survive Light', 'Dodge Slash', 'Dodge Ice', 'Spell Master', 'Rakukaja']
# ['Victory Cry', 'Counter', 'Mighty Swing', 'Mudoon', 'Power Slash']
# ['Zan-ei', 'High Counter', 'Rakukaja', 'Wind Amp', 'Dodge Slash']
# ['Dodge Slash', 'Life Drain', 'High Counter', 'Counter', 'Mind Charge']
# ['Counter', 'Spell Master', 'Dodge Ice', 'Mudoon', 'Wind Amp']
# ['Counter', 'Dodge Ice', 'Zan-ei', 'Rakukaja', 'Victory Cry']
# ['Dodge Ice', 'Mind Charge', 'Mudoon', 'Victory Cry', 'Absorb Slash']
# ['Dodge Slash', 'Mudoon', 'Getsu-ei', 'High Counter', 'Life Drain']
# ['Survive Light', 'Rakukaja', 'Counter', 'Absorb Slash', 'Dodge Ice']
# ['Power Slash', 'Rakukaja', 'Wind Amp', 'Survive Light', 'Dodge Slash']
# ['Victory Cry', 'Mind Charge', 'Rakukaja', 'Wind Amp', 'Power Slash']
# ['High Counter', 'Salvation', 'Wind Amp', 'Mudoon', 'Dodge Slash']
# ['Mind Charge', 'Power Slash', 'Survive Light', 'Counter', 'Mudoon']
# ['Mind Charge', 'High Counter', 'Rakukaja', 'Dodge Slash', 'Zan-ei']
# ['Dodge Ice', 'Victory Cry', 'Wind Amp', 'High Counter', 'Primal Force']
# ['High Counter', 'Mudoon', 'Rakukaja', 'Victory Cry', 'Counter']
# ['Dodge Slash', 'Counter', 'Wind Amp', 'Salvation', 'Mudoon']
# ['Getsu-ei', 'Mind Charge', 'Rakukaja', 'High Counter', 'Mudoon']
# ['Wind Amp', 'Mudoon', 'Mind Charge', 'Dodge Slash', 'Rakukaja']
# ['Survive Light', 'Life Drain', 'Dodge Slash', 'Dodge Ice', 'Absorb Slash']
# ['Dodge Ice', 'Mind Charge', 'Wind Amp', 'Counter', 'Salvation']
# ['Rakukaja', 'Mind Charge', 'Counter', 'Life Drain', 'Dodge Ice']
# ['Life Drain', 'Counter', 'Mudoon', 'Rakukaja', 'Victory Cry']
# ['Survive Light', 'Absorb Slash', 'Wind Amp', 'Getsu-ei', 'Dodge Ice']
# ['Mudoon', 'Victory Cry', 'Dodge Slash', 'High Counter', 'Mighty Swing']
# ['Wind Amp', 'Survive Light', 'Rakukaja', 'Dodge Slash', 'High Counter']
# ['Getsu-ei', 'Mind Charge', 'Mudoon', 'Dodge Ice', 'Rakukaja']
# ['Absorb Slash', 'Wind Amp', 'High Counter', 'Counter', 'Survive Light']
# ['Victory Cry', 'Survive Light', 'Dodge Slash', 'Dodge Ice', 'Counter']
# ['Survive Light', 'Rakukaja', 'Salvation', 'Dodge Ice', 'High Counter']
# ['Life Drain', 'Salvation', 'Mudoon', 'High Counter', 'Zan-ei']
# ['Rakukaja', 'Wind Amp', 'Dodge Ice', 'Absorb Slash', 'Survive Light']
# ['Mudoon', 'Survive Light', 'Victory Cry', 'Dodge Slash', 'Wind Amp']
# ['Getsu-ei', 'Counter', 'Mudoon', 'Mind Charge', 'Survive Light']
# ['Dodge Slash', 'Dodge Ice', 'Counter', 'Spell Master', 'High Counter']
# ['Zan-ei', 'Dodge Slash', 'Salvation', 'Victory Cry', 'Mudoon']
# ['Dodge Slash', 'Mind Charge', 'High Counter', 'Rakukaja', 'Survive Light']
# ['Mighty Swing', 'Counter', 'Victory Cry', 'High Counter', 'Rakukaja']
# ['Absorb Slash', 'Mudoon', 'Rakukaja', 'Mind Charge', 'Salvation']
# ['High Counter', 'Counter', 'Dodge Slash', 'Rakukaja', 'Spell Master']
# ['Counter', 'Survive Light', 'High Counter', 'Dodge Slash', 'Dodge Ice']
# ['Zan-ei', 'Dodge Ice', 'Counter', 'Rakukaja', 'Absorb Slash']
# ['Wind Amp', 'Counter', 'Dodge Ice', 'Salvation', 'Survive Light']
# ['Dodge Slash', 'Rakukaja', 'Wind Amp', 'Survive Light', 'Getsu-ei']
# ['Absorb Slash', 'Survive Light', 'Mudoon', 'High Counter', 'Mind Charge']
# ['Survive Light', 'Zan-ei', 'Counter', 'Victory Cry', 'Mudoon']
# ['Absorb Slash', 'Rakukaja', 'Dodge Ice', 'Salvation', 'Getsu-ei']
# ['Wind Amp', 'Zan-ei', 'Dodge Slash', 'Rakukaja', 'Spell Master']
# ['Wind Amp', 'Absorb Slash', 'Rakukaja', 'Dodge Slash', 'Survive Light']
# ['Survive Light', 'Dodge Ice', 'Primal Force', 'Mighty Swing', 'High Counter']
# ['Rakukaja', 'Mind Charge', 'Zan-ei', 'Dodge Slash', 'Absorb Slash']
# ['Counter', 'Mudoon', 'Rakukaja', 'High Counter', 'Victory Cry']
# ['Power Slash', 'Rakukaja', 'Counter', 'Dodge Ice', 'Mudoon']
# ['Absorb Slash', 'Survive Light', 'Dodge Ice', 'Spell Master', 'High Counter']
# ['Mind Charge', 'Absorb Slash', 'High Counter', 'Life Drain', 'Salvation']
# ['Mind Charge', 'Rakukaja', 'Mudoon', 'Dodge Slash', 'High Counter']
# ['Absorb Slash', 'Rakukaja', 'Getsu-ei', 'Survive Light', 'Mudoon']
# ['Dodge Slash', 'Rakukaja', 'Wind Amp', 'Counter', 'Absorb Slash']
# ['Absorb Slash', 'Mudoon', 'Wind Amp', 'Rakukaja', 'Getsu-ei']
# ['Counter', 'Survive Light', 'Rakukaja', 'Mind Charge', 'Absorb Slash']
# ['Mind Charge', 'Dodge Ice', 'Life Drain', 'Zan-ei', 'Rakukaja']
# ['Rakukaja', 'Mind Charge', 'Life Drain', 'Spell Master', 'Survive Light']
# ['Survive Light', 'Dodge Ice', 'Mudoon', 'Mind Charge', 'Rakukaja']
# ['High Counter', 'Mind Charge', 'Mudoon', 'Getsu-ei', 'Rakukaja']
# ['Dodge Slash', 'Mind Charge', 'Counter', 'Power Slash', 'Mighty Swing']
# ['Wind Amp', 'Dodge Slash', 'Salvation', 'Dodge Ice', 'Survive Light']
# ['Survive Light', 'Rakukaja', 'Absorb Slash', 'Mudoon', 'Wind Amp']
# ['High Counter', 'Dodge Ice', 'Survive Light', 'Life Drain', 'Mind Charge']
# ['Zan-ei', 'Rakukaja', 'Counter', 'Mudoon', 'Mind Charge']
# ['Spell Master', 'Counter', 'Rakukaja', 'Survive Light', 'Primal Force']
# ['High Counter', 'Wind Amp', 'Counter', 'Mudoon', 'Spell Master']
# ['Counter', 'Rakukaja', 'Dodge Slash', 'Mighty Swing', 'Wind Amp']
# ['Victory Cry', 'Mudoon', 'Survive Light', 'Wind Amp', 'High Counter']
# ['Rakukaja', 'Spell Master', 'Wind Amp', 'Counter', 'Dodge Slash']
# ['Dodge Slash', 'Rakukaja', 'Zan-ei', 'Wind Amp', 'Victory Cry']
# ['Mudoon', 'Survive Light', 'Mind Charge', 'Rakukaja', 'Dodge Slash']
# ['High Counter', 'Rakukaja', 'Dodge Ice', 'Mudoon', 'Salvation']
# ['Salvation', 'Survive Light', 'Dodge Ice', 'Counter', 'Zan-ei']
# ['Dodge Slash', 'Mudoon', 'Rakukaja', 'Counter', 'Victory Cry']
# ['Spell Master', 'High Counter', 'Rakukaja', 'Counter', 'Getsu-ei']
# ['Mind Charge', 'Absorb Slash', 'Getsu-ei', 'Dodge Slash', 'Dodge Ice']
# ['Survive Light', 'Rakukaja', 'Dodge Ice', 'Salvation', 'Mind Charge']
# ['Dodge Slash', 'Rakukaja', 'Dodge Ice', 'Survive Light', 'Counter']
# ['Wind Amp', 'Victory Cry', 'High Counter', 'Absorb Slash', 'Counter']
# ['Getsu-ei', 'Mind Charge', 'High Counter', 'Mighty Swing', 'Rakukaja']
# ['Survive Light', 'Salvation', 'Dodge Slash', 'Counter', 'Dodge Ice']
# ['Survive Light', 'Dodge Ice', 'Rakukaja', 'Salvation', 'Victory Cry']
# ['Getsu-ei', 'Rakukaja', 'Dodge Slash', 'Absorb Slash', 'Dodge Ice']
# ['Dodge Slash', 'Dodge Ice', 'Survive Light', 'Salvation', 'Victory Cry']
# ['Counter', 'Rakukaja', 'Zan-ei', 'Mudoon', 'Victory Cry']
# ['Mind Charge', 'Mighty Swing', 'Counter', 'Survive Light', 'Dodge Ice']
# ['Wind Amp', 'Survive Light', 'Spell Master', 'Dodge Ice', 'Rakukaja']
# ['Mudoon', 'Rakukaja', 'Dodge Ice', 'Dodge Slash', 'Salvation']
# ['Victory Cry', 'Salvation', 'High Counter', 'Survive Light', 'Mind Charge']
# ['Mudoon', 'Spell Master', 'Zan-ei', 'Mighty Swing', 'Dodge Ice']
# ['Life Drain', 'Getsu-ei', 'Counter', 'Rakukaja', 'Mind Charge']
# ['Rakukaja', 'Mudoon', 'Mind Charge', 'Dodge Ice', 'Survive Light']
# ['Mighty Swing', 'Victory Cry', 'Counter', 'Power Slash', 'Wind Amp']
# ['Rakukaja', 'Mudoon', 'Power Slash', 'Mighty Swing', 'Wind Amp']
# ['Mind Charge', 'Dodge Ice', 'Counter', 'Rakukaja', 'Salvation']
# ['High Counter', 'Survive Light', 'Counter', 'Wind Amp', 'Mind Charge']
# ['Rakukaja', 'Spell Master', 'High Counter', 'Mighty Swing', 'Life Drain']
# ['Mudoon', 'High Counter', 'Dodge Ice', 'Survive Light', 'Absorb Slash']
# ['Dodge Ice', 'Counter', 'Rakukaja', 'Morning Star', 'Wind Amp']
# ['Salvation', 'Wind Amp', 'Mudoon', 'Mind Charge', 'Power Slash']
# ['High Counter', 'Dodge Slash', 'Survive Light', 'Salvation', 'Wind Amp']
# ['Salvation', 'Dodge Slash', 'Dodge Ice', 'Rakukaja', 'Absorb Slash']
# ['Victory Cry', 'Rakukaja', 'Mind Charge', 'Dodge Slash', 'Life Drain']
# ['Mind Charge', 'Counter', 'Rakukaja', 'Spell Master', 'Wind Amp']
# ['Dodge Ice', 'Rakukaja', 'Survive Light', 'Counter', 'Absorb Slash']
# ['Mudoon', 'Dodge Slash', 'Rakukaja', 'Absorb Slash', 'Wind Amp']
# ['Mind Charge', 'Wind Amp', 'Victory Cry', 'Rakukaja', 'Power Slash']
# ['Dodge Slash', 'Mind Charge', 'Spell Master', 'Survive Light', 'Wind Amp']
# ['Rakukaja', 'Wind Amp', 'Victory Cry', 'Survive Light', 'Dodge Slash']
# ['Survive Light', 'Wind Amp', 'Mighty Swing', 'Mind Charge', 'Spell Master']
# ['Absorb Slash', 'Dodge Ice', 'Power Slash', 'Wind Amp', 'Mind Charge']
# ['Counter', 'Salvation', 'Power Slash', 'Mind Charge', 'Wind Amp']
# ['Power Slash', 'Wind Amp', 'Morning Star', 'Mind Charge', 'Getsu-ei']
# ['Dodge Ice', 'Counter', 'High Counter', 'Life Drain', 'Mudoon']
# ['Rakukaja', 'Getsu-ei', 'Dodge Ice', 'Wind Amp', 'Survive Light']
# ['Counter', 'High Counter', 'Rakukaja', 'Dodge Slash', 'Survive Light']
# ['Counter', 'Wind Amp', 'Mind Charge', 'Mudoon', 'Dodge Slash']
# ['Victory Cry', 'Salvation', 'Dodge Slash', 'Dodge Ice', 'Rakukaja']
# ['Mind Charge', 'Rakukaja', 'Victory Cry', 'Absorb Slash', 'Dodge Slash']
# ['Dodge Slash', 'Counter', 'Zan-ei', 'Mind Charge', 'Getsu-ei']
# ['Rakukaja', 'Survive Light', 'Getsu-ei', 'Counter', 'Mudoon']
# ['Counter', 'Mind Charge', 'Power Slash', 'Dodge Slash', 'Rakukaja']
# ['Rakukaja', 'Dodge Ice', 'Power Slash', 'Wind Amp', 'Survive Light']
# ['High Counter', 'Spell Master', 'Absorb Slash', 'Dodge Ice', 'Wind Amp']
# ['Wind Amp', 'Victory Cry', 'Rakukaja', 'Salvation', 'Power Slash']
# ['Survive Light', 'Zan-ei', 'Counter', 'Dodge Ice', 'Power Slash']
# ['Counter', 'Salvation', 'Dodge Slash', 'Mudoon', 'Survive Light']
# ['Mudoon', 'High Counter', 'Absorb Slash', 'Dodge Slash', 'Victory Cry']
# ['Wind Amp', 'Counter', 'High Counter', 'Salvation', 'Mind Charge']
# Best desire: 4
# ['Dodge Ice', 'Mighty Swing', 'Mind Charge', 'Absorb Slash', 'Rakukaja']
# ['High Counter', 'Wind Amp', 'Getsu-ei', 'Mudoon', 'Dodge Slash']
# ['Life Drain', 'Power Slash', 'Dodge Slash', 'Rakukaja', 'Mudoon']
# ['Dodge Slash', 'Rakukaja', 'Spell Master', 'Survive Light', 'Wind Amp']
# ['Mind Charge', 'Dodge Ice', 'Wind Amp', 'Absorb Slash', 'Power Slash']
# ['Salvation', 'Dodge Ice', 'Dodge Slash', 'Rakukaja', 'Spell Master']
# ['Getsu-ei', 'Life Drain', 'Absorb Slash', 'Rakukaja', 'High Counter']
# ['Life Drain', 'Mudoon', 'Counter', 'Victory Cry', 'Dodge Ice']
# ['Dodge Slash', 'Dodge Ice', 'High Counter', 'Rakukaja', 'Salvation']
# ['Survive Light', 'Power Slash', 'Salvation', 'Counter', 'High Counter']
# ['Rakukaja', 'Victory Cry', 'Mudoon', 'Wind Amp', 'Counter']
# ['Dodge Slash', 'Rakukaja', 'Counter', 'Wind Amp', 'Getsu-ei']
# ['Dodge Ice', 'Mudoon', 'Wind Amp', 'Survive Light', 'Counter']
# ['Rakukaja', 'Survive Light', 'Victory Cry', 'Salvation', 'Wind Amp']
# ['Mind Charge', 'Counter', 'Rakukaja', 'Dodge Slash', 'Life Drain']
# ['Dodge Ice', 'Mudoon', 'Power Slash', 'Morning Star', 'Wind Amp']
# ['Spell Master', 'Dodge Ice', 'Absorb Slash', 'Survive Light', 'Rakukaja']
# ['Spell Master', 'Mind Charge', 'Dodge Slash', 'Survive Light', 'Mudoon']
# ['Spell Master', 'Rakukaja', 'Victory Cry', 'Dodge Ice', 'Survive Light']
# ['Victory Cry', 'Dodge Ice', 'Spell Master', 'Mudoon', 'Counter']
# ['Dodge Slash', 'Dodge Ice', 'Mudoon', 'Rakukaja', 'Survive Light']
# ['Spell Master', 'Mind Charge', 'Life Drain', 'Dodge Ice', 'Victory Cry']
# ['Survive Light', 'Rakukaja', 'Dodge Ice', 'Dodge Slash', 'Counter']
# ['Life Drain', 'Rakukaja', 'Absorb Slash', 'Dodge Ice', 'Salvation']
# ['Dodge Ice', 'Victory Cry', 'Dodge Slash', 'Survive Light', 'Mudoon']
# ['Wind Amp', 'Rakukaja', 'Counter', 'Spell Master', 'Dodge Ice']
# ['High Counter', 'Dodge Ice', 'Counter', 'Rakukaja', 'Mighty Swing']
# ['Counter', 'Survive Light', 'Wind Amp', 'Zan-ei', 'Rakukaja']
# ['Zan-ei', 'Rakukaja', 'Mudoon', 'Counter', 'Salvation']
# ['Rakukaja', 'Dodge Slash', 'Mudoon', 'Mighty Swing', 'Absorb Slash']
# ['Dodge Ice', 'Rakukaja', 'Mind Charge', 'Victory Cry', 'High Counter']
# ['Counter', 'Survive Light', 'Rakukaja', 'Mind Charge', 'Victory Cry']
# ['Salvation', 'Rakukaja', 'Dodge Slash', 'Mind Charge', 'High Counter']
# ['Mudoon', 'Rakukaja', 'Life Drain', 'Dodge Slash', 'Wind Amp']
# ['Dodge Slash', 'Rakukaja', 'Mudoon', 'Dodge Ice', 'Wind Amp']
# ['Spell Master', 'Power Slash', 'Wind Amp', 'Dodge Ice', 'Dodge Slash']
# ['Absorb Slash', 'Wind Amp', 'High Counter', 'Counter', 'Dodge Ice']
# ['Wind Amp', 'Dodge Ice', 'Survive Light', 'Mind Charge', 'Rakukaja']
# ['Morning Star', 'Counter', 'Mudoon', 'Salvation', 'Survive Light']
# ['Wind Amp', 'Salvation', 'Counter', 'Mind Charge', 'Dodge Ice']
# ['Mind Charge', 'Dodge Ice', 'Getsu-ei', 'Life Drain', 'High Counter']
# ['Dodge Ice', 'Getsu-ei', 'Dodge Slash', 'Zan-ei', 'Counter']
# ['Rakukaja', 'High Counter', 'Survive Light', 'Mudoon', 'Mind Charge']
# ['Counter', 'Rakukaja', 'High Counter', 'Mudoon', 'Wind Amp']
# ['Counter', 'Dodge Slash', 'Rakukaja', 'Dodge Ice', 'Wind Amp']
# ['Wind Amp', 'Mudoon', 'Dodge Ice', 'Dodge Slash', 'Rakukaja']
# ['Morning Star', 'Mighty Swing', 'Wind Amp', 'Dodge Ice', 'Salvation']
# ['Rakukaja', 'Dodge Ice', 'Wind Amp', 'Dodge Slash', 'Mudoon']
# ['Mudoon', 'Dodge Slash', 'High Counter', 'Spell Master', 'Counter']
# ['Dodge Ice', 'Rakukaja', 'Mind Charge', 'High Counter', 'Counter']
# ['Absorb Slash', 'Dodge Slash', 'Dodge Ice', 'Mudoon', 'Rakukaja']
# ['Mudoon', 'Dodge Slash', 'Counter', 'Rakukaja', 'Absorb Slash']
# ['Mind Charge', 'Survive Light', 'Counter', 'Dodge Ice', 'Spell Master']
# ['Dodge Ice', 'Absorb Slash', 'High Counter', 'Rakukaja', 'Wind Amp']
# ['Rakukaja', 'Counter', 'Survive Light', 'Dodge Ice', 'Mudoon']
# ['Mudoon', 'Zan-ei', 'High Counter', 'Survive Light', 'Dodge Slash']
# ['Dodge Ice', 'Getsu-ei', 'Zan-ei', 'Life Drain', 'High Counter']
# ['Survive Light', 'Salvation', 'Rakukaja', 'Counter', 'Mind Charge']
# ['Counter', 'Survive Light', 'Getsu-ei', 'Victory Cry', 'Mind Charge']
# ['Survive Light', 'Rakukaja', 'Dodge Slash', 'Dodge Ice', 'Getsu-ei']
# ['Power Slash', 'Dodge Ice', 'Mighty Swing', 'Absorb Slash', 'Victory Cry']
# ['Rakukaja', 'Zan-ei', 'Mudoon', 'Dodge Slash', 'High Counter']
# ['Survive Light', 'Absorb Slash', 'Counter', 'Life Drain', 'Dodge Ice']
# ['High Counter', 'Mind Charge', 'Counter', 'Dodge Ice', 'Dodge Slash']
# ['Dodge Ice', 'Mudoon', 'Spell Master', 'Rakukaja', 'Dodge Slash']
# ['Mind Charge', 'Mudoon', 'Getsu-ei', 'Victory Cry', 'Spell Master']
# ['Mind Charge', 'Rakukaja', 'Wind Amp', 'Dodge Slash', 'High Counter']
# ['Dodge Ice', 'Salvation', 'Wind Amp', 'Spell Master', 'High Counter']
# ['Dodge Ice', 'Rakukaja', 'Spell Master', 'High Counter', 'Power Slash']
# ['Wind Amp', 'Dodge Slash', 'Dodge Ice', 'Getsu-ei', 'Primal Force']
# ['Counter', 'Rakukaja', 'Dodge Slash', 'Wind Amp', 'Survive Light']
# ['Mind Charge', 'Dodge Ice', 'Rakukaja', 'Wind Amp', 'High Counter']
# ['Dodge Slash', 'Salvation', 'Wind Amp', 'Primal Force', 'Counter']
# ['Mind Charge', 'Rakukaja', 'Dodge Ice', 'Counter', 'Primal Force']
# ['Mudoon', 'Life Drain', 'Spell Master', 'Rakukaja', 'Dodge Slash']
# ['Absorb Slash', 'Mudoon', 'Salvation', 'Dodge Ice', 'Life Drain']
# ['Rakukaja', 'Mudoon', 'Counter', 'Zan-ei', 'Survive Light']
# ['Power Slash', 'Mudoon', 'Dodge Ice', 'Counter', 'Rakukaja']
# ['Rakukaja', 'Dodge Ice', 'Wind Amp', 'Mind Charge', 'Salvation']
# ['Life Drain', 'Dodge Ice', 'Mind Charge', 'Mudoon', 'Dodge Slash']
# ['Wind Amp', 'Life Drain', 'High Counter', 'Dodge Ice', 'Mudoon']
# ['Mudoon', 'Rakukaja', 'Mighty Swing', 'Dodge Ice', 'Wind Amp']
# ['Survive Light', 'Wind Amp', 'Rakukaja', 'Dodge Slash', 'Salvation']
# ['Rakukaja', 'Survive Light', 'Dodge Ice', 'Mind Charge', 'Dodge Slash']
# ['Mind Charge', 'Wind Amp', 'Rakukaja', 'Dodge Ice', 'Survive Light']
# ['Dodge Slash', 'Survive Light', 'Counter', 'Absorb Slash', 'Salvation']
# ['Mighty Swing', 'Mind Charge', 'Wind Amp', 'Rakukaja', 'Survive Light']
# ['Rakukaja', 'Wind Amp', 'Morning Star', 'Mind Charge', 'Victory Cry']
# ['Counter', 'Power Slash', 'Survive Light', 'Dodge Slash', 'Wind Amp']
# ['Power Slash', 'Getsu-ei', 'Rakukaja', 'Wind Amp', 'Dodge Slash']
# ['Counter', 'Salvation', 'Rakukaja', 'Dodge Slash', 'Power Slash']
# ['Mudoon', 'High Counter', 'Salvation', 'Dodge Slash', 'Rakukaja']
# ['Dodge Slash', 'Mind Charge', 'Spell Master', 'Survive Light', 'Absorb Slash']
# ['Power Slash', 'Wind Amp', 'Mudoon', 'Mighty Swing', 'Getsu-ei']
# ['Dodge Ice', 'Rakukaja', 'Dodge Slash', 'Survive Light', 'Wind Amp']
# ['Dodge Ice', 'Rakukaja', 'Survive Light', 'Victory Cry', 'Wind Amp']
# ['Counter', 'Mudoon', 'Survive Light', 'Spell Master', 'High Counter']
# ['Survive Light', 'Dodge Slash', 'Mind Charge', 'Mudoon', 'Counter']
# ['Dodge Slash', 'Wind Amp', 'Absorb Slash', 'Victory Cry', 'Rakukaja']
# ['Rakukaja', 'Victory Cry', 'Wind Amp', 'Mudoon', 'Dodge Slash']
# ['Wind Amp', 'Rakukaja', 'High Counter', 'Dodge Ice', 'Survive Light']
# ['Dodge Ice', 'Rakukaja', 'Survive Light', 'Counter', 'High Counter']
# ['Absorb Slash', 'Rakukaja', 'Mudoon', 'Dodge Ice', 'Survive Light']
# ['Mudoon', 'Wind Amp', 'Rakukaja', 'Counter', 'Survive Light']
# ['Counter', 'Absorb Slash', 'Mudoon', 'Dodge Slash', 'Salvation']
# ['Dodge Ice', 'Dodge Slash', 'Mind Charge', 'High Counter', 'Mighty Swing']
# ['Mighty Swing', 'Mind Charge', 'High Counter', 'Victory Cry', 'Mudoon']
# ['Mind Charge', 'High Counter', 'Counter', 'Dodge Slash', 'Dodge Ice']
# ['Counter', 'Dodge Ice', 'Survive Light', 'Mind Charge', 'Dodge Slash']
# ['Rakukaja', 'Counter', 'High Counter', 'Dodge Slash', 'Absorb Slash']
# ['Dodge Ice', 'Rakukaja', 'Counter', 'Life Drain', 'Power Slash']
# ['Dodge Ice', 'Wind Amp', 'Mudoon', 'Absorb Slash', 'Dodge Slash']
# ['Salvation', 'Dodge Ice', 'Mighty Swing', 'Survive Light', 'Rakukaja']
# ['Mind Charge', 'Wind Amp', 'High Counter', 'Dodge Slash', 'Survive Light']
# ['Counter', 'Dodge Ice', 'Spell Master', 'Power Slash', 'Rakukaja']
# ['Dodge Slash', 'Survive Light', 'Mudoon', 'Mind Charge', 'Dodge Ice']
# ['Salvation', 'Dodge Slash', 'Survive Light', 'High Counter', 'Wind Amp']
# ['Wind Amp', 'Salvation', 'Zan-ei', 'Spell Master', 'Survive Light']
# ['Survive Light', 'Mudoon', 'Dodge Slash', 'Victory Cry', 'Dodge Ice']
# ['Mighty Swing', 'Wind Amp', 'Survive Light', 'Spell Master', 'Dodge Slash']
# ['Dodge Slash', 'Dodge Ice', 'Mudoon', 'Rakukaja', 'Mind Charge']
# ['Dodge Ice', 'Survive Light', 'Morning Star', 'Mudoon', 'Spell Master']
# ['Dodge Ice', 'Rakukaja', 'Dodge Slash', 'Wind Amp', 'Mudoon']
# ['Dodge Slash', 'Survive Light', 'Dodge Ice', 'High Counter', 'Mind Charge']
# ['High Counter', 'Survive Light', 'Rakukaja', 'Dodge Slash', 'Mind Charge']
# ['Dodge Slash', 'Dodge Ice', 'Rakukaja', 'Mudoon', 'Counter']
# ['Mind Charge', 'High Counter', 'Rakukaja', 'Wind Amp', 'Mudoon']
# ['Counter', 'Wind Amp', 'Mind Charge', 'Dodge Ice', 'Survive Light']
# ['Zan-ei', 'Dodge Ice', 'Mudoon', 'Salvation', 'Counter']
# ['Rakukaja', 'Getsu-ei', 'Mind Charge', 'High Counter', 'Dodge Slash']
# ['Wind Amp', 'Absorb Slash', 'Survive Light', 'Dodge Slash', 'Mighty Swing']
# ['Getsu-ei', 'Survive Light', 'Salvation', 'Dodge Ice', 'Zan-ei']
# ['Mudoon', 'Dodge Slash', 'Survive Light', 'Zan-ei', 'Mind Charge']
# ['Zan-ei', 'Counter', 'Wind Amp', 'Dodge Ice', 'Dodge Slash']
# ['Counter', 'Mudoon', 'Spell Master', 'Mind Charge', 'Dodge Ice']
# ['Dodge Ice', 'Wind Amp', 'Rakukaja', 'Mind Charge', 'Salvation']
# ['Life Drain', 'Primal Force', 'Victory Cry', 'Mind Charge', 'Absorb Slash']
# ['High Counter', 'Rakukaja', 'Mudoon', 'Mind Charge', 'Wind Amp']
# ['Counter', 'Wind Amp', 'Rakukaja', 'Dodge Slash', 'Survive Light']
# ['Survive Light', 'Salvation', 'Rakukaja', 'Dodge Slash', 'Absorb Slash']
# Active window has changed. Stopping the program.

# %%
global_best_desire
# Out:
# 4
