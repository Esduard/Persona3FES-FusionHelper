# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # replace with your actual path

# %%
from PIL import Image
import os

# Open an image file
mainDirectory = r"C:\Users\Eduardo\Pictures\Screenshots\persona3Telos"

directory = 0

fullDirectory = os.path.join(mainDirectory, str(directory))

i = 0

curr_image = os.path.join(fullDirectory, f"cropped_{i}.png")

img = Image.open(curr_image)
text = pytesseract.image_to_string(img)

print(text)
# Out:
# Growth 2

# %%
from PIL import Image
import os
import pytesseract

# Main directory
mainDirectory = r"C:\Users\Eduardo\Pictures\Screenshots\persona3Telos"

# Define the path to the custom dictionary
custom_dict_path = r"skills_dict.txt"

# Custom configuration for pytesseract
custom_config = r'--tessdata-dir "C:\Program Files\Tesseract-OCR\tessdata" --oem 3 --psm 7'

# Iterate over directories
for directory in range(10000):
    fullDirectory = os.path.join(mainDirectory, str(directory))

    # Iterate over images in each directory
    for i in range(8):
        curr_image = os.path.join(fullDirectory, f"cropped_{i}.png")

        # Check if the image file exists
        if os.path.exists(curr_image):
            img = Image.open(curr_image)
            text = pytesseract.image_to_string(img, config=custom_config)


            print(f"Text from image {i} in directory {fullDirectory}:")
            print(text)

            # Save the extracted text to a file
            with open(os.path.join(fullDirectory, f"cropped_{i}.txt"), 'w') as f:
                f.write(text)
        else:
            print(f"Image {i} in directory {directory} does not exist.")
# Out:
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\0:
# Growth 2
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\0:
# Wind Boost
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\0:
# Morning Star
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\0:
# Regenerate 3 |
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\0:
# Apt Pupil j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\0:
# Evade Wind :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\0:
# Absorb Pierce
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\0:
# Auto-Tarukaja_|
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\1:
# Absorb Pierce |
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\1:
# Megidola
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\1:
# Spell Master
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\1:
# Auto-Mataru
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\1:
# Salvation j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\1:
# Garula :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\1:
# Auto-Tarukaja_|
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\1:
# Apt Pupil
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\2:
# Invigorate 3
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\2:
# Akasha Arts
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\2:
# Regenerate 3
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\2:
# Primal Force
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\2:
# Stagnant Air |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\2:
# Tetrakarn :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\2:
# Wind Amp
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\2:
# Auto-Tarukaja_|
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\3:
# Absorb Strike |
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\3:
# Ghastly Wail
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\3:
# Growth 3
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\3:
# High Counter
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\3:
# Stagnant Air |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\3:
# Mahamaon :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\3:
# Apt Pupil
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\3:
# Garula
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\4:
# Wind Boost
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\4:
# God’s Hand
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\4:
# Stagnant Air
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\4:
# Tetrakarn
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\4:
# Auto-Sukukaja |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\4:
# Growth 2 :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\4:
# Primal Force
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\4:
# Growth 3
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\5:
# High Counter
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\5:
# Apt Pupil
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\5:
# Absorb Strike _|
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\5:
# Auto-Tarukaja_]
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\5:
# Wind Amp j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\5:
# Garula :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\5:
# Evade Wind
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\5:
# Auto-Sukukaja_]
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\6:
# Mahamaon
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\6:
# Growth 3
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\6:
# Auto-Tarukaja_|
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\6:
# Regenerate 3 |
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\6:
# Wind Boost j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\6:
# Evade Wind :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\6:
# Invigorate 3
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\6:
# Megidolaon
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\7:
# Stagnant Air
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\7:
# High Counter
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\7:
# Akasha Arts
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\7:
# Auto-Sukukaja_]
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\7:
# Growth 3 j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\7:
# Growth 2 :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\7:
# Invigorate 3
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\7:
# Wind Boost
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\8:
# Akasha Arts
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\8:
# Wind Boost
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\8:
# Tetrakarn
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\8:
# Evade Wind
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\8:
# High Counter |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\8:
# Garula :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\8:
# Ghastly Wail
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\8:
# Regenerate 3 |
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\9:
# Megidola
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\9:
# Garula
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\9:
# Auto-Tarukaja_|
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\9:
# Regenerate 3 |
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\9:
# Poison Arrow j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\9:
# High Counter :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\9:
# Auto-Sukukaja_|
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\9:
# Megidolaon
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\10:
# Salvation
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\10:
# Stagnant Air
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\10:
# Mind Charge
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\10:
# Absorb Slash _]
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\10:
# Wind Boost j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\10:
# Growth 2 :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\10:
# Tempest Slash_|
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\10:
# Auto-Sukukaja_]
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\11:
# Evade Wind
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\11:
# Mind Charge
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\11:
# Victory Cry
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\11:
# Regenerate 3 |
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\11:
# Growth 3 j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\11:
# Panta Rhei :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\11:
# Garula
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\11:
# Poison Arrow __]
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\12:
# Poison Arrow |
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\12:
# High Counter
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\12:
# Wind Boost
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\12:
# Mahamaon
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\12:
# Unshaken Will
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\12:
# Evade Wind :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\12:
# Stagnant Air
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\12:
# Mind Charge
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\13:
# Auto-Mataru
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\13:
# Auto-Sukuka ja_|
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\13:
# Mind Charge
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\13:
# Mahamaon
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\13:
# Ghastly Wail |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\13:
# Stagnant Air :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\13:
# Garula
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\13:
# Growth 2
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\14:
# Garula
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\14:
# Auto-Mataru
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\14:
# Enduring Soul
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\14:
# Apt Pupil
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\14:
# Primal Force jj
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\14:
# Ghastly Wail :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\14:
# Growth 2
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\14:
# Absorb Strike _]
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\15:
# Wind Amp
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\15:
# Absorb Pierce
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\15:
# Auto-Tarukaja_|
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\15:
# Evade Wind
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\15:
# Panta Rhei j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\15:
# Auto-Sukuka ja_|
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\15:
# Morning Star
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\15:
# Victory Cry
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\16:
# Megidolaon
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\16:
# Victory Cry
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\16:
# Wind Amp
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\16:
# Unshaken Will _|
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\16:
# Tetrakarn j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\16:
# God’s Hand :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\16:
# Wind Boost
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\16:
# Stagnant Air
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\17:
# Stagnant Air
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\17:
# Regenerate 3
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\17:
# Wind Amp
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\17:
# Auto-Tarukaja_]
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\17:
# Auto-Sukukaja |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\17:
# Absorb Pierce :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\17:
# Salvation
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\17:
# Evade Wind
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\18:
# Ghastly Wail
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\18:
# Wind Boost
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\18:
# Panta Rhei
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\18:
# Absorb Strike _]
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\18:
# Stagnant Air |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\18:
# Mahamaon :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\18:
# Evade Wind
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\18:
# Absorb Pierce |
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\19:
# Auto-Sukukaja_ |
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\19:
# Growth 2
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\19:
# Wind Amp
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\19:
# Ghastly Wall
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\19:
# Garula j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\19:
# Wind Boost :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\19:
# Stagnant Air
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\19:
# Apt Pupil
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\20:
# Wind Amp
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\20:
# Wind Boost
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\20:
# Absorb Slash _|
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\20:
# Growth 2
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\20:
# Poison Arrow j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\20:
# Tempest Slash _|
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\20:
# Evade Wind
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\20:
# Tetrakarn
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\21:
# Growth 3
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\21:
# Akasha Arts
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\21:
# Poison Arrow
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\21:
# Megidola
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\21:
# Wind Amp j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\21:
# Growth 2 :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\21:
# High Counter
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\21:
# Primal Force
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\22:
# Evade Wind
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\22:
# Megidolaon
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\22:
# Apt Pupil
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\22:
# Auto-Tarukaja_]
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\22:
# Wind Amp j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\22:
# 1hSwd Master _ |
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\22:
# Ghastly Wail
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\22:
# Absorb Slash _]
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\23:
# Megidola
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\23:
# Akasha Arts
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\23:
# Wind Boost
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\23:
# Unshaken Will _|
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\23:
# Wind Amp j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\23:
# Salvation :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\23:
# Stagnant Air
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\23:
# Auto-Tarukaja_|
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\24:
# Growth 3
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\24:
# Absorb Pierce
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\24:
# Auto-Mataru
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\24:
# God's Hand
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\24:
# Evade Wind j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\24:
# Mahamaon :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\24:
# Ghastly Wail
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\24:
# Growth 2
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\25:
# Regenerate 3
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\25:
# Stagnant Air
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\25:
# Absorb Pierce
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\25:
# High Counter
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\25:
# Primal Force jj
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\25:
# Auto-Mataru :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\25:
# Invigorate 3
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\25:
# Mahamaon
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\26:
# Unshaken Will |
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\26:
# Garula
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\26:
# High Counter
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\26:
# Mind Charge
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\26:
# Wind Boost j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\26:
# Victory Cry :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\26:
# Auto-Tarukaja_|
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\26:
# Absorb Strike _]
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\27:
# High Counter
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\27:
# Absorb Slash __ |
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\27:
# Megidolaon
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\27:
# Mind Charge
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\27:
# Invigorate 3 j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\27:
# Growth 3 :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\27:
# Wind Boost
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\27:
# Auto-Sukukaja_]
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\28:
# Megidola
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\28:
# Victory Cry
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\28:
# Primal Force
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\28:
# Panta Rhei
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\28:
# Megidolaon j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\28:
# Evade Wind :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\28:
# Stagnant Air
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\28:
# Apt Pupil
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\29:
# Growth 2
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\29:
# Growth 3
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\29:
# Invigorate 3
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\29:
# Victory Cry
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\29:
# Primal Force }
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\29:
# Stagnant Air :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\29:
# Morning Star
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\29:
# Apt Pupil
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\30:
# Salvation
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\30:
# Wind Boost
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\30:
# Auto-Sukukaja_|
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\30:
# Megidolaon
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\30:
# Garula j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\30:
# Panta Rhei :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\30:
# Growth 2
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\30:
# Wind Amp
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\31:
# Growth 3
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\31:
# Garula
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\31:
# Apt Pupil
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\31:
# Growth 2
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\31:
# Tempest Slash |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\31:
# Unshaken Will |
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\31:
# Regenerate 3
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\31:
# Enduring Soul |
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\32:
# Wind Boost
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\32:
# Salvation
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\32:
# Auto-Tarukaja_|
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\32:
# Stagnant Air
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\32:
# Morning Star}
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\32:
# Tempest Slash _|
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\32:
# Regenerate 3
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\32:
# Growth 3
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\33:
# Growth 3
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\33:
# Stagnant Air
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\33:
# Primal Force
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\33:
# Morning Star
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\33:
# Mind Charge jj
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\33:
# 1hSwd Master _ |
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\33:
# Wind Amp
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\33:
# Panta Rhei
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\34:
# Wind Boost
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\34:
# Growth 3
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\34:
# Akasha Arts
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\34:
# Invigorate 3
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\34:
# Salvation j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\34:
# Tempest Slash _|
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\34:
# Stagnant Air
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\34:
# Megidolaon
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\35:
# Auto-Tarukaja_ |
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\35:
# Garula
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\35:
# ThSwd Master |
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\35:
# Evade Wind
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\35:
# Auto-Mataru |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\35:
# Wind Boost :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\35:
# Primal Force
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\35:
# Megidola
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\36:
# Wind Boost
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\36:
# Megidolaon
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\36:
# High Counter
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\36:
# Auto-Tarukaja_]
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\36:
# Mind Charge jj
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\36:
# Auto-Mataru :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\36:
# Growth 2
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\36:
# Spell Master
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\37:
# Wind Amp
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\37:
# Evade Wind
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\37:
# Mind Charge
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\37:
# Auto-Mataru
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\37:
# Garula j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\37:
# Invigorate 3 :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\37:
# Morning Star
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\37:
# Wind Boost
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\38:
# Tetrakarn
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\38:
# Growth 3
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\38:
# Apt Pupil
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\38:
# Auto-Tarukaja_]
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\38:
# Auto-Sukukaja |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\38:
# Tempest Slash _|
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\38:
# Stagnant Air
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\38:
# Regenerate 3 |
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\39:
# Megidola
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\39:
# Wind Boost
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\39:
# Auto-Sukukaja_|
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\39:
# Victory Cry
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\39:
# Absorb Strike |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\39:
# Wind Amp :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\39:
# Auto-Tarukaja_|
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\39:
# Stagnant Air
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\40:
# 1hSwd Master |
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\40:
# Absorb Slash __ |
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\40:
# Growth 3
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\40:
# Auto-Tarukaja_]
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\40:
# Absorb Strike |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\40:
# Wind Boost :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\40:
# Absorb Pierce
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\40:
# Auto-Sukukaja_]
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\41:
# Garula
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\41:
# Growth 3
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\41:
# Poison Arrow
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\41:
# Akasha Arts
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\41:
# Auto-Tarukaja |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\41:
# Enduring Soul :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\41:
# Mind Charge
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\41:
# Auto-Sukukaja_]
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\42:
# Auto-Sukukaja_ |
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\42:
# Wind Boost
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\42:
# Garula
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\42:
# ThSwd Master _]
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\42:
# High Counter |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\42:
# Wind Amp :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\42:
# Spell Master
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\42:
# Growth 3
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\43:
# Growth 2
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\43:
# Garula
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\43:
# Evade Wind
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\43:
# Wind Amp
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\43:
# Mind Charge jj
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\43:
# Wind Boost :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\43:
# Tetrakarn
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\43:
# God's Hand
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\44:
# Mahamaon
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\44:
# Poison Arrow
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\44:
# Growth 2
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\44:
# High Counter
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\44:
# Apt Pupil j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\44:
# Morning Star :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\44:
# Megidola
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\44:
# Growth 3
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\45:
# Absorb Strike |
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\45:
# Regenerate 3
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\45:
# Absorb Pierce
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\45:
# Auto-Mataru
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\45:
# Wind Amp j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\45:
# High Counter :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\45:
# Evade Wind
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\45:
# Growth 2
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\46:
# God’s Hand
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\46:
# Auto-Tarukaja_ |
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\46:
# Evade Wind
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\46:
# Megidola
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\46:
# Akasha Arts |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\46:
# Enduring Soul :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\46:
# Ghastly Wail
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\46:
# Garula
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\47:
# Mind Charge
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\47:
# Megidola
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\47:
# Unshaken Will _|
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\47:
# Invigorate 3
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\47:
# Growth 2 j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\47:
# Evade Wind :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\47:
# Regenerate 3
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\47:
# Absorb Slash _]
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\48:
# 1hSwd Master |
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\48:
# Growth 2
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\48:
# Wind Amp
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\48:
# Invigorate 3
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\48:
# Evade Wind j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\48:
# Stagnant Air :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\48:
# High Counter
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\48:
# Auto-Tarukaja_|
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\49:
# Growth 2
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\49:
# Tempest Slash_ |
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\49:
# Spell Master
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\49:
# Evade Wind
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\49:
# Victory Cry j
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\49:
# Apt Pupil :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\49:
# Growth 3
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\49:
# Wind Boost
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\50:
# Growth 3
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\50:
# Poison Arrow
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\50:
# Mahamaon
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\50:
# High Counter
#
# Text from image 4 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\50:
# Absorb Slash |
#
# Text from image 5 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\50:
# Stagnant Air :
#
# Text from image 6 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\50:
# Tempest Slash_|
#
# Text from image 7 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\50:
# Evade Wind
#
# Text from image 0 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\51:
# Auto-Sukukaja_ |
#
# Text from image 1 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\51:
# Invigorate 3
#
# Text from image 2 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\51:
# Growth 3
#
# Text from image 3 in directory C:\Users\Eduardo\Pictures\Screenshots\persona3Telos\51:
# Primal Force
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 25
#      23 if os.path.exists(curr_image):
#      24     img = Image.open(curr_image)
# ---> 25     text = pytesseract.image_to_string(img, config=custom_config)
#      28     print(f"Text from image {i} in directory {fullDirectory}:")
#      29     print(text)
#
# File c:\Users\Eduardo\AppData\Local\Programs\Python\Python310\lib\site-packages\pytesseract\pytesseract.py:423, in image_to_string(image, lang, config, nice, output_type, timeout)
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
# --> 423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     426     Output.STRING: lambda: run_and_get_output(*args),
#     427 }[output_type]()
#
# File c:\Users\Eduardo\AppData\Local\Programs\Python\Python310\lib\site-packages\pytesseract\pytesseract.py:426, in image_to_string.<locals>.<lambda>()
#     418 """
#     419 Returns the result of a Tesseract OCR run on the provided image to string
#     420 """
#     421 args = [image, 'txt', lang, config, nice, timeout]
#     423 return {
#     424     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     425     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 426     Output.STRING: lambda: run_and_get_output(*args),
#     427 }[output_type]()
#
# File c:\Users\Eduardo\AppData\Local\Programs\Python\Python310\lib\site-packages\pytesseract\pytesseract.py:288, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     277 with save(image) as (temp_name, input_filename):
#     278     kwargs = {
#     279         'input_filename': input_filename,
#     280         'output_filename_base': temp_name,
#    (...)
#     285         'timeout': timeout,
#     286     }
# --> 288     run_tesseract(**kwargs)
#     289     filename = f"{kwargs['output_filename_base']}{extsep}{extension}"
#     290     with open(filename, 'rb') as output_file:
#
# File c:\Users\Eduardo\AppData\Local\Programs\Python\Python310\lib\site-packages\pytesseract\pytesseract.py:255, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     252     cmd_args.append(extension)
#     254 try:
# --> 255     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     256 except OSError as e:
#     257     if e.errno != ENOENT:
#
# File c:\Users\Eduardo\AppData\Local\Programs\Python\Python310\lib\subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     967         if self.text_mode:
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#     982     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File c:\Users\Eduardo\AppData\Local\Programs\Python\Python310\lib\subprocess.py:1440, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1438 # Start the process
#    1439 try:
# -> 1440     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1441                              # no special security
#    1442                              None, None,
#    1443                              int(not close_fds),
#    1444                              creationflags,
#    1445                              env,
#    1446                              cwd,
#    1447                              startupinfo)
#    1448 finally:
#    1449     # Child is launched. Close the parent's copy of those pipe
#    1450     # handles that only the child should have open.  You need
#    (...)
#    1453     # pipe will not close when the child process exits and the
#    1454     # ReadFile will hang.
#    1455     self._close_pipe_fds(p2cread, p2cwrite,
#    1456                          c2pread, c2pwrite,
#    1457                          errread, errwrite)
#
# KeyboardInterrupt:
